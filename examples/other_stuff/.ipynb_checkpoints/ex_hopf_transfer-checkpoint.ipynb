# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from DE_library import simulate_ODE, simulate_trajectories
import matplotlib.pyplot as plt
from example_utils import reject_outliers, plot_phase_portrait

from MARBLE import utils, geometry, net, plotting, postprocessing, compare_attractors
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def initial_conditions(n, reps, ranges=[[-1,-1],[1,1]]):
    X0_range = [geometry.sample_2d(n, ranges, 'random', seed=i) for i in range(reps)]
        
    return X0_range

def simulate_system(mu, X0, t):
    p, v = simulate_trajectories('supcritical_hopf', X0, t, par = {'mu': mu, 'omega': 1., 'b': 1.})
    pos, vel = [], []
    for p_, v_ in zip(p,v):
        ind = reject_outliers(p_, v_)
        pos.append(p_[ind])
        vel.append(v_[ind])
        
    return pos, vel

def plot_embedding(emb, ax, slices, i, n_clusters=2):
    s = range(slices[i], slices[i+1])
    clusters = geometry.cluster(emb, cluster_typ='kmeans', n_clusters=n_clusters, seed=0)
    plotting.embedding(emb[s], clusters['labels'][s], ax=ax[0])
    plot_phase_portrait(pos_subsample[i], vel_subsample[i], ax[1], node_feature=clusters['labels'][s])

# %% [markdown]
# # For initial conditions, sample a rectangle uniformly

# %%
t0, t1, dt = 0, 1, 0.2
t = np.arange(t0, t1, dt)
n = 200

# %% [markdown]
# # Geneate phase portraits from random initial conditions while varying $\beta_1$

# %%
n_steps=10
beta1 = np.hstack((np.linspace(-1.,1.,n_steps)))

pos, vel = [], []
X0_range = initial_conditions(n, len(beta1), ranges=[[-1,-1],[1,1]])
for i, b1 in enumerate(beta1):
    p, v = simulate_system(b1, X0_range[i], t)
            
    pos.append(np.vstack(p))
    vel.append(np.vstack(v))

# %%
k=10

data = utils.construct_dataset(pos, features=vel, graph_type='cknn', k=k, stop_crit=0.05)
# Out:
# ---- Embedding dimension: 2
# ---- Signal dimension: 2
#
# Embedding dimension <= 2, so manifold computations are disabled!

# %%
titles = [r'$\beta$ = {:0.2f}'.format(b) for b in beta1]

plotting.fields(data, col=4, alpha=0.2, scale=10)
#plotting.fields(data, col=4, alpha=0.2, width=10, , titles=titles, view=[50,60])
# Out:
# [<AxesSubplot:>,
#  <AxesSubplot:>,
#  <AxesSubplot:>,
#  <AxesSubplot:>,
#  <AxesSubplot:>,
#  <AxesSubplot:>,
#  <AxesSubplot:>,
#  <AxesSubplot:>,
#  <AxesSubplot:>,
#  <AxesSubplot:>]

# %% [markdown]
# # Train network

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

par = {'batch_size': 64, #batch size
       'epochs': 40, #optimisation epochs
       'order': 3, #order of derivatives
       'n_lin_layers': 2,
       'gamma': 1.,
       'lr': 0.01,
       'hidden_channels': 16, #number of internal dimensions in MLP
       'out_channels': 3,
       'diffusion': False,
       'inner_product_features': True,
       'batch_norm':False
      }

model = net(data, **par)
model.run_training(data)
# Out:
# ---- Settings:
#
# batch_size : 64
# epochs : 40
# order : 3
# n_lin_layers : 2
# gamma : 1.0
# lr : 0.01
# hidden_channels : 16
# out_channels : 3
# diffusion : False
# inner_product_features : True
# batch_norm : None
# momentum : 0.9
# autoencoder : False
# frac_sampled_nb : -1
# dropout : 0.0
# bias : True
# vec_norm : False
# seed : 0
# processes : 1
# dim_signal : 2
# dim_emb : 2
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  15
# ---- Total number of parameters:  369
#
# ---- Training network ...
#
# Epoch: 1, Training loss: 1.3838, Validation loss: 1.3848, lr: 0.0100 *
# Epoch: 2, Training loss: 1.3831, Validation loss: 1.3820, lr: 0.0100 *
# Epoch: 3, Training loss: 1.3820, Validation loss: 1.3798, lr: 0.0100 *
# Epoch: 4, Training loss: 1.3806, Validation loss: 1.3814, lr: 0.0100
# Epoch: 5, Training loss: 1.3794, Validation loss: 1.3774, lr: 0.0100 *
# Epoch: 6, Training loss: 1.3769, Validation loss: 1.3804, lr: 0.0100
# Epoch: 7, Training loss: 1.3736, Validation loss: 1.3744, lr: 0.0100 *
# Epoch: 8, Training loss: 1.3694, Validation loss: 1.3715, lr: 0.0100 *
# Epoch: 9, Training loss: 1.3646, Validation loss: 1.3603, lr: 0.0100 *
# Epoch: 10, Training loss: 1.3558, Validation loss: 1.3600, lr: 0.0100 *
# Epoch: 11, Training loss: 1.3410, Validation loss: 1.3621, lr: 0.0100
# Epoch: 12, Training loss: 1.3317, Validation loss: 1.3377, lr: 0.0100 *
# Epoch: 13, Training loss: 1.3100, Validation loss: 1.2865, lr: 0.0100 *
# Epoch: 14, Training loss: 1.2846, Validation loss: 1.3109, lr: 0.0100
# Epoch: 15, Training loss: 1.2451, Validation loss: 1.2673, lr: 0.0100 *
# Epoch: 16, Training loss: 1.2523, Validation loss: 1.2873, lr: 0.0100
# Epoch: 17, Training loss: 1.2388, Validation loss: 1.2009, lr: 0.0100 *
# Epoch: 18, Training loss: 1.2256, Validation loss: 1.2019, lr: 0.0100
# Epoch: 19, Training loss: 1.2131, Validation loss: 1.1947, lr: 0.0100 *
# Epoch: 20, Training loss: 1.2056, Validation loss: 1.2550, lr: 0.0100
# Epoch: 21, Training loss: 1.2307, Validation loss: 1.1964, lr: 0.0100
# Epoch: 22, Training loss: 1.2348, Validation loss: 1.2181, lr: 0.0100
# Epoch: 23, Training loss: 1.2043, Validation loss: 1.2047, lr: 0.0100
# Epoch: 24, Training loss: 1.2101, Validation loss: 1.2167, lr: 0.0100
# Epoch: 25, Training loss: 1.2035, Validation loss: 1.2125, lr: 0.0100
# Epoch: 26, Training loss: 1.2025, Validation loss: 1.2224, lr: 0.0100
# Epoch: 27, Training loss: 1.2087, Validation loss: 1.1674, lr: 0.0100 *
# Epoch: 28, Training loss: 1.1771, Validation loss: 1.1930, lr: 0.0100
# Epoch: 29, Training loss: 1.1578, Validation loss: 1.2027, lr: 0.0100
# Epoch: 30, Training loss: 1.1184, Validation loss: 1.2906, lr: 0.0100
# Epoch: 31, Training loss: 1.1431, Validation loss: 1.1437, lr: 0.0100 *
# Epoch: 32, Training loss: 1.1238, Validation loss: 1.1193, lr: 0.0100 *
# Epoch: 33, Training loss: 1.1200, Validation loss: 1.1548, lr: 0.0100
# Epoch: 34, Training loss: 1.1493, Validation loss: 1.2182, lr: 0.0100
# Epoch: 35, Training loss: 1.1527, Validation loss: 1.1634, lr: 0.0100
# Epoch: 36, Training loss: 1.1334, Validation loss: 1.0945, lr: 0.0100 *
# Epoch: 37, Training loss: 1.1214, Validation loss: 1.2660, lr: 0.0100
# Epoch: 38, Training loss: 1.1025, Validation loss: 1.0413, lr: 0.0100 *
# Epoch: 39, Training loss: 1.1408, Validation loss: 1.1464, lr: 0.0100
# Epoch: 40, Training loss: 1.1368, Validation loss: 1.1312, lr: 0.0100
# Final test loss: 1.2149

# %% [markdown]
# # Create embeddings

# %%
data = model.evaluate(data)
n_clusters=20
data = postprocessing(data, n_clusters=n_clusters)

emb_MDS, _ = geometry.embed(data.dist, embed_typ = 'MDS')
plotting.embedding(emb_MDS, beta1, s=30, alpha=1)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# Performed umap embedding on embedded results.
# Performed MDS embedding on embedded results.
# <AxesSubplot:>

# %% [markdown]
# # Distance matrix

# %%
plt.imshow(data.dist)

# %% [markdown]
# # Cluster and visualise embedding

# %%
n_clusters=[2,4,6,8]
fig, ax = plt.subplots(len(n_clusters),4, figsize=(10,10))
slices=data._slice_dict['x']

snapshot=3
for i, n in enumerate(n_clusters):
    plot_embedding(emb, ax[:,:2][i], slices, snapshot, n_clusters=n)
    
snapshot=5
for i, n in enumerate(n_clusters):
    plot_embedding(emb, ax[:,2:][i], slices, snapshot, n_clusters=n)

# %%
_, clusters, dist, gamma = geometry.cluster_embedding(data,cluster_typ='kmeans', embed_typ='umap', n_clusters=30)
# Out:
# Performed umap embedding on embedded results.

# %%
plt.imshow(gamma[4][5])

# %% [markdown]
# # Transfer to Van der Pol oscillator

# %%
def simulate_system(mu, X0, eps=1e-10):
    p, v = simulate_phase_portrait('vanderpol', t, X0, par = {'mu': mu})
    pos, vel = [], []
    for p_, v_ in zip(p,v):
        ind = np.where((abs(p_) < 3).all(1))[0]
        p_ = p_[ind,:]; v_ = v_[ind,:]
        ind = np.where((abs(v_) > eps).any(1))[0]
        p_ = p_[ind,:]; v_ = v_[ind,:]
        pos.append(p_)
        vel.append(v_)
        
    return pos, vel

# %%
n_steps=10
beta1 = np.hstack((np.linspace(-.5,.5,n_steps)))

pos, vel = [], []
X0_range = initial_conditions(n, len(beta1))
for i, b1 in enumerate(beta1):
    p, v = simulate_system(b1, X0_range[i])
            
    pos.append(np.vstack(p))
    vel.append(np.vstack(v))
    
pos_subsample, vel_subsample = [], []
for i, (p,v) in enumerate(zip(pos,vel)):
    ind, _ = geometry.furthest_point_sampling(p, stop_crit=0.02)
    pos_subsample.append(p[ind])
    vel_subsample.append(v[ind])
    
k=10

data_vdp = utils.construct_dataset(pos_subsample, features=vel_subsample, graph_type='cknn', k=k)

# %%
data_vdp = model.evaluate(data_vdp)

# %%
umap_emb, clusters, dist, gamma = geometry.cluster_embedding(data_vdp, n_clusters=20, embed_typ='umap')
titles = [r'$\beta$ = {:0.2f}'.format(b) for b in beta1]
plotting.embedding(umap_emb, data_vdp.y.numpy(), clusters, titles=titles,  s=30)
# Out:
# Performed umap embedding on embedded results.
# <AxesSubplot:>

# %%
emb_MDS = geometry.embed(dist, embed_typ = 'MDS')
labels = [0 if b<0 else 1 for b in beta1]
plotting.embedding(emb_MDS, beta1, s=30, alpha=1)
# Out:
# Performed MDS embedding on embedded results.
# <AxesSubplot:>
