# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

import numpy as np
from DE_library import simulate_ODE, simulate_trajectories
import matplotlib.pyplot as plt
from example_utils import reject_outliers, initial_conditions, plot_phase_portrait, plot_phase_portrait, find_nn, circle

from MARBLE import utils, geometry, net, plotting, postprocessing, compare_attractors

# %%
def simulate_system(mu, X0, t):
    p, v = simulate_trajectories('vanderpol', X0, t, par = {'mu': mu})
    pos, vel = [], []
    for p_, v_ in zip(p,v):
        ind = reject_outliers(p_, v_)
        pos.append(p_[ind])
        vel.append(v_[ind])
        
    return pos, vel

def parabola(X, Y, alpha=0.05):
    Z = -(alpha*X)**2 -(alpha*Y)**2
    
    return np.column_stack([X.flatten(), Y.flatten(), Z.flatten()])

# %% [markdown]
# # For initial conditions, sample a rectangle uniformly

# %%
t0, t1, dt = 0, 10, 0.2
t = np.arange(t0, t1, dt)
n = 5
area = [[-3,-3],[3,3]]

# %% [markdown]
# # Geneate phase portraits from random initial conditions while varying $\beta_1$

# %%
X0_range = initial_conditions(n, 1, area,seed=11)[0]
pos, vel = simulate_system(0.5, X0_range, t)
    
#embed on parabola
for i, (p, v) in enumerate(zip(pos, vel)):
    end_point = p + v
    new_endpoint = parabola(end_point[:,0], end_point[:,1])
    pos[i] = parabola(p[:,0], p[:,1])
    vel[i] = new_endpoint - pos[i]

# %%
plotting.time_series(t, list(pos[0].T), style='.', figsize=(3,2), ms=4)
#plt.savefig('../results/time_series.svg')
plotting.time_series(t, list(pos[1].T), style='.', figsize=(3,2), ms=4)
#plt.savefig('../results/time_series_2.svg')
# Out:
# <AxesSubplot:>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

from matplotlib.colors import LightSource

X, Y = np.mgrid[-3.:3.:0.05, -3.:3.:0.05]
xyz = np.array(parabola(X.flatten(), Y.flatten()))
ls = LightSource(azdeg=30,altdeg=30)
rgb = ls.shade(xyz[:,2].reshape(X.shape)-0.1, plt.cm.gray)


ax.plot_surface(X, Y, xyz[:,2].reshape(X.shape),
                color='gray', 
                shade=True,
                lightsource=ls,
                facecolors=rgb,
                zorder=0
               )

ax = plot_phase_portrait(pos, vel, ax=ax,style='-', lw=2,
                         node_feature=[[i]*len(p) for i, p in enumerate(pos)])
ax = plot_phase_portrait(pos, vel, ax=ax,style='>', scale=10, lw=15, spacing=5,
                         node_feature=[[i]*len(p) for i, p in enumerate(pos)])

ax.view_init(elev=70, azim=25)
#plt.savefig('./outputs/parabolas.svg')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pos_concat, vel_concat = np.vstack(pos), np.vstack(vel)
data = utils.construct_dataset(pos_concat, features=vel_concat, graph_type='cknn', k=15, stop_crit=0.03, vector=False)
# Out:
# ---- Embedding dimension: 3
# ---- Signal dimension: 3
#
# Vector computations are disabled
#
# ---- Computing kernels ... Done
# ---- Computing eigendecomposition ... Done

# %%
ax = plotting.fields(data, col=1, alpha=1, width=20, scale=2, view=[70,25])

ax[0].plot_surface(X, Y, xyz[:,2].reshape(X.shape)-0.01,
                color='white', 
                alpha=0.1,
                shade=False,
                lightsource=ls,
                facecolors=rgb,
                zorder=0
               )
#plt.savefig('./outputs/parabola_graph.svg')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
par = {'epochs': 75, #optimisation epochs
       'order': 2, #order of derivatives
       'hidden_channels': 32, #number of internal dimensions in MLP
       'out_channels': 4,
       'inner_product_features': True,
      }

model = net(data, par=par)
model.run_training(data)
# Out:
# ---- Settings:
#
# epochs : 75
# order : 2
# hidden_channels : 32
# out_channels : 4
# inner_product_features : True
# batch_size : 64
# lr : 0.01
# momentum : 0.9
# diffusion : False
# include_positions : False
# frac_sampled_nb : -1
# dropout : 0.0
# n_lin_layers : 2
# bias : True
# vec_norm : False
# batch_norm : None
# seed : 0
# processes : 1
# dim_signal : 3
# dim_emb : 3
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  13
# ---- Total number of parameters:  698
#
# ---- Training network ...
#
# Epoch: 1, Training loss: 1.3771, Validation loss: 1.3900, lr: 0.0100 *
# Epoch: 2, Training loss: 1.3837, Validation loss: 1.3672, lr: 0.0100 *
# Epoch: 3, Training loss: 1.3828, Validation loss: 1.3969, lr: 0.0100
# Epoch: 4, Training loss: 1.3897, Validation loss: 1.4050, lr: 0.0100
# Epoch: 5, Training loss: 1.3835, Validation loss: 1.3923, lr: 0.0100
# Epoch: 6, Training loss: 1.3763, Validation loss: 1.3931, lr: 0.0100
# Epoch: 7, Training loss: 1.3838, Validation loss: 1.3850, lr: 0.0100
# Epoch: 8, Training loss: 1.3795, Validation loss: 1.3720, lr: 0.0100
# Epoch: 9, Training loss: 1.3736, Validation loss: 1.3710, lr: 0.0100
# Epoch: 10, Training loss: 1.3797, Validation loss: 1.3920, lr: 0.0100
# Epoch: 11, Training loss: 1.3767, Validation loss: 1.3874, lr: 0.0100
# Epoch: 12, Training loss: 1.3729, Validation loss: 1.3815, lr: 0.0100
# Epoch: 13, Training loss: 1.3770, Validation loss: 1.3887, lr: 0.0100
# Epoch: 14, Training loss: 1.3778, Validation loss: 1.3821, lr: 0.0100
# Epoch: 15, Training loss: 1.3778, Validation loss: 1.3938, lr: 0.0100
# Epoch: 16, Training loss: 1.3788, Validation loss: 1.3842, lr: 0.0100
# Epoch: 17, Training loss: 1.3773, Validation loss: 1.3834, lr: 0.0100
# Epoch: 18, Training loss: 1.3759, Validation loss: 1.3708, lr: 0.0100
# Epoch: 19, Training loss: 1.3701, Validation loss: 1.3779, lr: 0.0100
# Epoch: 20, Training loss: 1.3608, Validation loss: 1.3805, lr: 0.0100
# Epoch: 55, Training loss: 1.2691, Validation loss: 1.3925, lr: 0.0100
# Epoch: 56, Training loss: 1.2560, Validation loss: 1.3773, lr: 0.0100
# Epoch: 57, Training loss: 1.3134, Validation loss: 1.3220, lr: 0.0100
# Epoch: 58, Training loss: 1.3065, Validation loss: 1.3245, lr: 0.0100
# Epoch: 59, Training loss: 1.2452, Validation loss: 1.2521, lr: 0.0100 *
# Epoch: 60, Training loss: 1.3069, Validation loss: 1.3038, lr: 0.0100
# Epoch: 61, Training loss: 1.2538, Validation loss: 1.3866, lr: 0.0100
# Epoch: 62, Training loss: 1.2798, Validation loss: 1.3362, lr: 0.0100
# Epoch: 63, Training loss: 1.3073, Validation loss: 1.2757, lr: 0.0100
# Epoch: 64, Training loss: 1.3402, Validation loss: 1.2592, lr: 0.0100
# Epoch: 65, Training loss: 1.2789, Validation loss: 1.2898, lr: 0.0100
# Epoch: 66, Training loss: 1.3366, Validation loss: 1.3611, lr: 0.0100
# Epoch: 67, Training loss: 1.3597, Validation loss: 1.3615, lr: 0.0100
# Epoch: 68, Training loss: 1.2656, Validation loss: 1.3173, lr: 0.0100
# Epoch: 69, Training loss: 1.2839, Validation loss: 1.2593, lr: 0.0100
# Epoch: 70, Training loss: 1.2040, Validation loss: 1.3284, lr: 0.0100
# Epoch: 71, Training loss: 1.2481, Validation loss: 1.2910, lr: 0.0100
# Epoch: 72, Training loss: 1.2589, Validation loss: 1.2456, lr: 0.0100 *
# Epoch: 73, Training loss: 1.2526, Validation loss: 1.3178, lr: 0.0100
# Epoch: 74, Training loss: 1.3449, Validation loss: 1.2589, lr: 0.0100
# Epoch: 75, Training loss: 1.2688, Validation loss: 1.2662, lr: 0.0100
# Final test loss: 1.3599

# %%
data = model.evaluate(data)
data = postprocessing(data, n_clusters=10)
plotting.embedding(data)
#plt.savefig('./outputs/embedding.svg')
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
plotting.neighbourhoods(data, hops=2)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 plotting.neighbourhoods(data, hops=2)
#
# File /mnt/scratch/lts2/gosztolai/MARBLE/MARBLE/lib/plotting.py:272, in neighbourhoods(data, hops, cols, norm, color, plot_graph, figsize, fontsize)
#     251 def neighbourhoods(data,
#     252                    hops=1,
#     253                    cols=4,
#    (...)
#     257                    figsize=(15, 20),
#     258                    fontsize=20):
#     259     """
#     260     For each clustered neighbourhood type, draw one sample neighbourhood
#     261     from each dataset and plot.
#    (...)
#     269
#     270     """
# --> 272     assert hasattr(data, 'clusters'), 'No clusters found. First, run \
#     273         geometry.cluster(data) or postprocessing(data)!'
#     275     vector = True if data.x.shape[1] > 1 else False
#     276     clusters = data.clusters
#
# AssertionError: No clusters found. First, run         geometry.cluster(data) or postprocessing(data)!
