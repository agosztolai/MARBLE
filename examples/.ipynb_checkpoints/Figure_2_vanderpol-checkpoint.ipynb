# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import sys
sys.path.append("./RNN_scripts")
from DE_library import simulate_ODE, simulate_trajectories
import matplotlib.pyplot as plt
from example_utils import reject_outliers, initial_conditions, plot_phase_portrait

from MARBLE import utils, geometry, net, plotting, postprocessing, compare_attractors
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def simulate_system(mu, X0, t):
    p, v = simulate_trajectories('vanderpol', X0, t, par = {'mu': mu})
    pos, vel = [], []
    for p_, v_ in zip(p,v):
        ind = reject_outliers(p_, v_)
        pos.append(p_[ind])
        vel.append(v_[ind])
        
    return pos, vel

def parabola(X, Y, alpha=0.05):
    Z = -(alpha*X)**2 -(alpha*Y)**2
    
    return np.column_stack([X.flatten(), Y.flatten(), Z.flatten()])

# %% [markdown]
# # For initial conditions, sample a rectangle uniformly

# %%
t0, t1, dt = 0, 3, 0.5
t = np.arange(t0, t1, dt)
n = 100
area = [[-3,-3],[3,3]]

# %% [markdown]
# # Geneate phase portraits from random initial conditions while varying $\beta_1$

# %%
n_steps=20
beta1 = np.hstack((np.linspace(-.5,.5,n_steps)))

pos, vel = [], []
X0_range = initial_conditions(n, len(beta1), area)
for i, b1 in enumerate(beta1):
    p, v = simulate_system(b1, X0_range[i], t)
            
    pos.append(np.vstack(p))
    vel.append(np.vstack(v))
    
#embed on parabola
for i, (p, v) in enumerate(zip(pos, vel)):
    end_point = p + v
    new_endpoint = parabola(end_point[:,0], end_point[:,1])
    pos[i] = parabola(p[:,0], p[:,1])
    vel[i] = new_endpoint - pos[i]
# Out:
# /mnt/scratch/lts2/gosztolai/miniconda3/envs/MARBLE/lib/python3.9/site-packages/scipy/integrate/_odepack_py.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)

# %% [markdown]
# # Plot vector fields

# %%
data = utils.construct_dataset(pos, features=vel, graph_type='cknn', k=20, n_geodesic_nb=30, stop_crit=0.03, vector=False)
# Out:
# ---- Embedding dimension: 3
# ---- Signal dimension: 3
#
#
# Vector computations are disabled

# %%
titles = [r'$\beta$ = {:0.2f}'.format(b) for b in beta1]

#plotting.fields(data, col=4, alpha=0.3, scale=10)
axes = plotting.fields(data, col=4, alpha=1, width=7, scale=2, titles=titles, view=[70,20])

from matplotlib.colors import LightSource

x = y = np.arange(-3.0, 3.0, 0.05)
X, Y = np.meshgrid(x, y)
xyz = np.array(parabola(np.ravel(X), np.ravel(Y)))
ls = LightSource(azdeg=30,altdeg=30)
rgb = ls.shade(xyz[:,2].reshape(X.shape)-0.1, plt.cm.gray)

for ax in axes:
    ax.plot_surface(xyz[:,0].reshape(X.shape), xyz[:,1].reshape(X.shape), xyz[:,2].reshape(X.shape)-0.02, 
                color='gray', 
                shade=True,
                lightsource=ls,
                facecolors=rgb
               )
#plt.savefig('./outputs/parabolas.svg')

# %% [markdown]
# # Train network

# %%
par = {'epochs': 75, #optimisation epochs
       'order': 2, #order of derivatives
       'hidden_channels': 32, #number of internal dimensions in MLP
       'out_channels': 4,
       'inner_product_features': True,
      }

model = net(data, **par)
model.run_training(data)
# Out:
# ---- Settings:
#
# epochs : 75
# order : 2
# hidden_channels : 32
# out_channels : 4
# inner_product_features : True
# batch_size : 64
# lr : 0.01
# momentum : 0.9
# autoencoder : False
# diffusion : False
# frac_sampled_nb : -1
# dropout : 0.0
# n_lin_layers : 2
# bias : True
# vec_norm : False
# batch_norm : None
# seed : 0
# processes : 1
# dim_signal : 3
# dim_emb : 3
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  13
# ---- Total number of parameters:  698
#
# ---- Training network ...
#
# Epoch: 1, Training loss: 1.3747, Validation loss: 1.3575, lr: 0.0100 *
# Epoch: 44, Training loss: 1.0474, Validation loss: 0.9767, lr: 0.0100 *
# Epoch: 45, Training loss: 1.0480, Validation loss: 0.9920, lr: 0.0100
# Epoch: 46, Training loss: 1.0479, Validation loss: 1.0633, lr: 0.0100
# Epoch: 47, Training loss: 1.0312, Validation loss: 1.0547, lr: 0.0100
# Epoch: 48, Training loss: 1.0278, Validation loss: 1.0543, lr: 0.0100
# Epoch: 49, Training loss: 1.0141, Validation loss: 1.1438, lr: 0.0100
# Epoch: 50, Training loss: 1.0408, Validation loss: 1.0947, lr: 0.0100
# Epoch: 51, Training loss: 1.0374, Validation loss: 1.0274, lr: 0.0100
# Epoch: 52, Training loss: 1.0184, Validation loss: 1.0178, lr: 0.0100
# Epoch: 53, Training loss: 1.0273, Validation loss: 1.0294, lr: 0.0100
# Epoch: 54, Training loss: 1.0244, Validation loss: 0.9684, lr: 0.0100 *
# Epoch: 55, Training loss: 1.0304, Validation loss: 0.9970, lr: 0.0100
# Epoch: 56, Training loss: 1.0453, Validation loss: 1.1030, lr: 0.0100
# Epoch: 57, Training loss: 1.0165, Validation loss: 1.0178, lr: 0.0100
# Epoch: 58, Training loss: 1.0349, Validation loss: 1.0842, lr: 0.0100
# Epoch: 59, Training loss: 1.0313, Validation loss: 1.0871, lr: 0.0100
# Epoch: 60, Training loss: 1.0334, Validation loss: 1.0024, lr: 0.0010
# Epoch: 61, Training loss: 1.0314, Validation loss: 1.0443, lr: 0.0010
# Epoch: 62, Training loss: 1.0360, Validation loss: 1.0582, lr: 0.0010
# Epoch: 63, Training loss: 1.0206, Validation loss: 1.0104, lr: 0.0010
# Epoch: 64, Training loss: 1.0246, Validation loss: 1.0454, lr: 0.0010
# Epoch: 65, Training loss: 1.0269, Validation loss: 1.0065, lr: 0.0010
# Epoch: 66, Training loss: 1.0195, Validation loss: 1.0571, lr: 0.0010
# Epoch: 67, Training loss: 1.0265, Validation loss: 1.0548, lr: 0.0010
# Epoch: 68, Training loss: 1.0132, Validation loss: 1.0550, lr: 0.0010
# Epoch: 69, Training loss: 1.0159, Validation loss: 1.0609, lr: 0.0010
# Epoch: 70, Training loss: 1.0305, Validation loss: 1.0003, lr: 0.0010
# Epoch: 71, Training loss: 1.0374, Validation loss: 0.9712, lr: 0.0010
# Epoch: 72, Training loss: 1.0308, Validation loss: 0.9506, lr: 0.0010 *
# Epoch: 73, Training loss: 1.0256, Validation loss: 1.0394, lr: 0.0010
# Epoch: 74, Training loss: 1.0161, Validation loss: 1.0394, lr: 0.0010
# Epoch: 75, Training loss: 1.0300, Validation loss: 1.0220, lr: 0.0010
# Final test loss: 1.0722

# %% [markdown]
# # Create embeddings

# %%
data = model.evaluate(data)
n_clusters=40
data = postprocessing(data, n_clusters=n_clusters)

emb_MDS, _ = geometry.embed(data.dist, embed_typ = 'MDS')
plotting.embedding(emb_MDS, beta1, s=30, alpha=1)
#plt.savefig('../results/van_der_pol_MDS.svg')
# Out:
# Performed umap embedding on embedded results.
# Performed MDS embedding on embedded results.
# <AxesSubplot:>

# %% [markdown]
# # Distance matrix

# %%
im = plt.imshow(data.dist)
plt.colorbar(im)
#plt.savefig('../results/van_der_pol_D.svg')

# %% [markdown]
# # Cluster and visualise embedding

# %%
titles = [r'$\beta$ = {:0.2f}'.format(b) for b in beta1]
plotting.embedding(data, beta1[data.y.numpy().astype(int)], titles=titles)
#plt.savefig('../results/van_der_pol_embedding.svg')
# Out:
# <AxesSubplot:>
