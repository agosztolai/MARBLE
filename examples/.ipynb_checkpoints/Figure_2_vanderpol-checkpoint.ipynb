# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import example_utils as ex_utils

from MARBLE import utils, geometry, net, plotting, postprocessing
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # For initial conditions, sample a rectangle uniformly

# %%
t0, t1, dt = 0, 3, 0.5
t = np.arange(t0, t1, dt)
n = 100
area = [[-3,-3],[3,3]]

# %% [markdown]
# # Geneate phase portraits from random initial conditions while varying $\beta_1$

# %%
n_steps=20
mu = np.hstack((np.linspace(-.5,.5,n_steps)))

pos, vel = [], []
X0_range = ex_utils.initial_conditions(n, len(mu), area)
for i, m in enumerate(mu):
    p, v = ex_utils.simulate_vanderpol(m, X0_range[i], t)
            
    pos.append(np.vstack(p))
    vel.append(np.vstack(v))
    
#embed on parabola
for i, (p, v) in enumerate(zip(pos, vel)):
    end_point = p + v
    new_endpoint = ex_utils.parabola(end_point[:,0], end_point[:,1])
    pos[i] = ex_utils.parabola(p[:,0], p[:,1])
    vel[i] = new_endpoint - pos[i]
# Out:
# /mnt/scratch/lts2/gosztolai/miniconda3/envs/MARBLE/lib/python3.9/site-packages/scipy/integrate/_odepack_py.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)

# %% [markdown]
# # Plot vector fields

# %%
data = utils.construct_dataset(pos, features=vel, graph_type='cknn', k=20, n_geodesic_nb=30, stop_crit=0.03, vector=False)
# Out:
# ---- Embedding dimension: 3
# ---- Signal dimension: 3
#
#
# Vector computations are disabled
#
# ---- Computing kernels ... Done

# %%
titles = [r'$\beta$ = {:0.2f}'.format(m) for m in mu]

axes = plotting.fields(data, col=4, alpha=1, width=7, scale=2, titles=titles, view=[70,20])
for ax in axes:
    ex_utils.plot_parabola(ax)

#plt.savefig('./outputs/parabolas.svg')

# %% [markdown]
# # Train network

# %%
par = {'epochs': 75, #optimisation epochs
       'order': 2, #order of derivatives
       'hidden_channels': 32, #number of internal dimensions in MLP
       'out_channels': 5,
       'inner_product_features': True,
      }

model = net(data, **par)
model.run_training(data, outdir='./output/vanderpol_data')
#model.load_model('./output/vanderpol_data/best_model.pth')
# Out:
# ---- Settings:
#
# epochs : 75
# order : 2
# hidden_channels : 32
# out_channels : 5
# inner_product_features : True
# batch_size : 64
# lr : 0.01
# momentum : 0.9
# diffusion : False
# frac_sampled_nb : -1
# dropout : 0.0
# n_lin_layers : 2
# bias : True
# vec_norm : False
# batch_norm : None
# seed : 0
# processes : 1
# dim_signal : 3
# dim_emb : 3
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  13
# ---- Total number of parameters:  731
#
# ---- Training network ...
#
# Epoch: 1, Training loss: 1.3725, Validation loss: 1.3550, lr: 0.0100 *
# Epoch: 2, Training loss: 1.2925, Validation loss: 1.2916, lr: 0.0100 *
# Epoch: 3, Training loss: 1.2554, Validation loss: 1.2794, lr: 0.0100 *
# Epoch: 4, Training loss: 1.2430, Validation loss: 1.2652, lr: 0.0100 *
# Epoch: 5, Training loss: 1.2155, Validation loss: 1.2239, lr: 0.0100 *
# Epoch: 6, Training loss: 1.1992, Validation loss: 1.1412, lr: 0.0100 *
# Epoch: 7, Training loss: 1.1220, Validation loss: 1.1032, lr: 0.0100 *
# Epoch: 8, Training loss: 1.0820, Validation loss: 1.0672, lr: 0.0100 *
# Epoch: 47, Training loss: 1.0185, Validation loss: 1.1000, lr: 0.0100
# Epoch: 48, Training loss: 1.0043, Validation loss: 1.0183, lr: 0.0010
# Epoch: 49, Training loss: 1.0129, Validation loss: 1.0052, lr: 0.0010
# Epoch: 50, Training loss: 1.0093, Validation loss: 0.9776, lr: 0.0010 *
# Epoch: 51, Training loss: 0.9888, Validation loss: 1.0134, lr: 0.0010
# Epoch: 52, Training loss: 1.0043, Validation loss: 1.0155, lr: 0.0010
# Epoch: 53, Training loss: 0.9773, Validation loss: 1.0413, lr: 0.0010
# Epoch: 54, Training loss: 0.9862, Validation loss: 1.0254, lr: 0.0010
# Epoch: 55, Training loss: 1.0121, Validation loss: 1.0230, lr: 0.0010
# Epoch: 56, Training loss: 1.0121, Validation loss: 1.0430, lr: 0.0010
# Epoch: 57, Training loss: 1.0075, Validation loss: 1.0062, lr: 0.0010
# Epoch: 58, Training loss: 0.9948, Validation loss: 1.0670, lr: 0.0010
# Epoch: 59, Training loss: 0.9979, Validation loss: 1.0069, lr: 0.0010
# Epoch: 60, Training loss: 0.9799, Validation loss: 1.0071, lr: 0.0010
# Epoch: 61, Training loss: 1.0112, Validation loss: 1.0612, lr: 0.0010
# Epoch: 62, Training loss: 0.9962, Validation loss: 0.9969, lr: 0.0010
# Epoch: 63, Training loss: 0.9874, Validation loss: 1.0200, lr: 0.0010
# Epoch: 64, Training loss: 0.9928, Validation loss: 1.0576, lr: 0.0001
# Epoch: 65, Training loss: 0.9987, Validation loss: 0.9772, lr: 0.0001 *
# Epoch: 66, Training loss: 1.0117, Validation loss: 0.9877, lr: 0.0001
# Epoch: 67, Training loss: 0.9922, Validation loss: 1.0208, lr: 0.0001
# Epoch: 68, Training loss: 0.9900, Validation loss: 1.0147, lr: 0.0001
# Epoch: 69, Training loss: 1.0032, Validation loss: 0.9763, lr: 0.0001 *
# Epoch: 70, Training loss: 0.9835, Validation loss: 1.0330, lr: 0.0001
# Epoch: 71, Training loss: 0.9977, Validation loss: 0.9950, lr: 0.0001
# Epoch: 72, Training loss: 0.9941, Validation loss: 1.0400, lr: 0.0001
# Epoch: 73, Training loss: 0.9999, Validation loss: 0.9893, lr: 0.0001
# Epoch: 74, Training loss: 0.9872, Validation loss: 1.0263, lr: 0.0001
# Epoch: 75, Training loss: 1.0158, Validation loss: 1.0267, lr: 0.0000
# Final test loss: 1.0090

# %% [markdown]
# # Create embeddings

# %%
data = model.evaluate(data)
n_clusters=40
data = postprocessing(data, n_clusters=n_clusters)

emb_MDS, _ = geometry.embed(data.dist, embed_typ = 'MDS')
plotting.embedding(emb_MDS, mu, s=30, alpha=1)
#plt.savefig('../results/van_der_pol_MDS.svg')
plt.show()

# %% [markdown]
# # Distance matrix

# %%
im = plt.imshow(data.dist)
plt.colorbar(im)
#plt.savefig('../results/van_der_pol_D.svg')

# %% [markdown]
# # Cluster and visualise embedding

# %%
titles = [r'$\beta$ = {:0.2f}'.format(m) for m in mu]
plotting.embedding(data, mu[data.y.numpy().astype(int)], titles=titles)
#plt.savefig('../results/van_der_pol_embedding.svg')
# Out:
# <AxesSubplot:>
