# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("./RNN_scripts")
import torch
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from RNN_scripts import dms, ranktwo, clustering
from RNN_scripts.modules import LowRankRNN, train
import seaborn as sns

import MARBLE
from MARBLE import utils, geometry, plotting, postprocessing, compare_attractors
from example_utils import generate_trajectories, plot_experiment, aggregate_data

# %% [markdown]
# # Load trained model

# %%
noise_std = 5e-2
alpha = 0.2
hidden_size=500

x_train, y_train, mask_train, x_val, y_val, mask_val = dms.generate_dms_data(1000)
net1 =  LowRankRNN(2, hidden_size, 1, noise_std, alpha, rank=2)
net1.load_state_dict(torch.load(f'./RNN_scripts/dms_rank2_500.pt', map_location='cpu'))
net1.svd_reparametrization()

net2 =  LowRankRNN(2, hidden_size, 1, noise_std, alpha, rank=2)
net2.load_state_dict(torch.load(f'./RNN_scripts/dms_rank2_500_2.pt', map_location='cpu'))
net2.svd_reparametrization()

# %% [markdown]
# # Fit Gaussian and sample new networks

# %%
n_pops = 2
z1, _ = clustering.gmm_fit(net1, n_pops, algo='bayes', random_state=2020)  # z will contain labels for the 2 populations
z2, _ = clustering.gmm_fit(net2, n_pops, algo='bayes', random_state=2020)

net1_sampled_1 = clustering.to_support_net(net1, z1)
net1_sampled_2 = clustering.to_support_net(net1, z1)

net2_sampled_1 = clustering.to_support_net(net2, z2)
net2_sampled_2 = clustering.to_support_net(net2, z2)

# %% [markdown]
# # Visualising two network populations

# %%
# Visualizing those 2 populations
m = net1.m[:,0].detach().numpy()
n = net1.n[:,0].detach().numpy() 
wi1 = net1.wi[0].detach().numpy()
wi2 = net1.wi[1].detach().numpy()

fig, ax = plt.subplots(1, 2, figsize=(8, 4))
colors = ['rebeccapurple', 'seagreen']
fs = 12
clustering.pop_scatter_linreg(wi1, wi2, z1, n_pops, colors=colors, ax=ax[0])
#clustering.pop_scatter_linreg(n, wi1, z1, n_pops, colors=colors, ax=ax[0])
clustering.pop_scatter_linreg(n, wi2, z1, n_pops, colors=colors, ax=ax[1])
#plt.savefig('./outputs/GNN_parameter_distribution.svg')
# Out:
# pop 0: slope=0.06, intercept=0.02
# pop 1: slope=-0.24, intercept=-0.18
# pop 0: slope=-0.01, intercept=0.02
# pop 1: slope=-0.02, intercept=-0.20

# %% [markdown]
# # Design input

# %%
n_gains=20
stim1_begin, stim1_end, stim2_begin, stim2_end, decision = 25, 50, 200, 225, 275
epochs = [0, stim1_begin, stim1_end, stim2_begin, stim2_end, decision]
gain = np.linspace(1,0,n_gains)
    
input = torch.zeros(n_gains, decision, 2)
for i, g in enumerate(gain):
    input[i, stim1_begin:stim1_end, 0] = g
    input[i, stim2_begin:stim2_end, 0] = g
    
fig, ax = plt.subplots(1, 1, figsize=(5, 3))
plt.plot(input[0])
#plt.savefig('./outputs/stim.svg')
# Out:
# [<matplotlib.lines.Line2D at 0x7f0d4c97b430>,
#  <matplotlib.lines.Line2D at 0x7f0d4c9e87c0>]

# %% [markdown]
# # Plot phase portraits of two different dynamics

# %%
n_traj=100

traj1 = generate_trajectories(net1, input, epochs, n_traj, fname='./outputs/RNN_trajectories1.pkl')
traj2 = generate_trajectories(net2, input, epochs, n_traj, fname='./outputs/RNN_trajectories1.pkl')

traj11 = generate_trajectories(net1_sampled_1, input, epochs, n_traj, fname='./outputs/RNN_trajectories11.pkl')
traj12 = generate_trajectories(net1_sampled_2, input, epochs, n_traj, fname='./outputs/RNN_trajectories12.pkl')
traj21 = generate_trajectories(net2_sampled_1, input, epochs, n_traj, fname='./outputs/RNN_trajectories21.pkl')
traj22 = generate_trajectories(net2_sampled_2, input, epochs, n_traj, fname='./outputs/RNN_trajectories22.pkl')

# %%
plot_experiment(net1, input, traj1, epochs, rect=(-6, 6, -4, 4), traj_to_show=5)

#plt.savefig('./outputs/fields_all_conditions.svg')

# %%
plot_experiment(net2, input, traj2, epochs, rect=(-8, 8, -6, 6), traj_to_show=5)

# %% [markdown]
# # Concatenate data and create dataset

# %%
pos11, vel11 = aggregate_data(traj11, epochs)
pos12, vel12 = aggregate_data(traj12, epochs)

#pos21, vel21 = aggregate_data(traj21, epochs)
#pos22, vel22 = aggregate_data(traj22, epochs)

pos = pos11 + pos12# + pos21 + pos22
vel = vel11 + vel12# + vel21 + vel22

#pos1, vel1 = aggregate_data(traj1, epochs)
#pos2, vel2 = aggregate_data(traj2, epochs)

#pos = pos1 + pos2
#vel = vel1 + vel2

# %%
data = utils.construct_dataset(pos, features=vel, graph_type='cknn', k=15, stop_crit=0.03, vector=False)
# Out:
# ---- Embedding dimension: 3
# ---- Signal dimension: 3
#
#
# Vector computations are disabled

# %%
titles = [r'$gain$ = {:0.2f}, {}'.format(g, s) for s in ['stim', 'unstim'] for g in gain ]

plotting.fields(data, col=4, alpha=0.2, width=0.01, scale=200, titles=titles)
plt.show()

# %%
par = {'epochs': 40, #optimisation epochs
       'order': 2, #order of derivatives
       'hidden_channels': 32, #number of internal dimensions in MLP
       'out_channels': 5,
       'inner_product_features': True,
      }

model = MARBLE.net(data, **par)
model.run_training(data, use_best=True)
# Out:
# ---- Settings:
#
# epochs : 40
# order : 2
# hidden_channels : 32
# out_channels : 5
# inner_product_features : True
# batch_size : 64
# lr : 0.01
# momentum : 0.9
# autoencoder : False
# diffusion : False
# frac_sampled_nb : -1
# dropout : 0.0
# n_lin_layers : 2
# bias : True
# vec_norm : False
# batch_norm : None
# seed : 0
# processes : 1
# dim_signal : 3
# dim_emb : 3
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  13
# ---- Total number of parameters:  731
#
# ---- Training network ...
#
# Epoch: 1, Training loss: 1.2120, Validation loss: 1.1512, lr: 0.0100 *
# Epoch: 2, Training loss: 1.0980, Validation loss: 1.1195, lr: 0.0100 *
# Epoch: 3, Training loss: 1.0596, Validation loss: 1.0888, lr: 0.0100 *
# Epoch: 4, Training loss: 1.0363, Validation loss: 1.0451, lr: 0.0100 *
# Epoch: 5, Training loss: 1.0235, Validation loss: 1.0419, lr: 0.0100 *
# Epoch: 6, Training loss: 1.0211, Validation loss: 1.0611, lr: 0.0100
# Epoch: 7, Training loss: 1.0223, Validation loss: 1.0605, lr: 0.0100
# Epoch: 8, Training loss: 1.0208, Validation loss: 1.0426, lr: 0.0100
# Epoch: 9, Training loss: 1.0091, Validation loss: 1.0456, lr: 0.0100
# Epoch: 10, Training loss: 1.0097, Validation loss: 1.0526, lr: 0.0100
# Epoch: 11, Training loss: 1.0056, Validation loss: 1.0515, lr: 0.0100
# Epoch: 12, Training loss: 1.0091, Validation loss: 1.0355, lr: 0.0100 *
# Epoch: 13, Training loss: 1.0098, Validation loss: 1.0295, lr: 0.0100 *
# Epoch: 14, Training loss: 0.9906, Validation loss: 1.0417, lr: 0.0100
# Epoch: 15, Training loss: 1.0033, Validation loss: 1.0240, lr: 0.0100 *
# Epoch: 16, Training loss: 1.0007, Validation loss: 1.0251, lr: 0.0100
# Epoch: 17, Training loss: 0.9948, Validation loss: 1.0674, lr: 0.0100
# Epoch: 18, Training loss: 0.9935, Validation loss: 1.0454, lr: 0.0100
# Epoch: 19, Training loss: 0.9950, Validation loss: 1.0387, lr: 0.0100
# Epoch: 20, Training loss: 0.9909, Validation loss: 1.0425, lr: 0.0100
# Epoch: 21, Training loss: 0.9800, Validation loss: 1.0351, lr: 0.0100
# Epoch: 22, Training loss: 0.9948, Validation loss: 1.0307, lr: 0.0100
# Epoch: 23, Training loss: 0.9775, Validation loss: 1.0277, lr: 0.0100
# Epoch: 24, Training loss: 0.9839, Validation loss: 1.0272, lr: 0.0100
# Epoch: 25, Training loss: 0.9898, Validation loss: 1.0408, lr: 0.0100
# Epoch: 26, Training loss: 0.9977, Validation loss: 1.0050, lr: 0.0100 *
# Epoch: 27, Training loss: 0.9862, Validation loss: 1.0350, lr: 0.0100
# Epoch: 28, Training loss: 0.9790, Validation loss: 1.0219, lr: 0.0100
# Epoch: 29, Training loss: 0.9789, Validation loss: 1.0388, lr: 0.0100
# Epoch: 30, Training loss: 0.9822, Validation loss: 1.0310, lr: 0.0100
# Epoch: 31, Training loss: 0.9837, Validation loss: 1.0128, lr: 0.0100
# Epoch: 32, Training loss: 0.9822, Validation loss: 1.0274, lr: 0.0100
# Epoch: 33, Training loss: 0.9783, Validation loss: 1.0531, lr: 0.0100
# Epoch: 34, Training loss: 0.9698, Validation loss: 1.0505, lr: 0.0100
# Epoch: 35, Training loss: 0.9804, Validation loss: 1.0186, lr: 0.0100
# Epoch: 36, Training loss: 0.9840, Validation loss: 1.0305, lr: 0.0100
# Epoch: 37, Training loss: 0.9725, Validation loss: 1.0323, lr: 0.0100
# Epoch: 38, Training loss: 0.9870, Validation loss: 1.0289, lr: 0.0100
# Epoch: 39, Training loss: 0.9775, Validation loss: 1.0238, lr: 0.0100
# Epoch: 40, Training loss: 0.9748, Validation loss: 1.0149, lr: 0.0100
# Final test loss: 1.0225

# %%
data = model.evaluate(data)
n_clusters=40
data = postprocessing(data, n_clusters=n_clusters)

emb_MDS, _ = geometry.embed(data.dist, embed_typ = 'MDS')
labels = 2*[g for i in range(2) for g in gain ]
plotting.embedding(emb_MDS, labels, s=30, alpha=1)
# Out:
# Performed umap embedding on embedded results.
# Performed MDS embedding on embedded results.
# <AxesSubplot:>

# %%
im = plt.imshow(data.dist)
plt.colorbar(im)

# %%
titles = [r'$gain$ = {:0.2f}, {}'.format(g, s) for s in ['stim', 'unstim'] for g in gain ]
labels = np.hstack([gain,gain])
plotting.embedding(data.emb_2d, data.y.numpy(), titles=titles)

# %% [markdown]
# # Create new network by fitting Gaussian mixture to the connectivity space

# %% [markdown]
# Check that the resampled networks still give the same validation losses

# %%
accs2 = []
for _ in range(10):
    net_sampled.resample_basis()
    loss, acc = dms.test_dms(net_sampled, x_val, y_val, mask_val)
    accs2.append(acc)

# %% [markdown]
# Train net network for a few epochs

# %%
train(net_sampled, x_train, y_train, mask_train, 20, lr=1e-6, resample=True, keep_best=True, clip_gradient=1)
