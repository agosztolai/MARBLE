# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from DE_library import simulate_ODE, simulate_phase_portrait
import matplotlib.pyplot as plt

from MARBLE import utils, geometry, net, plotting
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def initial_conditions(n, reps, seed=0):
    X0_range = [geometry.sample_2d(n, [[-3,-3],[3,3]], 'random', seed=seed+i) for i in range(reps)]
        
    return X0_range

def simulate_system(mu, X0, t, eps=1e-10):
    p, v = simulate_phase_portrait('vanderpol', t, X0, par = {'mu': mu})
    pos, vel = [], []
    for p_, v_ in zip(p,v):
        ind = np.where((abs(p_) < 3).all(1))[0]
        p_ = p_[ind,:]; v_ = v_[ind,:]
        ind = np.where((abs(v_) > eps).any(1))[0]
        p_ = p_[ind,:]; v_ = v_[ind,:]
        pos.append(p_)
        vel.append(v_)
        
    return pos, vel

def plot_phase_portrait(pos, vel, ax=None, node_feature=None):
    if not isinstance(pos, list):
        pos = [pos]
    if not isinstance(vel, list):
        vel = [vel]

    for p, v in zip(pos, vel):
        ax = plotting.trajectories(p, v, ax=ax, style='>', node_feature=node_feature, lw=2, arrowhead=.1, axis=False, alpha=1.)
    ax.axis('square')
    
def reject_outliers(data, m=1):
    data = data.mean(1)
    return np.where(abs(data - np.median(data)) < m * np.std(data))[0]

def plot_embedding(emb, ax, slices, i, n_clusters=2):
    s = range(slices[i], slices[i+1])
    clusters = geometry.cluster(emb, cluster_typ='kmeans', n_clusters=n_clusters, seed=0)
    plotting.embedding(emb[s], clusters['labels'][s], ax=ax[0])
    plot_phase_portrait(pos_subsample[i], vel_subsample[i], ax[1], node_feature=clusters['labels'][s])

# %% [markdown]
# # For initial conditions, sample a rectangle uniformly

# %%
t0, t1, dt = 0, 1, 0.2
t = np.arange(t0, t1, dt)
n = 150

# %% [markdown]
# # Geneate phase portraits from random initial conditions while varying $\beta_1$

# %%
n_steps=10
beta1 = np.hstack((np.linspace(-0.5,0.5,n_steps)))

pos, vel = [], []
X0_range = initial_conditions(n, len(beta1), seed=0)
for i, b1 in enumerate(beta1):
    p, v = simulate_system(b1, X0_range[i], t)
            
    pos.append(np.vstack(p))
    vel.append(np.vstack(v))
# Out:
# /mnt/scratch/lts2/gosztolai/miniconda3/envs/MARBLE/lib/python3.9/site-packages/scipy/integrate/_ode.py:1011: UserWarning: zvode: Excess work done on this call. (Perhaps wrong MF.)
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
#  ZVODE--  Warning: internal T (=R1) and H (=R2) are
#        such that in the machine, T + H = T on the next step
#        (H = step size). solver will continue anyway
#       In above,  R1 =  0.5727548390225D+00   R2 =  0.4446988312035D-16
#  ZVODE--  Warning: internal T (=R1) and H (=R2) are
#        such that in the machine, T + H = T on the next step
#        (H = step size). solver will continue anyway
#       In above,  R1 =  0.5727548390225D+00   R2 =  0.4446988312035D-16
#  ZVODE--  Above warning has been issued I1 times.
#        it will not be issued again for this problem
#       In above message,  I1 =         2
#  ZVODE--  Warning: internal T (=R1) and H (=R2) are
#        such that in the machine, T + H = T on the next step
#        (H = step size). solver will continue anyway
#       In above,  R1 =  0.5289228242546D+00   R2 =  0.5497078090857D-16
#  ZVODE--  Warning: internal T (=R1) and H (=R2) are
#        such that in the machine, T + H = T on the next step
#        (H = step size). solver will continue anyway
#       In above,  R1 =  0.5289228242546D+00   R2 =  0.5497078090857D-16
#  ZVODE--  Above warning has been issued I1 times.
#        it will not be issued again for this problem
#       In above message,  I1 =         2
#  ZVODE--  Warning: internal T (=R1) and H (=R2) are
#        such that in the machine, T + H = T on the next step
#        (H = step size). solver will continue anyway
#       In above,  R1 =  0.4814939581255D+00   R2 =  0.2126980302286D-16
#  ZVODE--  Warning: internal T (=R1) and H (=R2) are
#        such that in the machine, T + H = T on the next step
#        (H = step size). solver will continue anyway
#       In above,  R1 =  0.4814939581255D+00   R2 =  0.2126980302286D-16
#  ZVODE--  Above warning has been issued I1 times.
#        it will not be issued again for this problem
#       In above message,  I1 =         2
#  ZVODE--  Warning: internal T (=R1) and H (=R2) are
#        such that in the machine, T + H = T on the next step
#        (H = step size). solver will continue anyway
#       In above,  R1 =  0.5123156697886D+00   R2 =  0.4306254609622D-16
#  ZVODE--  Warning: internal T (=R1) and H (=R2) are
#        such that in the machine, T + H = T on the next step
#        (H = step size). solver will continue anyway
#       In above,  R1 =  0.5123156697886D+00   R2 =  0.4306254609622D-16
#  ZVODE--  Above warning has been issued I1 times.
#        it will not be issued again for this problem
#       In above message,  I1 =         2
#  ZVODE--  Warning: internal T (=R1) and H (=R2) are
#        such that in the machine, T + H = T on the next step
#        (H = step size). solver will continue anyway
#       In above,  R1 =  0.4696799104759D+00   R2 =  0.2055681226002D-16
#  ZVODE--  Warning: internal T (=R1) and H (=R2) are
#        such that in the machine, T + H = T on the next step
#        (H = step size). solver will continue anyway
#       In above,  R1 =  0.4696799104759D+00   R2 =  0.2055681226002D-16
#  ZVODE--  Above warning has been issued I1 times.
#        it will not be issued again for this problem
#       In above message,  I1 =         2
#  ZVODE--  Warning: internal T (=R1) and H (=R2) are
#        such that in the machine, T + H = T on the next step
#        (H = step size). solver will continue anyway
#       In above,  R1 =  0.5407840037596D+00   R2 =  0.4499703071555D-16
#  ZVODE--  Warning: internal T (=R1) and H (=R2) are
#        such that in the machine, T + H = T on the next step
#        (H = step size). solver will continue anyway
#       In above,  R1 =  0.5407840037596D+00   R2 =  0.4499703071555D-16
#  ZVODE--  Above warning has been issued I1 times.
#        it will not be issued again for this problem
#       In above message,  I1 =         2

# %% [markdown]
# # Display state spaces under four different parameter conditions

# %%
fig, ax = plt.subplots(1,4, figsize=(20,5))
    
plot_phase_portrait(pos[0], vel[0], ax[0])
plot_phase_portrait(pos[n_steps//2-1], vel[n_steps//2-1], ax[1])
plot_phase_portrait(pos[n_steps//2+1], vel[n_steps//2+1], ax[2])
plot_phase_portrait(pos[-1], vel[-1], ax[3])

# %% [markdown]
# # Train network

# %%
k=10

data = utils.construct_dataset(pos, features=vel, graph_type='cknn', k=k)

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"

par = {'batch_size': 512, #batch size
       'epochs': 60, #optimisation epochs
       'order': 2, #order of derivatives
       'n_lin_layers': 2,
       'hidden_channels': 16, #number of internal dimensions in MLP
       'out_channels': 3,
       'diffusion': False,
       'inner_product_features': True,
       'pretrained':True,
       'second_training': False
      }

model = net(data, **par)
model.run_training(data)
# Out:
# ---- Settings:
#
# batch_size : 512
# epochs : 60
# order : 2
# n_lin_layers : 2
# hidden_channels : 16
# out_channels : 3
# diffusion : False
# inner_product_features : True
# pretrained : True
# second_training : False
# lr : 0.01
# vector : False
# frac_geodesic_nb : 2.0
# frac_sampled_nb : -1
# var_explained : 0.9
# diffusion_method : spectral
# dropout : 0.0
# bias : True
# vec_norm : False
# batch_norm : None
# seed : 0
# processes : 1
# dim_signal : 2
# dim_emb : 2
# n_geodesic_nb : 20
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  7
# ---- Total number of parameters:  455
# ---- Treating features as scalar channels.
#
# ---- Pretraining encoder ...
#
# Epoch: 1, reconstruction loss: 2.3093
# Epoch: 2, reconstruction loss: 0.6656
# Epoch: 3, reconstruction loss: 0.4548
# Epoch: 4, reconstruction loss: 0.3433
# Epoch: 5, reconstruction loss: 0.2871
# Epoch: 6, reconstruction loss: 0.2612
# Epoch: 7, reconstruction loss: 0.2457
# Epoch: 8, reconstruction loss: 0.2354
# Epoch: 9, reconstruction loss: 0.2292
# Epoch: 10, reconstruction loss: 0.2222
# Epoch: 11, reconstruction loss: 0.2166
# Epoch: 12, reconstruction loss: 0.2137
# Epoch: 13, reconstruction loss: 0.2059
# Epoch: 14, reconstruction loss: 0.2006
# Epoch: 15, reconstruction loss: 0.1983
# Epoch: 16, reconstruction loss: 0.1933
# Epoch: 17, reconstruction loss: 0.1925
# Epoch: 18, reconstruction loss: 0.1904
# Epoch: 19, reconstruction loss: 0.1906
# Epoch: 20, reconstruction loss: 0.1869
# Epoch: 21, reconstruction loss: 0.1877
# Epoch: 22, reconstruction loss: 0.1834
# Epoch: 23, reconstruction loss: 0.1862
# Epoch: 24, reconstruction loss: 0.1862
# Epoch: 25, reconstruction loss: 0.1828
# Epoch: 26, reconstruction loss: 0.1812
# Epoch: 27, reconstruction loss: 0.1790
# Epoch: 28, reconstruction loss: 0.1764
# Epoch: 29, reconstruction loss: 0.1750
# Epoch: 30, reconstruction loss: 0.1750
# Epoch: 31, reconstruction loss: 0.1717
# Epoch: 32, reconstruction loss: 0.1737
# Epoch: 33, reconstruction loss: 0.1696
# Epoch: 34, reconstruction loss: 0.1714
# Epoch: 35, reconstruction loss: 0.1720
# Epoch: 36, reconstruction loss: 0.1710
# Epoch: 37, reconstruction loss: 0.1711
# Epoch: 38, reconstruction loss: 0.1696
# Epoch: 39, reconstruction loss: 0.1646
# Epoch: 40, reconstruction loss: 0.1658
# Epoch: 41, reconstruction loss: 0.1622
# Epoch: 42, reconstruction loss: 0.1604
# Epoch: 43, reconstruction loss: 0.1589
# Epoch: 44, reconstruction loss: 0.1605
# Epoch: 45, reconstruction loss: 0.1588
# Epoch: 46, reconstruction loss: 0.1586
# Epoch: 47, reconstruction loss: 0.1571
# Epoch: 48, reconstruction loss: 0.1545
# Epoch: 49, reconstruction loss: 0.1552
# Epoch: 50, reconstruction loss: 0.1538
# Epoch: 51, reconstruction loss: 0.1512
# Epoch: 52, reconstruction loss: 0.1523
# Epoch: 53, reconstruction loss: 0.1509
# Epoch: 54, reconstruction loss: 0.1485
# Epoch: 55, reconstruction loss: 0.1471
# Epoch: 56, reconstruction loss: 0.1486
# Epoch: 57, reconstruction loss: 0.1513
# Epoch: 58, reconstruction loss: 0.1483
# Epoch: 59, reconstruction loss: 0.1482
# Epoch: 60, reconstruction loss: 0.1495

# %% [markdown]
# # Create another dataset from a different sampling

# %%
t0, t1, dt = 0, 1, 0.2
t = np.arange(t0, t1, dt)
n = 100

n_steps=10
beta1 = np.hstack((np.linspace(-0.5, 0.5, n_steps)))

pos, vel = [], []
X0_range = initial_conditions(n, len(beta1), seed=10) #change seed
for i, b1 in enumerate(beta1):
    p, v = simulate_system(b1, X0_range[i], t)
            
    pos.append(np.vstack(p))
    vel.append(np.vstack(v))
    
data_transfer = utils.construct_dataset(pos, features=vel, graph_type='cknn', k=k)

# %% [markdown]
# # Evalute network on both data

# %%
data = model.evaluate(data) #original data
data_transfer = model.evaluate(data_transfer) #resampled data

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))

dist, gamma = geometry.compute_distribution_distances(data)
emb_MDS, _ = geometry.embed(dist, embed_typ = 'MDS')
plotting.embedding(emb_MDS, beta1, ax=ax[0], s=30, alpha=1)

dist_transfer, gamma_transfer = geometry.compute_distribution_distances(data_transfer)
emb_MDS_transfer, _ = geometry.embed(dist_transfer, embed_typ = 'MDS')
plotting.embedding(emb_MDS_transfer, beta1, ax=ax[1], s=30, alpha=1)
# Out:
# Performed MDS embedding on embedded results.
# Performed MDS embedding on embedded results.
# <AxesSubplot:>

# %% [markdown]
# # Compare distance matrices

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))
ax[0].imshow(dist)
ax[1].imshow(dist_transfer)

# %% [markdown]
# # Compare embeddings

# %%
emb, manifold, _, dist, gamma = geometry.cluster_embedding(data, embed_typ='umap', n_clusters=30)
emb_transfer, manifold, _, dist, gamma_transfer = geometry.cluster_embedding(data_transfer, embed_typ='umap', manifold=manifold, n_clusters=30)

titles = ['Original data', 'Transferred data']
plotting.embedding(np.vstack([emb, emb_transfer]), 
                   np.hstack([np.zeros(len(emb)),np.ones(len(emb_transfer))]), 
                   titles=titles)
# Out:
# Performed umap embedding on embedded results.
# Performed umap embedding on embedded results.
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))

ax[0].imshow(gamma[3,5])
ax[1].imshow(gamma_transfer[3,5])
