# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from DE_library import simulate_ODE, simulate_phase_portrait
import matplotlib.pyplot as plt
from example_utils import reject_outliers, initial_conditions, plot_phase_portrait

from MARBLE import utils, geometry, net, plotting, postprocessing, compare_attractors

# %%
def simulate_system(mu, X0):
    p, v = simulate_phase_portrait('vanderpol', t, X0, par = {'mu': mu})
    pos, vel = [], []
    for p_, v_ in zip(p,v):
        ind = reject_outliers(p_, v_)
        pos.append(p_[ind])
        vel.append(v_[ind])
        
    return pos, vel

# %% [markdown]
# # Geneate phase portraits from random initial conditions while varying $\beta_1$

# %%
t0, t1, dt = 0, 3, 0.5
t = np.arange(t0, t1, dt)
n = 100
area = [[-3,-3],[3,3]]
n_steps=10
beta1 = np.hstack((np.linspace(-.5,.5,n_steps)))

pos, vel = [], []
X0_range = initial_conditions(n, len(beta1), area)
for i, b1 in enumerate(beta1):
    p, v = simulate_system(b1, X0_range[i])
            
    pos.append(np.vstack(p))
    vel.append(np.vstack(v))
# Out:
# /mnt/scratch/lts2/gosztolai/miniconda3/envs/MARBLE/lib/python3.9/site-packages/scipy/integrate/_odepack_py.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)

# %% [markdown]
# # Display state spaces under four different parameter conditions

# %%
fig, ax = plt.subplots(1,4, figsize=(20,5))
    
plot_phase_portrait(pos[0], vel[0], ax[0])
plot_phase_portrait(pos[n_steps//2-1], vel[n_steps//2-1], ax[1])
plot_phase_portrait(pos[n_steps//2+1], vel[n_steps//2+1], ax[2])
plot_phase_portrait(pos[-1], vel[-1], ax[3])

# %% [markdown]
# # Train network

# %%
k=10

data = utils.construct_dataset(pos, features=vel, graph_type='cknn', k=k, stop_crit=0.02)

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="2"

par = {'batch_size': 64, #batch size
       'epochs': 60, #optimisation epochs
       'order': 2, #order of derivatives
       'n_lin_layers': 2,
       'hidden_channels': 16, #number of internal dimensions in MLP
       'out_channels': 3,
       'inner_product_features': True,
      }

model = net(data, **par)
model.run_training(data)
# Out:
# ---- Settings:
#
# batch_size : 64
# epochs : 60
# order : 2
# n_lin_layers : 2
# hidden_channels : 16
# out_channels : 3
# inner_product_features : True
# lr : 0.001
# autoencoder : False
# vector : False
# diffusion : None
# frac_geodesic_nb : 2.0
# frac_sampled_nb : -1
# var_explained : 0.9
# dropout : 0.0
# bias : True
# vec_norm : False
# batch_norm : None
# seed : 0
# processes : 1
# dim_signal : 2
# dim_emb : 2
# n_geodesic_nb : 20
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  7
# ---- Total number of parameters:  209
# ---- Treating features as scalar channels.
#
# ---- Training network ...
#
# Epoch: 1, Training loss: 1.3817, Validation loss: 1.3763
# Epoch: 2, Training loss: 1.3662, Validation loss: 1.3454
# Epoch: 3, Training loss: 1.3158, Validation loss: 1.2866
# Epoch: 4, Training loss: 1.2422, Validation loss: 1.2210
# Epoch: 5, Training loss: 1.1805, Validation loss: 1.1353
# Epoch: 6, Training loss: 1.1351, Validation loss: 1.1775
# Epoch: 7, Training loss: 1.1307, Validation loss: 1.1358
# Epoch: 8, Training loss: 1.1168, Validation loss: 1.1662
# Epoch: 9, Training loss: 1.1154, Validation loss: 1.1436
# Epoch: 10, Training loss: 1.1311, Validation loss: 1.0923
# Epoch: 11, Training loss: 1.1202, Validation loss: 1.1168
# Epoch: 12, Training loss: 1.1159, Validation loss: 1.1148
# Epoch: 13, Training loss: 1.1000, Validation loss: 1.1468
# Epoch: 14, Training loss: 1.1068, Validation loss: 1.0812
# Epoch: 15, Training loss: 1.1186, Validation loss: 1.0607
# Epoch: 16, Training loss: 1.1059, Validation loss: 1.1532
# Epoch: 17, Training loss: 1.1065, Validation loss: 1.0821
# Epoch: 18, Training loss: 1.1159, Validation loss: 1.1399
# Epoch: 19, Training loss: 1.0969, Validation loss: 1.1357
# Epoch: 20, Training loss: 1.1121, Validation loss: 1.0782
# Epoch: 21, Training loss: 1.1130, Validation loss: 1.1078
# Epoch: 22, Training loss: 1.0994, Validation loss: 1.0763
# Epoch: 23, Training loss: 1.1019, Validation loss: 1.1682
# Epoch: 24, Training loss: 1.1047, Validation loss: 1.0905
# Epoch: 25, Training loss: 1.0794, Validation loss: 1.0939
# Epoch: 26, Training loss: 1.1084, Validation loss: 1.0944
# Epoch: 27, Training loss: 1.1051, Validation loss: 1.1116
# Epoch: 28, Training loss: 1.1108, Validation loss: 1.1678
# Epoch: 29, Training loss: 1.0955, Validation loss: 1.1193
# Epoch: 30, Training loss: 1.0786, Validation loss: 1.0241
# Epoch: 31, Training loss: 1.0850, Validation loss: 1.0974
# Epoch: 32, Training loss: 1.0945, Validation loss: 1.1298
# Epoch: 33, Training loss: 1.0918, Validation loss: 1.1390
# Epoch: 34, Training loss: 1.0869, Validation loss: 1.1290
# Epoch: 35, Training loss: 1.1157, Validation loss: 1.1366
# Epoch: 36, Training loss: 1.0992, Validation loss: 1.0816
# Epoch: 37, Training loss: 1.0671, Validation loss: 1.1474
# Epoch: 38, Training loss: 1.0989, Validation loss: 1.0208
# Epoch: 39, Training loss: 1.1051, Validation loss: 1.0868
# Epoch: 40, Training loss: 1.0903, Validation loss: 1.0496
# Epoch: 41, Training loss: 1.0916, Validation loss: 1.0670
# Epoch: 42, Training loss: 1.0800, Validation loss: 1.0986
# Epoch: 43, Training loss: 1.1191, Validation loss: 1.0936
# Epoch: 44, Training loss: 1.1098, Validation loss: 1.1600
# Epoch: 45, Training loss: 1.1020, Validation loss: 1.0858
# Epoch: 46, Training loss: 1.0739, Validation loss: 1.0531
# Epoch: 47, Training loss: 1.0933, Validation loss: 1.1117
# Epoch: 48, Training loss: 1.0925, Validation loss: 1.0486
# Epoch: 49, Training loss: 1.0782, Validation loss: 1.1123
# Epoch: 50, Training loss: 1.0786, Validation loss: 1.0592
# Epoch: 51, Training loss: 1.0873, Validation loss: 1.0999
# Epoch: 52, Training loss: 1.0961, Validation loss: 1.1454
# Epoch: 53, Training loss: 1.0926, Validation loss: 1.0919
# Epoch: 54, Training loss: 1.0742, Validation loss: 1.0727
# Epoch: 55, Training loss: 1.0752, Validation loss: 1.1086
# Epoch: 56, Training loss: 1.1026, Validation loss: 1.0507
# Epoch: 57, Training loss: 1.0878, Validation loss: 1.1866
# Epoch: 58, Training loss: 1.0739, Validation loss: 1.0688
# Epoch: 59, Training loss: 1.0788, Validation loss: 1.0730
# Epoch: 60, Training loss: 1.1023, Validation loss: 1.0774
# Final test loss: 1.0868

# %% [markdown]
# # Create another dataset from a different sampling

# %%
t0, t1, dt = 0, 3, 0.5
t = np.arange(t0, t1, dt)
n = 100
area = [[-3,-3],[3,3]]

n_steps=10
beta1 = np.hstack((np.linspace(-0.5, 0.5, n_steps)))

pos, vel = [], []
X0_range = initial_conditions(n, len(beta1), area)
for i, b1 in enumerate(beta1):
    p, v = simulate_system(b1, X0_range[i])
            
    pos.append(np.vstack(p))
    vel.append(np.vstack(v))
    
data_transfer = utils.construct_dataset(pos, features=vel, graph_type='cknn', k=k, stop_crit=0.0)
# Out:
# /mnt/scratch/lts2/gosztolai/miniconda3/envs/MARBLE/lib/python3.9/site-packages/scipy/integrate/_odepack_py.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)

# %% [markdown]
# # Evalute network on both data

# %%
data = model.evaluate(data) #original data
data_transfer = model.evaluate(data_transfer) #resampled data
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_3021581/2961459133.py in <module>
# ----> 1 data = model.evaluate(data) #original data
#       2 data_transfer = model.evaluate(data_transfer) #resampled data
#
# /mnt/scratch/lts2/gosztolai/MARBLE/MARBLE/main.py in evaluate(self, data)
#      94             #move to gpu
#      95             device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# ---> 96             adjs = [adj.to(device) for adj in adjs]
#      97             x = data.x.to(device)
#      98
#
# /mnt/scratch/lts2/gosztolai/MARBLE/MARBLE/main.py in <listcomp>(.0)
#      94             #move to gpu
#      95             device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# ---> 96             adjs = [adj.to(device) for adj in adjs]
#      97             x = data.x.to(device)
#      98
#
# /mnt/scratch/lts2/gosztolai/MARBLE/MARBLE/lib/utils.py in to(self, *args, **kwargs)
#     249
#     250     def to(self, *args, **kwargs):
# --> 251         edge_index = self.edge_index.to(*args, **kwargs)
#     252         e_id = self.e_id.to(*args, **kwargs) if self.e_id is not None else None
#     253         return EdgeIndex(edge_index, e_id, self.size)
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call,so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))

n_clusters=30
data = postprocessing(data, n_clusters=n_clusters)
emb_MDS, _ = geometry.embed(data.dist, embed_typ = 'MDS')
plotting.embedding(emb_MDS, beta1, ax=ax[0], s=30, alpha=1)

data_transfer = postprocessing(data_transfer, n_clusters=n_clusters)
emb_MDS_transfer, _ = geometry.embed(data_transfer.dist, embed_typ = 'MDS')
plotting.embedding(emb_MDS_transfer, beta1, ax=ax[1], s=30, alpha=1)

# %% [markdown]
# # Compare distance matrices

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))
ax[0].imshow(data.dist)
ax[1].imshow(data_transfer.dist)

# %% [markdown]
# # Compare embeddings

# %%
titles = ['Original data', 'Transferred data']
plotting.embedding(np.vstack([data.emb_2d, data_transfer.emb_2d]), 
                   np.hstack([np.zeros(len(data.emb_2d)),np.ones(len(data_transfer.emb_2d))]), 
                   titles=titles)

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))

ax[0].imshow(data.gamma[3,5])
ax[1].imshow(data_transfer.gamma[3,5])
