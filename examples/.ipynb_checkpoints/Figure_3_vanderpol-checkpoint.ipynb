# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from DE_library import simulate_ODE, simulate_trajectories
import matplotlib.pyplot as plt
from example_utils import reject_outliers, initial_conditions, plot_phase_portrait

from MARBLE import utils, geometry, net, plotting, postprocessing, compare_attractors

# %%
def simulate_system(mu, X0, t):
    p, v = simulate_trajectories('vanderpol', X0, t, par = {'mu': mu})
    pos, vel = [], []
    for p_, v_ in zip(p,v):
        ind = reject_outliers(p_, v_)
        pos.append(p_[ind])
        vel.append(v_[ind])
        
    return pos, vel

def parabola(X, Y, alpha=0.05):
    Z = -(alpha*X)**2 -(alpha*Y)**2
    
    return np.column_stack([X.flatten(), Y.flatten(), Z.flatten()])

# %% [markdown]
# # For initial conditions, sample a rectangle uniformly

# %%
t0, t1, dt = 0, 3, 0.5
t = np.arange(t0, t1, dt)
n = 100
area = [[-3,-3],[3,3]]

# %% [markdown]
# # Geneate phase portraits from random initial conditions while varying $\beta_1$

# %%
n_steps=20
beta1 = np.hstack((np.linspace(-.5,.5,n_steps)))

pos, vel = [], []
X0_range = initial_conditions(n, len(beta1), area)
for i, b1 in enumerate(beta1):
    p, v = simulate_system(b1, X0_range[i], t)
            
    pos.append(np.vstack(p))
    vel.append(np.vstack(v))
    
#embed on parabola
for i, (p, v) in enumerate(zip(pos, vel)):
    end_point = p + v
    new_endpoint = parabola(end_point[:,0], end_point[:,1])
    pos[i] = parabola(p[:,0], p[:,1])
    vel[i] = new_endpoint - pos[i]
# Out:
# /mnt/scratch/lts2/gosztolai/miniconda3/envs/MARBLE/lib/python3.9/site-packages/scipy/integrate/_odepack_py.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)

# %% [markdown]
# # Plot vector fields

# %%
k=15

data = utils.construct_dataset(pos, features=vel, graph_type='cknn', k=k, stop_crit=0.03, vector=False)
# Out:
# ---- Embedding dimension: 3
# ---- Signal dimension: 3
#
#
# Vector computations are disabled

# %%
titles = [r'$\beta$ = {:0.2f}'.format(b) for b in beta1]

#plotting.fields(data, col=4, alpha=0.3, scale=10)
axes = plotting.fields(data, col=4, alpha=1, width=7, scale=2, titles=titles, view=[70,20])

from matplotlib.colors import LightSource

x = y = np.arange(-3.0, 3.0, 0.05)
X, Y = np.meshgrid(x, y)
xyz = np.array(parabola(np.ravel(X), np.ravel(Y)))
ls = LightSource(azdeg=30,altdeg=30)
rgb = ls.shade(xyz[:,2].reshape(X.shape)-0.1, plt.cm.gray)

for ax in axes:
    ax.plot_surface(xyz[:,0].reshape(X.shape), xyz[:,1].reshape(X.shape), xyz[:,2].reshape(X.shape)-0.02, 
                color='gray', 
                shade=True,
                lightsource=ls,
                facecolors=rgb
               )
#plt.savefig('./outputs/parabolas.svg')

# %% [markdown]
# # Train network

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="4"

par = {'epochs': 75, #optimisation epochs
       'order': 2, #order of derivatives
       'hidden_channels': 32, #number of internal dimensions in MLP
       'out_channels': 4,
       'inner_product_features': True,
      }

model = net(data, **par)
model.run_training(data)
# Out:
# ---- Settings:
#
# epochs : 75
# order : 2
# hidden_channels : 32
# out_channels : 4
# inner_product_features : True
# batch_size : 64
# lr : 0.01
# momentum : 0.9
# autoencoder : False
# diffusion : False
# frac_sampled_nb : -1
# dropout : 0.0
# n_lin_layers : 2
# bias : True
# vec_norm : False
# batch_norm : None
# seed : 0
# processes : 1
# dim_signal : 3
# dim_emb : 3
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  13
# ---- Total number of parameters:  698
#
# ---- Training network ...
#
# Epoch: 1, Training loss: 1.3747, Validation loss: 1.3703, lr: 0.0100 *
# Epoch: 43, Training loss: 1.0402, Validation loss: 1.1064, lr: 0.0100
# Epoch: 44, Training loss: 1.0576, Validation loss: 1.0519, lr: 0.0100
# Epoch: 45, Training loss: 1.0222, Validation loss: 1.0500, lr: 0.0100
# Epoch: 46, Training loss: 1.0405, Validation loss: 1.0177, lr: 0.0100
# Epoch: 47, Training loss: 1.0407, Validation loss: 1.0470, lr: 0.0100
# Epoch: 48, Training loss: 1.0405, Validation loss: 1.0098, lr: 0.0100 *
# Epoch: 49, Training loss: 1.0264, Validation loss: 1.0689, lr: 0.0100
# Epoch: 50, Training loss: 1.0373, Validation loss: 1.0625, lr: 0.0100
# Epoch: 51, Training loss: 1.0444, Validation loss: 1.0645, lr: 0.0100
# Epoch: 52, Training loss: 1.0005, Validation loss: 1.0288, lr: 0.0100
# Epoch: 53, Training loss: 1.0464, Validation loss: 0.9826, lr: 0.0100 *
# Epoch: 54, Training loss: 1.0275, Validation loss: 1.0942, lr: 0.0100
# Epoch: 55, Training loss: 1.0307, Validation loss: 1.0431, lr: 0.0100
# Epoch: 56, Training loss: 1.0326, Validation loss: 1.0855, lr: 0.0100
# Epoch: 57, Training loss: 1.0305, Validation loss: 1.0757, lr: 0.0100
# Epoch: 58, Training loss: 1.0380, Validation loss: 1.0649, lr: 0.0100
# Epoch: 59, Training loss: 1.0246, Validation loss: 1.0385, lr: 0.0100
# Epoch: 60, Training loss: 1.0326, Validation loss: 1.0969, lr: 0.0100
# Epoch: 61, Training loss: 1.0238, Validation loss: 1.0277, lr: 0.0100
# Epoch: 62, Training loss: 1.0220, Validation loss: 1.0143, lr: 0.0100
# Epoch: 63, Training loss: 1.0283, Validation loss: 1.0121, lr: 0.0010
# Epoch: 64, Training loss: 1.0279, Validation loss: 1.0026, lr: 0.0010
# Epoch: 65, Training loss: 1.0102, Validation loss: 1.0136, lr: 0.0010
# Epoch: 66, Training loss: 1.0318, Validation loss: 1.0426, lr: 0.0010
# Epoch: 67, Training loss: 1.0038, Validation loss: 1.0479, lr: 0.0010
# Epoch: 68, Training loss: 1.0122, Validation loss: 1.0191, lr: 0.0010
# Epoch: 69, Training loss: 1.0096, Validation loss: 1.0648, lr: 0.0010
# Epoch: 70, Training loss: 1.0346, Validation loss: 1.0314, lr: 0.0010
# Epoch: 71, Training loss: 1.0323, Validation loss: 1.0534, lr: 0.0010
# Epoch: 72, Training loss: 1.0049, Validation loss: 1.0651, lr: 0.0010
# Epoch: 73, Training loss: 1.0260, Validation loss: 1.0280, lr: 0.0010
# Epoch: 74, Training loss: 1.0236, Validation loss: 1.0763, lr: 0.0001
# Epoch: 75, Training loss: 1.0198, Validation loss: 1.0121, lr: 0.0001
# Final test loss: 1.0070

# %% [markdown]
# # Create embeddings

# %%
data = model.evaluate(data)
n_clusters=40
data = postprocessing(data, n_clusters=n_clusters)

emb_MDS, _ = geometry.embed(data.dist, embed_typ = 'MDS')
plotting.embedding(emb_MDS, beta1, s=30, alpha=1)
plt.savefig('../results/van_der_pol_MDS.svg')
# Out:
# Performed umap embedding on embedded results.
# Performed MDS embedding on embedded results.

# %% [markdown]
# # Distance matrix

# %%
im = plt.imshow(data.dist)
plt.colorbar(im)
plt.savefig('../results/van_der_pol_D.svg')

# %% [markdown]
# # Cluster and visualise embedding

# %%
titles = [r'$\beta$ = {:0.2f}'.format(b) for b in beta1]
plotting.embedding(data, beta1[data.y.numpy()], titles=titles)
plt.savefig('../results/van_der_pol_embedding.svg')
