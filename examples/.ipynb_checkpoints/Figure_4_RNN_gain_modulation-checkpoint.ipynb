# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("./RNN_scripts")
import torch
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from RNN_scripts import dms, ranktwo, clustering
from RNN_scripts.modules import LowRankRNN, train
import seaborn as sns
import pickle

import MARBLE
from MARBLE import utils, geometry, plotting, postprocessing, compare_attractors
from sklearn.decomposition import PCA

# %%
matplotlib.rcParams['figure.figsize'] = (6, 5)
matplotlib.rcParams['font.size'] = 10
matplotlib.rcParams['font.family'] = 'sans-serif'
matplotlib.rcParams['axes.titlesize'] = 'medium'
matplotlib.rcParams['xtick.labelsize'] = 10
matplotlib.rcParams['ytick.labelsize'] = 10
matplotlib.rcParams['axes.spines.right'] = False
matplotlib.rcParams['axes.spines.top'] = False

# %% [markdown]
# # Load trained model

# %%
hidden_size = 500
noise_std = 5e-2
alpha = 0.2
x_train, y_train, mask_train, x_val, y_val, mask_val = dms.generate_dms_data(1000)
net =  LowRankRNN(2, hidden_size, 1, noise_std, alpha, rank=2)
net.load_state_dict(torch.load(f'./RNN_scripts/dms_rank2_{hidden_size}.pt', map_location='cpu'))
net.svd_reparametrization()

# %%
loss_orig, acc_orig = dms.test_dms(net, x_val, y_val, mask_val)
print(acc_orig)
print(loss_orig)
# Out:
# 1.0
# 0.01481472235172987

# %% [markdown]
# # Visualising two network populations

# %%
n_pops = 2
z, _ = clustering.gmm_fit(net, n_pops, algo='bayes', random_state=2020)  # z will contain labels for the 2 populations

# %%
# Visualizing those 2 populations
m = net.m[:,0].detach().numpy()
n = net.n[:,0].detach().numpy() 
wi1 = net.wi[0].detach().numpy()
wi2 = net.wi[1].detach().numpy()

fig, ax = plt.subplots(2, 1, figsize=(4, 12))
colors = ['rebeccapurple', 'seagreen']
fs = 12
clustering.pop_scatter_linreg(n, wi1, z, n_pops, colors=colors, ax=ax[0])
clustering.pop_scatter_linreg(n, wi2, z, n_pops, colors=colors, ax=ax[1])
# Out:
# pop 0: slope=-0.01, intercept=-0.04
# pop 1: slope=-0.03, intercept=0.06
# pop 0: slope=-0.01, intercept=0.02
# pop 1: slope=-0.02, intercept=-0.20

# %% [markdown]
# # Create new network by fitting Gaussian mixture to the connectivity space

# %%
net3 = clustering.to_support_net(net, z, scaling=True)

# %% [markdown]
# Check that the resampled networks still give the same validation losses

# %%
accs2 = []
for _ in range(10):
    net3.resample_basis()
    loss, acc = dms.test_dms(net3, x_val, y_val, mask_val)
    accs2.append(acc)

# %% [markdown]
# Train net network for a few epochs

# %%
train(net3, x_train, y_train, mask_train, 20, lr=1e-6, resample=True, keep_best=True, clip_gradient=1)

# %% [markdown]
# # Plot phase portraits of the original system for various parameters

# %%
stim1_begin, stim1_end, stim2_begin, stim2_end, decision = 25, 50, 200, 225, 275
epochs = [0, stim1_begin, stim1_end, stim2_begin, stim2_end, decision]
gain = [1.0, 0.75, 0.5, 0.0]

input = torch.zeros(4, decision, 2)
input[0, stim1_begin:stim1_end, 0] = gain[0]
input[0, stim2_begin:stim2_end, 0] = gain[0]
input[1, stim1_begin:stim1_end, 0] = gain[1]
input[1, stim2_begin:stim2_end, 0] = gain[1]
input[2, stim1_begin:stim1_end, 0] = gain[2]
input[2, stim2_begin:stim2_end, 0] = gain[2]
input[3, stim1_begin:stim1_end, 0] = gain[3]
input[3, stim2_begin:stim2_end, 0] = gain[3]

# %%
n_traj=30

fig, ax = plt.subplots(4, 5, figsize=(25, 20))
traj = []
for i in range(4):
    
    conds = []
    for k in range(n_traj):
        #net.h0.data = torch.rand(size=net.h0.data.shape) #random ic
        _, traj_ = net(input[i].unsqueeze(0))
        traj_ = traj_.squeeze().detach().numpy()
        traj_epoch = [traj_[e:epochs[j+1]] for j, e in enumerate(epochs[:-1])]
        conds.append(traj_epoch)
        
    traj.append(conds)
    
    for j, e in enumerate(epochs[:-1]):
        dms.plot_field(net, input[i, e], ax[i][j], sizes=1.3)
        epoch = [c[j] for c in conds]
        dms.plot_trajectories(net, epoch, ax[i][j], c='C{}'.format(j), n_traj=len(epoch))
        #if j>0:
        #    epoch = [c[j-1] for c in conds]
        #    dms.plot_trajectories(net, epoch, ax[i][j], c='C0', n_traj=len(epoch))

ax[0][0].set_title('Fix')
ax[0][1].set_title('Stim 1')
ax[0][2].set_title('Delay')
ax[0][3].set_title('Stim 2')
ax[0][4].set_title('Decision')

for i in range(4):
    ax[i][0].set_ylabel('$\kappa_2$')
for i in range(5):
    ax[3][i].set_xlabel('$\kappa_1$')
    
fig.subplots_adjust(hspace=.1, wspace=.1)
# plt.savefig('figures/si_dms_epochs.pdf')

# %% [markdown]
# # Plot phase portraits of the resampled system for various parameters

# %%
n_traj=2

fig, ax = plt.subplots(4, 5, figsize=(25, 20))
traj = []
for i in range(4):
    
    conds = []
    for k in range(n_traj):
        #net.h0.data = torch.rand(size=net.h0.data.shape) #random ic
        _, traj_ = net3(input[i].unsqueeze(0))
        traj_ = traj_.squeeze().detach().numpy()
        traj_epoch = [traj_[e:epochs[j+1]] for j, e in enumerate(epochs[:-1])]
        conds.append(traj_epoch)
        
    traj.append(conds)
    
    for j, e in enumerate(epochs[:-1]):
        dms.plot_field(net3, input[i, e], ax[i][j], sizes=1.3)
        epoch = [c[j] for c in conds]
        dms.plot_trajectories(net3, epoch, ax[i][j], c='C1', n_traj=len(epoch))
        if j>0:
            epoch = [c[j-1] for c in conds]
            dms.plot_trajectories(net3, epoch, ax[i][j], c='C0', n_traj=len(epoch))

ax[0][0].set_title('Fix')
ax[0][1].set_title('Stim 1')
ax[0][2].set_title('Delay')
ax[0][3].set_title('Stim 2')
ax[0][4].set_title('Decision')

for i in range(4):
    ax[i][0].set_ylabel('$\kappa_2$')
for i in range(5):
    ax[3][i].set_xlabel('$\kappa_1$')
    
fig.subplots_adjust(hspace=.1, wspace=.1)

# %%
pickle.dump(traj, open('./outputs/RNN_data.pkl','wb'))

# %% [markdown]
# # Concatenate data and create dataset

# %%
pca_dim = 2
transient = 0 #timesteps to exclude due to transient

n_conds = len(gain)
n_epochs = len(epochs)-1

#fit PCA to all data
pos, vel = [], []
for i in range(n_conds): #conditions
    for k in range(n_epochs): 
        for j in range(n_traj): #trajectories
            pos.append(traj[i][j][k])
            
manifold = PCA(n_components=pca_dim).fit(np.vstack(pos))

pos, vel = [], []
for i in range(n_conds): #conditions
    
    m1 = net.m[:,0].detach().numpy()
    m2 = net.m[:,1].detach().numpy()
    
    #aggregate data under baseline condition (no input)
    pos_, vel_ = [], []
    for k in [0, 2, 4]:
        for j in range(n_traj): #trajectories
            #pos_proj = manifold.transform(traj[i][j][k][transient:])
            pos_proj1 = traj[i][j][k][transient:]@m1
            pos_proj2 = traj[i][j][k][transient:]@m2
            pos_proj = np.stack([pos_proj1, pos_proj2], axis=1)
            pos_.append(pos_proj[:-1]) #stack trajectories
            vel_.append(np.diff(pos_proj, axis=0)) #compute differences
                        
    pos_, vel_ = np.vstack(pos_), np.vstack(vel_) #stack trajectories
    pos.append(pos_)
    vel.append(vel_)
    
for i in range(n_conds): #conditions 
        
    #aggregate data under stimulated condition
    pos_, vel_ = [], []
    for k in [1, 3]:        
        for j in range(n_traj): #trajectories
            #pos_proj = manifold.transform(traj[i][j][k][transient:])
            pos_proj1 = traj[i][j][k][transient:]@m1
            pos_proj2 = traj[i][j][k][transient:]@m2
            pos_proj = np.stack([pos_proj1, pos_proj2], axis=1)
            pos_.append(pos_proj[:-1])
            vel_.append(np.diff(pos_proj, axis=0))
                
    pos_, vel_ = np.vstack(pos_), np.vstack(vel_) #stack trajectories
    pos.append(pos_)
    vel.append(vel_)

# %%
n_neighb = 10
data = utils.construct_dataset(pos, features=vel, graph_type='cknn', k=n_neighb, stop_crit=0.02)
# Out:
# ---- Embedding dimension: 2
# ---- Signal dimension: 2
#
# Embedding dimension <= 2, so manifold computations are disabled!

# %%
titles = [r'$gain$ = {:0.2f}, {}'.format(g, s) for s in ['stim', 'unstim'] for g in gain ]

plotting.fields(data, col=4, alpha=0.2, width=0.005, scale=300, titles=titles)
plt.show()

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="2"

par = {'epochs': 100, #optimisation epochs
       'order': 2, #order of derivatives
       'hidden_channels': 16, #number of internal dimensions in MLP
       'out_channels': 3,
       'inner_product_features': True,
      }

model = MARBLE.net(data, **par)
model.run_training(data)
# Out:
# ---- Settings:
#
# epochs : 100
# order : 2
# hidden_channels : 16
# out_channels : 3
# inner_product_features : True
# batch_size : 64
# lr : 0.01
# momentum : 0.9
# autoencoder : False
# diffusion : False
# frac_sampled_nb : -1
# dropout : 0.0
# n_lin_layers : 2
# bias : True
# vec_norm : False
# batch_norm : None
# seed : 0
# processes : 1
# dim_signal : 2
# dim_emb : 2
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  7
# ---- Total number of parameters:  209
#
# ---- Training network ...
#
# Epoch: 1, Training loss: 1.3746, Validation loss: 1.3561, lr: 0.0100 *
# Epoch: 2, Training loss: 1.3435, Validation loss: 1.3066, lr: 0.0100 *
# Epoch: 3, Training loss: 1.3131, Validation loss: 1.2744, lr: 0.0100 *
# Epoch: 4, Training loss: 1.2783, Validation loss: 1.2040, lr: 0.0100 *
# Epoch: 5, Training loss: 1.2460, Validation loss: 1.2641, lr: 0.0100
# Epoch: 6, Training loss: 1.2421, Validation loss: 1.2713, lr: 0.0100
# Epoch: 7, Training loss: 1.2256, Validation loss: 1.2162, lr: 0.0100
# Epoch: 8, Training loss: 1.1977, Validation loss: 1.2323, lr: 0.0100
# Epoch: 9, Training loss: 1.1892, Validation loss: 1.1998, lr: 0.0100 *
# Epoch: 10, Training loss: 1.1907, Validation loss: 1.2569, lr: 0.0100
# Epoch: 11, Training loss: 1.1991, Validation loss: 1.2677, lr: 0.0100
# Epoch: 12, Training loss: 1.1818, Validation loss: 1.2085, lr: 0.0100
# Epoch: 13, Training loss: 1.1972, Validation loss: 1.1859, lr: 0.0100 *
# Epoch: 14, Training loss: 1.1872, Validation loss: 1.2224, lr: 0.0100
# Epoch: 15, Training loss: 1.1805, Validation loss: 1.2079, lr: 0.0100
# Epoch: 16, Training loss: 1.2065, Validation loss: 1.2258, lr: 0.0100
# Epoch: 17, Training loss: 1.1907, Validation loss: 1.1933, lr: 0.0100
# Epoch: 18, Training loss: 1.1836, Validation loss: 1.1597, lr: 0.0100 *
# Epoch: 19, Training loss: 1.1834, Validation loss: 1.2426, lr: 0.0100
# Epoch: 20, Training loss: 1.1588, Validation loss: 1.1515, lr: 0.0100 *
# Epoch: 21, Training loss: 1.1609, Validation loss: 1.1995, lr: 0.0100
# Epoch: 22, Training loss: 1.2144, Validation loss: 1.1666, lr: 0.0100
# Epoch: 23, Training loss: 1.1942, Validation loss: 1.1922, lr: 0.0100
# Epoch: 24, Training loss: 1.1961, Validation loss: 1.2996, lr: 0.0100
# Epoch: 25, Training loss: 1.1599, Validation loss: 1.1385, lr: 0.0100 *
# Epoch: 26, Training loss: 1.1671, Validation loss: 1.1751, lr: 0.0100
# Epoch: 27, Training loss: 1.1519, Validation loss: 1.2613, lr: 0.0100
# Epoch: 28, Training loss: 1.1806, Validation loss: 1.2002, lr: 0.0100
# Epoch: 29, Training loss: 1.1499, Validation loss: 1.2061, lr: 0.0100
# Epoch: 30, Training loss: 1.1952, Validation loss: 1.2176, lr: 0.0100
# Epoch: 31, Training loss: 1.2028, Validation loss: 1.1510, lr: 0.0100
# Epoch: 32, Training loss: 1.1855, Validation loss: 1.1894, lr: 0.0100
# Epoch: 33, Training loss: 1.1799, Validation loss: 1.1811, lr: 0.0100
# Epoch: 34, Training loss: 1.1678, Validation loss: 1.1855, lr: 0.0100
# Epoch: 35, Training loss: 1.1566, Validation loss: 1.1379, lr: 0.0100 *
# Epoch: 36, Training loss: 1.1823, Validation loss: 1.1646, lr: 0.0100
# Epoch: 37, Training loss: 1.1768, Validation loss: 1.2286, lr: 0.0100
# Epoch: 38, Training loss: 1.1641, Validation loss: 1.1619, lr: 0.0100
# Epoch: 39, Training loss: 1.1563, Validation loss: 1.1886, lr: 0.0100
# Epoch: 40, Training loss: 1.1619, Validation loss: 1.1941, lr: 0.0010
# Epoch: 41, Training loss: 1.1725, Validation loss: 1.1617, lr: 0.0010
# Epoch: 42, Training loss: 1.1646, Validation loss: 1.2706, lr: 0.0010
# Epoch: 43, Training loss: 1.1701, Validation loss: 1.1424, lr: 0.0010
# Epoch: 44, Training loss: 1.1338, Validation loss: 1.1427, lr: 0.0010
# Epoch: 45, Training loss: 1.1619, Validation loss: 1.0967, lr: 0.0010 *
# Epoch: 46, Training loss: 1.1665, Validation loss: 1.2148, lr: 0.0010
# Epoch: 47, Training loss: 1.1513, Validation loss: 1.2043, lr: 0.0010
# Epoch: 48, Training loss: 1.1483, Validation loss: 1.1878, lr: 0.0010
# Epoch: 49, Training loss: 1.1632, Validation loss: 1.1286, lr: 0.0010
# Epoch: 50, Training loss: 1.1540, Validation loss: 1.1095, lr: 0.0010
# Epoch: 51, Training loss: 1.1718, Validation loss: 1.1471, lr: 0.0010
# Epoch: 52, Training loss: 1.1492, Validation loss: 1.1872, lr: 0.0010
# Epoch: 53, Training loss: 1.1619, Validation loss: 1.1733, lr: 0.0010
# Epoch: 54, Training loss: 1.1590, Validation loss: 1.1861, lr: 0.0010
# Epoch: 55, Training loss: 1.1594, Validation loss: 1.1830, lr: 0.0001
# Epoch: 56, Training loss: 1.1413, Validation loss: 1.1913, lr: 0.0001
# Epoch: 57, Training loss: 1.1808, Validation loss: 1.1889, lr: 0.0001
# Epoch: 58, Training loss: 1.1464, Validation loss: 1.1811, lr: 0.0001
# Epoch: 59, Training loss: 1.1607, Validation loss: 1.2242, lr: 0.0001
# Epoch: 60, Training loss: 1.1385, Validation loss: 1.1255, lr: 0.0001
# Epoch: 61, Training loss: 1.1535, Validation loss: 1.2049, lr: 0.0001
# Epoch: 62, Training loss: 1.1528, Validation loss: 1.1949, lr: 0.0001
# Epoch: 63, Training loss: 1.1726, Validation loss: 1.1921, lr: 0.0001
# Epoch: 64, Training loss: 1.1657, Validation loss: 1.1584, lr: 0.0001
# Epoch: 65, Training loss: 1.1523, Validation loss: 1.1169, lr: 0.0001
# Epoch: 66, Training loss: 1.1511, Validation loss: 1.1682, lr: 0.0000
# Epoch: 67, Training loss: 1.1522, Validation loss: 1.1402, lr: 0.0000
# Epoch: 68, Training loss: 1.1652, Validation loss: 1.2427, lr: 0.0000
# Epoch: 69, Training loss: 1.1747, Validation loss: 1.1436, lr: 0.0000
# Epoch: 70, Training loss: 1.1748, Validation loss: 1.1634, lr: 0.0000
# Epoch: 71, Training loss: 1.1504, Validation loss: 1.2080, lr: 0.0000
# Epoch: 72, Training loss: 1.1542, Validation loss: 1.1434, lr: 0.0000
# Epoch: 73, Training loss: 1.1592, Validation loss: 1.1293, lr: 0.0000
# Epoch: 74, Training loss: 1.1866, Validation loss: 1.1652, lr: 0.0000
# Epoch: 75, Training loss: 1.1420, Validation loss: 1.0846, lr: 0.0000 *
# Epoch: 76, Training loss: 1.1491, Validation loss: 1.1935, lr: 0.0000
# Epoch: 77, Training loss: 1.1559, Validation loss: 1.1930, lr: 0.0000
# Epoch: 78, Training loss: 1.1609, Validation loss: 1.2391, lr: 0.0000
# Epoch: 79, Training loss: 1.1513, Validation loss: 1.1786, lr: 0.0000
# Epoch: 80, Training loss: 1.1603, Validation loss: 1.0868, lr: 0.0000
# Epoch: 81, Training loss: 1.1397, Validation loss: 1.1852, lr: 0.0000
# Epoch: 82, Training loss: 1.1409, Validation loss: 1.2301, lr: 0.0000
# Epoch: 83, Training loss: 1.1517, Validation loss: 1.1483, lr: 0.0000
# Epoch: 84, Training loss: 1.1424, Validation loss: 1.1968, lr: 0.0000
# Epoch: 85, Training loss: 1.1573, Validation loss: 1.3550, lr: 0.0000
# Epoch: 86, Training loss: 1.1550, Validation loss: 1.1826, lr: 0.0000
# Epoch: 87, Training loss: 1.1613, Validation loss: 1.1580, lr: 0.0000
# Epoch: 88, Training loss: 1.1720, Validation loss: 1.1361, lr: 0.0000
# Epoch: 89, Training loss: 1.1484, Validation loss: 1.1278, lr: 0.0000
# Epoch: 90, Training loss: 1.1721, Validation loss: 1.0991, lr: 0.0000
# Epoch: 91, Training loss: 1.1371, Validation loss: 1.2123, lr: 0.0000
# Epoch: 92, Training loss: 1.1643, Validation loss: 1.2371, lr: 0.0000
# Epoch: 93, Training loss: 1.1713, Validation loss: 1.1893, lr: 0.0000
# Epoch: 94, Training loss: 1.1592, Validation loss: 1.1926, lr: 0.0000
# Epoch: 95, Training loss: 1.1485, Validation loss: 1.1861, lr: 0.0000
# Epoch: 96, Training loss: 1.1652, Validation loss: 1.2029, lr: 0.0000
# Epoch: 97, Training loss: 1.1430, Validation loss: 1.1484, lr: 0.0000
# Epoch: 98, Training loss: 1.1636, Validation loss: 1.1134, lr: 0.0000
# Epoch: 99, Training loss: 1.1378, Validation loss: 1.1028, lr: 0.0000
# Epoch: 100, Training loss: 1.1514, Validation loss: 1.1434, lr: 0.0000
# Final test loss: 1.0678

# %%
data = model.evaluate(data)
n_clusters=20
data = postprocessing(data, n_clusters=n_clusters)

emb_MDS, _ = geometry.embed(data.dist, embed_typ = 'MDS')
labels = [g for i in range(2) for g in gain ]
plotting.embedding(emb_MDS, labels, s=30, alpha=1)
# Out:
# Performed umap embedding on embedded results.
# Performed MDS embedding on embedded results.
# <AxesSubplot:>

# %%
plt.imshow(data.dist)

# %%
plotting.embedding(data.emb_2d, data.y.numpy(), titles=titles)
# Out:
# <AxesSubplot:>
