# %%
import numpy as np
from GeoDySys import solvers, time_series, plotting

# %% [markdown]
# # Simulate Lorenz system

# %%
par = {'sigma': 10.0, 'beta': 8/3.0, 'rho': 28.0, 'tau': 1.0}
fun = 'lorenz'

# par['sigma']*((par['sigma']+par['beta']+3)/(par['sigma']-par['beta']-1))


#simulate system
x0 = [-8.0, 7.0, 27.0]
T = np.linspace(0, 20, 1000)
mu, sigma = 0, 1 # mean and standard deviation
X = solvers.simulate_ODE(fun, T, x0, par, noise=False, mu=mu, sigma=sigma)

# %% [markdown]
# # Plot state-space

# %%
plotting.trajectories(X, style='o', lw=1, ms=1)
# Out:
# <Axes3DSubplot:>

# %% [markdown]
# # Create random projections of state-space to scalar time series

# %%
n_obs = 5

x = []
for i in range(n_obs):
    x_tmp = time_series.random_projection(X, seed=i)
    x.append(x_tmp)

# %% [markdown]
# # Plot trajectories

# %%
ax = plotting.time_series(T, x, style='o', node_feature=None, lw=1, ms=4, save='Lorenz_projections.svg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/hj/113tdgn92h36jbyjj8hw4lkc0000gp/T/ipykernel_46293/2853044851.py in <module>
# ----> 1 ax = plotting.time_series(T, x[0], style='o', node_feature=None, lw=1, ms=4, save='scalar_fields_nhoods.svg')
#
# TypeError: time_series() got an unexpected keyword argument 'save'
