# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import sys
from MARBLE import plotting, utils, geometry, net

# %%
n = 512
k = 30
n_clusters = 10
    
par = {'batch_size': 256, #batch size, this should be as large as possible
       'epochs': 30, #optimisation epochs
       'order': 2, #order of derivatives
       'n_lin_layers': 2,
       'hidden_channels': 16, #number of internal dimensions in MLP
       'out_channels': 4,
      }

# %% [markdown]
# # Continuously deform a parabola to a saddle

# %%
def f(x, alpha=0):
    return x[:,[0]]**2 - alpha*x[:,[1]]**2

# %%
n_steps = 10
beta = np.linspace(-1, 1, n_steps)
x = [geometry.sample_2d(n, [[-1,-1],[1,1]], 'random') for i in range(n_steps)]
y = [f(x_, beta[i]) for i,x_ in enumerate(x)] #evaluated functions

data = utils.construct_dataset(x, y, graph_type='cknn', k=k)

# %%
titles = [r'$\beta$ = {:0.2f}'.format(a)  for a in beta]
plotting.fields(data, col=5, figsize=(10,3), titles=titles)#, save='scalar_fields.svg')

# %%
# !export CUDA_VISIBLE_DEVICES=0

model = net(data, gauge='global', **par)
model.run_training(data)
# Out:
# ---- Settings:
#
# gauge : global
# batch_size : 256
# epochs : 30
# order : 2
# n_lin_layers : 2
# hidden_channels : 16
# out_channels : 4
# depth : 0
# vec_norm : False
# inner_product_features : False
# vector : False
# frac_geodesic_nb : 2.0
# var_explained : 0.9
# frac_sampled_nb : 0.8
# dropout : 0.0
# bias : False
# batch_norm : batch_norm
# lr : 0.01
# seed : 0
# signal_dim : 1
# emb_dim : 2
# slices : tensor([   0,  512, 1024, 1536, 2048, 2560, 3072, 3584, 4096, 4608, 5120])
# n_sampled_nb : 24
# n_geodesic_nb : 60
#
#
# ---- Number of features to pass to the MLP:  6
# ---- Total number of parameters:  213
#
# ---- Starting training ...
#
# Epoch: 1, Training loss: 20.6426, Validation loss: 21.9763
# Epoch: 2, Training loss: 19.9118, Validation loss: 21.3151
# Epoch: 3, Training loss: 19.7893, Validation loss: 20.2325
# Epoch: 4, Training loss: 19.4379, Validation loss: 18.8889
# Epoch: 5, Training loss: 19.5753, Validation loss: 19.3500
# Epoch: 6, Training loss: 19.3860, Validation loss: 19.0796
# Epoch: 7, Training loss: 18.8921, Validation loss: 18.6937
# Epoch: 8, Training loss: 19.0450, Validation loss: 19.4869
# Epoch: 9, Training loss: 18.9815, Validation loss: 18.7549
# Epoch: 10, Training loss: 18.6007, Validation loss: 18.7849
# Epoch: 11, Training loss: 18.4667, Validation loss: 18.6442
# Epoch: 12, Training loss: 18.4479, Validation loss: 19.2522
# Epoch: 13, Training loss: 18.3704, Validation loss: 18.2721
# Epoch: 14, Training loss: 18.2532, Validation loss: 18.7252
# Epoch: 15, Training loss: 18.2370, Validation loss: 17.6447
# Epoch: 16, Training loss: 18.1121, Validation loss: 18.9223
# Epoch: 17, Training loss: 17.9050, Validation loss: 18.4863
# Epoch: 18, Training loss: 17.9659, Validation loss: 18.4300
# Epoch: 19, Training loss: 17.8041, Validation loss: 17.7785
# Epoch: 20, Training loss: 17.8403, Validation loss: 17.8785
# Epoch: 21, Training loss: 17.8594, Validation loss: 18.5013
# Epoch: 22, Training loss: 17.7555, Validation loss: 17.6134
# Epoch: 23, Training loss: 17.6850, Validation loss: 17.7045
# Epoch: 24, Training loss: 17.7898, Validation loss: 16.5224
# Epoch: 25, Training loss: 17.6517, Validation loss: 17.4756
# Epoch: 26, Training loss: 17.8154, Validation loss: 18.4526
# Epoch: 27, Training loss: 17.7763, Validation loss: 17.7890
# Epoch: 28, Training loss: 17.7892, Validation loss: 17.9447
# Epoch: 29, Training loss: 17.7836, Validation loss: 17.7889
# Epoch: 30, Training loss: 17.7325, Validation loss: 17.5155
# Final test loss: 17.9018

# %% [markdown]
# # Create embeddings and clusters for visualisation

# %%
emb = model.evaluate(data)
emb, clusters, dist = model.cluster_and_embed(n_clusters=n_clusters)
emb_MDS = geometry.embed(dist, embed_typ='MDS')
# Out:
# Performed t-SNE embedding on embedded results.

# %%
plotting.embedding(emb, data.y.numpy(), clusters, titles=titles)#, save='scalar_fields_embedding.svg')

# %%
# plotting.neighbourhoods(data, clusters, hops=1, norm=True, save='scalar_fields_nhoods.svg')
plotting.embedding(emb_MDS, beta)#, save='scalar_fields_MDS.svg')
