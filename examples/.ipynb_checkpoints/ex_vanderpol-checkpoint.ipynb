# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from DE_library import simulate_ODE, simulate_trajectories
import matplotlib.pyplot as plt
from example_utils import reject_outliers, initial_conditions, plot_phase_portrait

from MARBLE import utils, geometry, net, plotting, postprocessing, compare_attractors

# %%
def simulate_system(mu, X0, t):
    p, v = simulate_trajectories('vanderpol', X0, t, par = {'mu': mu})
    pos, vel = [], []
    for p_, v_ in zip(p,v):
        ind = reject_outliers(p_, v_)
        pos.append(p_[ind])
        vel.append(v_[ind])
        
    return pos, vel

# %% [markdown]
# # For initial conditions, sample a rectangle uniformly

# %%
t0, t1, dt = 0, 3, 0.5
t = np.arange(t0, t1, dt)
n = 100
area = [[-3,-3],[3,3]]

# %% [markdown]
# # Geneate phase portraits from random initial conditions while varying $\beta_1$

# %%
def cone(X, Y, alpha):
    Z = -(alpha*X)**2 -(alpha*Y)**2
    
    return np.column_stack([X.flatten(), Y.flatten(), Z.flatten()])

# %%
n_steps=10
beta1 = np.hstack((np.linspace(-.5,.5,n_steps)))

pos, vel = [], []
X0_range = initial_conditions(n, len(beta1), area)
for i, b1 in enumerate(beta1):
    p, v = simulate_system(b1, X0_range[i], t)
            
    pos.append(np.vstack(p))
    vel.append(np.vstack(v))
    
#embed on cone
#alpha = 0.05
#for i, (p, v) in enumerate(zip(pos, vel)):
#    end_point = p + v
#    new_endpoint = cone(end_point[:,0], end_point[:,1], alpha)
#    pos[i] = cone(p[:,0], p[:,1], alpha)
#    vel[i] = new_endpoint - pos[i]
# Out:
# /mnt/scratch/lts2/gosztolai/miniconda3/envs/MARBLE/lib/python3.9/site-packages/scipy/integrate/_odepack_py.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)

# %% [markdown]
# # Plot vector fields

# %%
k=15

data = utils.construct_dataset(pos, features=vel, graph_type='cknn', k=k, stop_crit=0.05)
# Out:
# ---- Embedding dimension: 2
# ---- Signal dimension: 2
#
# Embedding dimension <= 2, so manifold computations are disabled!

# %%
titles = [r'$\beta$ = {:0.2f}'.format(b) for b in beta1]

plotting.fields(data, col=4, alpha=0.2)
#plotting.fields(data, col=4, alpha=0.2, width=10, scale=2, titles=titles, view=[50,60])
# Out:
# [<AxesSubplot:>,
#  <AxesSubplot:>,
#  <AxesSubplot:>,
#  <AxesSubplot:>,
#  <AxesSubplot:>,
#  <AxesSubplot:>,
#  <AxesSubplot:>,
#  <AxesSubplot:>,
#  <AxesSubplot:>,
#  <AxesSubplot:>]

# %% [markdown]
# # Train network

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="2"

par = {'batch_size': 64, #batch size
       'epochs': 70, #optimisation epochs
       'momentum': 1,
       'lr': 0.01,
       'gamma': 1.,
       'order': 2, #order of derivatives
       'n_lin_layers': 2,
       'hidden_channels': 8, #number of internal dimensions in MLP
       'out_channels': 3,
       'inner_product_features': True,
       'autoencoder': False,
      }

model = net(data, **par)
model.run_training(data)
# Out:
# ---- Settings:
#
# batch_size : 64
# epochs : 70
# lr : 0.01
# gamma : 0.95
# order : 2
# n_lin_layers : 2
# hidden_channels : 8
# out_channels : 3
# inner_product_features : True
# autoencoder : False
# momentum : 0.9
# diffusion : False
# frac_sampled_nb : -1
# dropout : 0.0
# bias : True
# vec_norm : False
# batch_norm : None
# seed : 0
# processes : 1
# dim_signal : 2
# dim_emb : 2
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  7
# ---- Total number of parameters:  121
#
# ---- Training network ...
#
# Epoch: 1, Training loss: 1.3832, Validation loss: 1.3780, lr: 0.0095 *
# Epoch: 2, Training loss: 1.3802, Validation loss: 1.3777, lr: 0.0090 *
# Epoch: 3, Training loss: 1.3770, Validation loss: 1.3751, lr: 0.0086 *
# Epoch: 4, Training loss: 1.3758, Validation loss: 1.3795, lr: 0.0081
# Epoch: 46, Training loss: 1.2136, Validation loss: 1.2362, lr: 0.0009
# Epoch: 47, Training loss: 1.2087, Validation loss: 1.2659, lr: 0.0009
# Epoch: 48, Training loss: 1.2346, Validation loss: 1.1493, lr: 0.0009
# Epoch: 49, Training loss: 1.2339, Validation loss: 1.2907, lr: 0.0008
# Epoch: 50, Training loss: 1.2168, Validation loss: 1.2647, lr: 0.0008
# Epoch: 51, Training loss: 1.1900, Validation loss: 1.2277, lr: 0.0007
# Epoch: 52, Training loss: 1.2028, Validation loss: 1.2565, lr: 0.0007
# Epoch: 53, Training loss: 1.2005, Validation loss: 1.2283, lr: 0.0007
# Epoch: 54, Training loss: 1.2077, Validation loss: 1.2322, lr: 0.0006
# Epoch: 55, Training loss: 1.2117, Validation loss: 1.2271, lr: 0.0006
# Epoch: 56, Training loss: 1.2188, Validation loss: 1.0886, lr: 0.0006 *
# Epoch: 57, Training loss: 1.2056, Validation loss: 1.1711, lr: 0.0005
# Epoch: 58, Training loss: 1.2200, Validation loss: 1.1301, lr: 0.0005
# Epoch: 59, Training loss: 1.1810, Validation loss: 1.2432, lr: 0.0005
# Epoch: 60, Training loss: 1.2411, Validation loss: 1.1867, lr: 0.0005
# Epoch: 61, Training loss: 1.2248, Validation loss: 1.2185, lr: 0.0004
# Epoch: 62, Training loss: 1.2000, Validation loss: 1.2149, lr: 0.0004
# Epoch: 63, Training loss: 1.2148, Validation loss: 1.1667, lr: 0.0004
# Epoch: 64, Training loss: 1.1830, Validation loss: 1.2022, lr: 0.0004
# Epoch: 65, Training loss: 1.2235, Validation loss: 1.1840, lr: 0.0004
# Epoch: 66, Training loss: 1.1894, Validation loss: 1.1869, lr: 0.0003
# Epoch: 67, Training loss: 1.2019, Validation loss: 1.1412, lr: 0.0003
# Epoch: 68, Training loss: 1.2349, Validation loss: 1.1965, lr: 0.0003
# Epoch: 69, Training loss: 1.1881, Validation loss: 1.2275, lr: 0.0003
# Epoch: 70, Training loss: 1.2020, Validation loss: 1.1410, lr: 0.0003
# Final test loss: 1.2041

# %% [markdown]
# # Create embeddings

# %%
data = model.evaluate(data)
n_clusters=20
data = postprocessing(data, n_clusters=n_clusters)

emb_MDS, _ = geometry.embed(data.dist, embed_typ = 'MDS')
plotting.embedding(emb_MDS, beta1, s=30, alpha=1)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# Performed umap embedding on embedded results.
# Performed MDS embedding on embedded results.
# <AxesSubplot:>

# %% [markdown]
# # Distance matrix

# %%
plt.imshow(data.dist)

# %% [markdown]
# # Cluster and visualise embedding

# %%
titles = [r'$\beta$ = {:0.2f}'.format(b) for b in beta1]
plotting.embedding(data.emb_2d, data.y.numpy(), titles=titles)

# %%
compare_attractors(data, (4,5))

# %%
n_clusters=[2,4,6,8]
fig, ax = plt.subplots(len(n_clusters),4, figsize=(10,10))
slices=data._slice_dict['x']

def plot_embedding(data, ax, slices, i, n_clusters=2):
    s = range(slices[i], slices[i+1])
    clusters = geometry.cluster(data.emb_2d, cluster_typ='kmeans', n_clusters=n_clusters, seed=0)
    plotting.embedding(data.emb_2d[s], clusters['labels'][s], ax=ax[0])
    plot_phase_portrait(data.pos[s], data.x[s], ax[1], node_feature=clusters['labels'][s])

snapshot=4
for i, n in enumerate(n_clusters):
    plot_embedding(data, ax[:,:2][i], slices, snapshot, n_clusters=n)
    
snapshot=5
for i, n in enumerate(n_clusters):
    plot_embedding(data, ax[:,2:][i], slices, snapshot, n_clusters=n)
