# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from DE_library import simulate_ODE, simulate_phase_portrait
import matplotlib.pyplot as plt

import sys
from MARBLE import utils, geometry, net, plotting

rng = np.random.RandomState(1)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Bogdanov-Takens system http://www.scholarpedia.org/article/Bogdanov-Takens_bifurcation

# %% [markdown]
# # For initial conditions, sample the $[-1,1]^2$ rectangle uniformly

# %%
t0, t1, dt = 0, 1, 0.2
t = np.arange(t0, t1, dt)
n = 100

eps=0.01
X0_range = [geometry.sample_2d(n, [[-3,-3],[3,3]], 'random') for i in range(4)]
for i, X0 in enumerate(X0_range):
    X0_range[i][np.abs(X0) < eps]=eps

# %% [markdown]
# # Display state spaces under four different parameter conditions

# %%
def simulate_system(mu, X0_range):
    pos, vel = simulate_phase_portrait('vanderpol', t, X0_range, par = {'mu': mu})
    return pos, vel

def plot_phase_portrait(pos, vel, ax):

    for p, v in zip(pos, vel):
        ax = plotting.trajectories(p, v, ax=ax, style='>', lw=1, arrowhead=.03, axis=False, alpha=None)
    ax.axis('square')
    ax.set_xlim([-3,3])
    ax.set_ylim([-3,3])

# %%
fig, ax = plt.subplots(1,4, figsize=(20,5))
    
pos, vel = simulate_system(-0.5, X0_range[0])
plot_phase_portrait(pos, vel, ax[0])
pos, vel = simulate_system(-0.1, X0_range[1])
plot_phase_portrait(pos, vel, ax[1])
pos, vel = simulate_system(0.1, X0_range[2])
plot_phase_portrait(pos, vel, ax[2])
pos, vel = simulate_system(0.5, X0_range[3])
plot_phase_portrait(pos, vel, ax[3])
# Out:
# /mnt/scratch/lts2/gosztolai/miniconda3/envs/MARBLE/lib/python3.9/site-packages/scipy/integrate/_odepack_py.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# /mnt/scratch/lts2/gosztolai/miniconda3/envs/MARBLE/lib/python3.9/site-packages/matplotlib/quiver.py:651: RuntimeWarning: overflow encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))

# %% [markdown]
# # Geneate phase portraits from random initial conditions while varying $\beta_1$

# %%
#beta1 = np.hstack((np.linspace(-0.5,-0.2,5),np.linspace(0.2,0.5,5)))
beta1 = np.hstack((np.linspace(-0.5,0.5,10)))

pos, vel = [], []
for b1 in beta1:
    X0_range = geometry.sample_2d(n, [[-3,-3],[3,3]], 'random')
    p, v = simulate_system(b1, X0_range)
    p, v = np.vstack(p), np.vstack(v)
    vel_mag = np.linalg.norm(v, axis=1)
    
    ind = np.where((abs(p)<3).any(1) & (abs(vel_mag)<(vel_mag.mean() + vel_mag.std())))[0]
    v = v[ind,:]
    p = p[ind,:]
    
    pos.append(p)
    vel.append(v)

# %%
pos_subsample = pos
vel_subsample = vel
#ind = rng.permutation(len(beta1))
#pos_subsampl = [pos_subsample[i] for i in ind]
#vel_subsample = [vel_subsample[i] for i in ind]

# %% [markdown]
# # Subsample phase portrait

# %%
pos_subsample, vel_subsample = [], []
for i, (p,v) in enumerate(zip(pos,vel)):
    ind, _ = geometry.furthest_point_sampling(p, stop_crit=0.01)
    pos_subsample.append(p[ind])
    vel_subsample.append(v[ind])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1589392/2491424346.py in <module>
#       1 pos_subsample, vel_subsample = [], []
#       2 for i, (p,v) in enumerate(zip(pos,vel)):
# ----> 3     ind, _ = geometry.furthest_point_sampling(p, stop_crit=0.01)
#       4     pos_subsample.append(p[ind])
#       5     vel_subsample.append(v[ind])
#
# /mnt/scratch/lts2/gosztolai/MARBLE/MARBLE/lib/geometry.py in furthest_point_sampling(x, N, stop_crit)
#      63     """
#      64
# ---> 65     D = pairwise_distances(x)
#      66     n = D.shape[0] if N is None else N
#      67     diam = D.max()
#
# /mnt/scratch/lts2/gosztolai/miniconda3/envs/MARBLE/lib/python3.9/site-packages/sklearn/metrics/pairwise.py in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    2020         func = partial(distance.cdist, metric=metric, **kwds)
#    2021
# -> 2022     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    2023
#    2024
#
# /mnt/scratch/lts2/gosztolai/miniconda3/envs/MARBLE/lib/python3.9/site-packages/sklearn/metrics/pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1561
#    1562     if effective_n_jobs(n_jobs) == 1:
# -> 1563         return func(X, Y, **kwds)
#    1564
#    1565     # enforce a threading backend to prevent data communication overhead
#
# /mnt/scratch/lts2/gosztolai/miniconda3/envs/MARBLE/lib/python3.9/site-packages/sklearn/metrics/pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     298            [1.41421356]])
#     299     """
# --> 300     X, Y = check_pairwise_arrays(X, Y)
#     301
#     302     if X_norm_squared is not None:
#
# /mnt/scratch/lts2/gosztolai/miniconda3/envs/MARBLE/lib/python3.9/site-packages/sklearn/metrics/pairwise.py in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     144
#     145     if Y is X or Y is None:
# --> 146         X = Y = check_array(
#     147             X,
#     148             accept_sparse=accept_sparse,
#
# /mnt/scratch/lts2/gosztolai/miniconda3/envs/MARBLE/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     907         n_samples = _num_samples(array)
#     908         if n_samples < ensure_min_samples:
# --> 909             raise ValueError(
#     910                 "Found array with %d sample(s) (shape=%s) while a"
#     911                 " minimum of %d is required%s."
#
# ValueError: Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required by check_pairwise_arrays.

# %% [markdown]
# Compare phase portraits before and after subsampling

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))

i=0
j=-1
#plot_phase_portrait([pos[j]], [vel[j]], ax[1])
plot_phase_portrait([pos[i]], [vel[i]], ax[0])
plot_phase_portrait([pos_subsample[i]], [vel_subsample[i]], ax[1])
# Out:
# /mnt/scratch/lts2/gosztolai/miniconda3/envs/MARBLE/lib/python3.9/site-packages/matplotlib/quiver.py:651: RuntimeWarning: divide by zero encountered in double_scalars
#   length = a * (widthu_per_lenu / (self.scale * self.width))

# %% [markdown]
# # Train network

# %%
k=10

data = utils.construct_dataset(pos_subsample, features=vel_subsample, graph_type='cknn', k=k)

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

par = {'batch_size': 256, #batch size
       'epochs': 20, #optimisation epochs
       'order': 2, #order of derivatives
       'depth': 0, #number of hops in neighbourhood
       'n_lin_layers': 2,
       'hidden_channels': 16, #number of internal dimensions in MLP
       'out_channels': 4,
       'diffusion': False,
       'inner_product_features': True,
       'vector' : False
      }

model = net(data, **par)
model.run_training(data)
# Out:
# ---- Settings:
#
# batch_size : 256
# epochs : 20
# order : 2
# depth : 0
# n_lin_layers : 2
# hidden_channels : 16
# out_channels : 4
# diffusion : False
# inner_product_features : True
# vector : False
# lr : 0.01
# pretrained : True
# frac_geodesic_nb : 2.0
# var_explained : 0.9
# dropout : 0.0
# bias : False
# batch_norm : batch_norm
# seed : 0
# signal_dim : 2
# emb_dim : 2
# n_geodesic_nb : 20
# dim_embedding : 2
#
# ---- Number of features to pass to the MLP:  7
# ---- Total number of parameters:  488
# ---- Treating features as scalar channels.
#
# ---- Pretraining encoder ...
#
# Epoch: 1, reconstruction loss: 575.2412
# Epoch: 2, reconstruction loss: 415.3962
# Epoch: 3, reconstruction loss: 302.5001
# Epoch: 4, reconstruction loss: 137.4679
# Epoch: 5, reconstruction loss: 113.8901
# Epoch: 6, reconstruction loss: 75.2161
# Epoch: 7, reconstruction loss: 81.4104
# Epoch: 8, reconstruction loss: 80.2623
# Epoch: 9, reconstruction loss: 86.1349
# Epoch: 10, reconstruction loss: 54.9214
# Epoch: 11, reconstruction loss: 83.2265
# Epoch: 12, reconstruction loss: 83.9403
# Epoch: 13, reconstruction loss: 42.4160
# Epoch: 14, reconstruction loss: 59.6499
# Epoch: 15, reconstruction loss: 54.8855
# Epoch: 16, reconstruction loss: 52.6502
# Epoch: 17, reconstruction loss: 59.3121
# Epoch: 18, reconstruction loss: 60.8817
# Epoch: 19, reconstruction loss: 58.2229
# Epoch: 20, reconstruction loss: 57.4155
#
# ---- Training network ...
#
# Epoch: 1, Training loss: 21.9479, Validation loss: 19.2771
# Epoch: 2, Training loss: 15.8180, Validation loss: 19.7111
# Epoch: 3, Training loss: 14.4446, Validation loss: 19.5212
# Epoch: 4, Training loss: 14.5058, Validation loss: 18.7383
# Epoch: 5, Training loss: 14.1613, Validation loss: 18.8017
# Epoch: 6, Training loss: 14.0340, Validation loss: 18.8771
# Epoch: 7, Training loss: 14.9875, Validation loss: 18.5740
# Epoch: 8, Training loss: 14.1191, Validation loss: 19.2602
# Epoch: 9, Training loss: 14.2912, Validation loss: 18.4363
# Epoch: 10, Training loss: 13.9979, Validation loss: 19.5233
# Epoch: 11, Training loss: 14.2843, Validation loss: 18.8989
# Epoch: 12, Training loss: 14.0821, Validation loss: 18.6313
# Epoch: 13, Training loss: 14.4129, Validation loss: 19.4110
# Epoch: 14, Training loss: 14.0281, Validation loss: 18.8457
# Epoch: 15, Training loss: 13.8738, Validation loss: 17.7951
# Epoch: 16, Training loss: 13.6637, Validation loss: 18.8229
# Epoch: 17, Training loss: 13.8678, Validation loss: 17.8165
# Epoch: 18, Training loss: 13.6925, Validation loss: 18.2943
# Epoch: 19, Training loss: 13.4907, Validation loss: 17.5789
# Epoch: 20, Training loss: 13.4564, Validation loss: 18.2102
# Final test loss: 18.2398

# %% [markdown]
# # Create embeddings and cluster

# %%
n_clusters = 30
data = model.evaluate(data)

# %% [markdown]
# # Visualise embedding

# %%
tsne_emb, clusters, dist = geometry.cluster_embedding(data, n_clusters=n_clusters, embed_typ='umap')
titles = [r'$\beta$ = {:0.2f}'.format(b) for b in beta1]
plotting.embedding(tsne_emb, data.y.numpy(), clusters, titles=titles)
# Out:
# Performed UMAP embedding on embedded results.

# %%
#dist = geometry.compute_distribution_distances(data)
emb_MDS = geometry.embed(dist, embed_typ = 'MDS')
plotting.embedding(emb_MDS, beta1)

# %%
plt.imshow(dist)
