# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from DE_library import simulate_ODE, simulate_phase_portrait
import matplotlib.pyplot as plt

from MARBLE import utils, geometry, net, plotting

# %%
def initial_conditions(n, reps):
    X0_range = [geometry.sample_2d(n, [[-3,-3],[3,3]], 'random', seed=i) for i in range(reps)]
        
    return X0_range

def simulate_system(mu, X0, eps=1e-10):
    p, v = simulate_phase_portrait('vanderpol', t, X0, par = {'mu': mu})
    pos, vel = [], []
    for p_, v_ in zip(p,v):
        ind = np.where((abs(p_) < 3).all(1))[0]
        p_ = p_[ind,:]; v_ = v_[ind,:]
        ind = np.where((abs(v_) > eps).any(1))[0]
        p_ = p_[ind,:]; v_ = v_[ind,:]
        pos.append(p_)
        vel.append(v_)
        
    return pos, vel

def plot_phase_portrait(pos, vel, ax=None, node_feature=None):
    if not isinstance(pos, list):
        pos = [pos]
    if not isinstance(vel, list):
        vel = [vel]

    for p, v in zip(pos, vel):
        ax = plotting.trajectories(p, v, ax=ax, style='>', node_feature=node_feature, lw=2, arrowhead=.1, axis=False, alpha=1.)
    ax.axis('square')
    
def reject_outliers(data, m=1):
    data = data.mean(1)
    return np.where(abs(data - np.median(data)) < m * np.std(data))[0]

def plot_embedding(emb, ax, slices, i, n_clusters=2):
    s = range(slices[i], slices[i+1])
    clusters = geometry.cluster(emb, cluster_typ='kmeans', n_clusters=n_clusters, seed=0)
    plotting.embedding(emb, clusters['labels'], ax=ax[0])
    plot_phase_portrait(pos_subsample[i], vel_subsample[i], ax[1], node_feature=clusters['labels'][s])

# %% [markdown]
# # For initial conditions, sample a rectangle uniformly

# %%
t0, t1, dt = 0, 1, 0.2
t = np.arange(t0, t1, dt)
n = 100

# %% [markdown]
# # Geneate phase portraits from random initial conditions while varying $\beta_1$

# %%
n_steps=10
beta1 = np.hstack((np.linspace(-0.5,0.5,n_steps)))

pos, vel = [], []
X0_range = initial_conditions(n, len(beta1))
for i, b1 in enumerate(beta1):
    p, v = simulate_system(b1, X0_range[i])
            
    pos.append(np.vstack(p))
    vel.append(np.vstack(v))
# Out:
# /mnt/scratch/lts2/gosztolai/miniconda3/envs/MARBLE/lib/python3.9/site-packages/scipy/integrate/_odepack_py.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)

# %% [markdown]
# # Display state spaces under four different parameter conditions

# %%
fig, ax = plt.subplots(1,4, figsize=(20,5))
    
plot_phase_portrait(pos[0], vel[0], ax[0])
plot_phase_portrait(pos[n_steps//2-1], vel[n_steps//2-1], ax[1])
plot_phase_portrait(pos[n_steps//2+1], vel[n_steps//2+1], ax[2])
plot_phase_portrait(pos[-1], vel[-1], ax[3])

# %% [markdown]
# # Subsample phase portrait

# %%
pos_subsample, vel_subsample = [], []
for i, (p,v) in enumerate(zip(pos,vel)):
    ind, _ = geometry.furthest_point_sampling(p, stop_crit=0.02)
    pos_subsample.append(p[ind])
    vel_subsample.append(v[ind])

# %% [markdown]
# Compare phase portraits before and after subsampling

# %%
fig, ax = plt.subplots(1,4, figsize=(20,5))
    
plot_phase_portrait(pos_subsample[0], vel_subsample[0], ax[0])
plot_phase_portrait(pos_subsample[n_steps//2-1], vel_subsample[n_steps//2-1], ax[1])
plot_phase_portrait(pos_subsample[n_steps//2+1], vel_subsample[n_steps//2+1], ax[2])
plot_phase_portrait(pos_subsample[-1], vel_subsample[-1], ax[3])

# %% [markdown]
# # Train network

# %%
k=10

data = utils.construct_dataset(pos_subsample, features=vel_subsample, graph_type='cknn', k=k)

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

par = {'batch_size': 256, #batch size
       'epochs': 40, #optimisation epochs
       'order': 3, #order of derivatives
       'n_lin_layers': 2,
       'hidden_channels': 16, #number of internal dimensions in MLP
       'out_channels': 3,
       'diffusion': False,
       'inner_product_features': True,
       'pretrained':False,
       'second_training': True
      }

model = net(data, **par)
model.run_training(data)
# Out:
# ---- Settings:
#
# batch_size : 256
# epochs : 40
# order : 3
# n_lin_layers : 2
# hidden_channels : 16
# out_channels : 3
# diffusion : False
# inner_product_features : True
# pretrained : False
# second_training : True
# lr : 0.01
# vector : False
# frac_geodesic_nb : 2.0
# frac_sampled_nb : -1
# var_explained : 0.9
# diffusion_method : spectral
# dropout : 0.0
# bias : True
# vec_norm : False
# batch_norm : None
# seed : 0
# processes : 1
# dim_signal : 2
# dim_emb : 2
# n_geodesic_nb : 20
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  15
# ---- Total number of parameters:  368
# ---- Treating features as scalar channels.
#
# ---- Training network ...
#
# Epoch: 1, Training loss: 13.6511, Validation loss: 21.2548
# Epoch: 2, Training loss: 12.5285, Validation loss: 21.1386
# Epoch: 3, Training loss: 12.0041, Validation loss: 18.0194
# Epoch: 4, Training loss: 11.4526, Validation loss: 18.8140
# Epoch: 5, Training loss: 11.5630, Validation loss: 17.8255
# Epoch: 6, Training loss: 11.0284, Validation loss: 18.2351
# Epoch: 7, Training loss: 11.0847, Validation loss: 19.6552
# Epoch: 8, Training loss: 11.0117, Validation loss: 16.5959
# Epoch: 9, Training loss: 11.0042, Validation loss: 17.5905
# Epoch: 10, Training loss: 11.2916, Validation loss: 16.9185
# Epoch: 11, Training loss: 10.5399, Validation loss: 17.6514
# Epoch: 12, Training loss: 10.6742, Validation loss: 16.4800
# Epoch: 13, Training loss: 10.5223, Validation loss: 17.7274
# Epoch: 14, Training loss: 10.7078, Validation loss: 16.5285
# Epoch: 15, Training loss: 10.8435, Validation loss: 16.4660
# Epoch: 16, Training loss: 10.6551, Validation loss: 16.5324
# Epoch: 17, Training loss: 10.5892, Validation loss: 17.5263
# Epoch: 18, Training loss: 11.2558, Validation loss: 16.8418
# Epoch: 19, Training loss: 10.7146, Validation loss: 17.0475
# Epoch: 20, Training loss: 10.5258, Validation loss: 17.6545
# Epoch: 21, Training loss: 10.8537, Validation loss: 17.8656
# Epoch: 22, Training loss: 11.0002, Validation loss: 18.1534
# Epoch: 23, Training loss: 10.7760, Validation loss: 17.7881
# Epoch: 24, Training loss: 11.0034, Validation loss: 17.8274
# Epoch: 25, Training loss: 10.6863, Validation loss: 17.2039
# Epoch: 26, Training loss: 10.8916, Validation loss: 17.1264
# Epoch: 27, Training loss: 10.9840, Validation loss: 17.7560
# Epoch: 28, Training loss: 10.7527, Validation loss: 17.4841
# Epoch: 29, Training loss: 10.6794, Validation loss: 17.6850
# Epoch: 30, Training loss: 10.9775, Validation loss: 16.0635
# Epoch: 31, Training loss: 10.9426, Validation loss: 16.6848
# Epoch: 32, Training loss: 10.3977, Validation loss: 16.6095
# Epoch: 33, Training loss: 11.1086, Validation loss: 17.8690
# Epoch: 34, Training loss: 10.6726, Validation loss: 17.1120
# Epoch: 35, Training loss: 10.8383, Validation loss: 16.5668
# Epoch: 36, Training loss: 11.3986, Validation loss: 18.6875
# Epoch: 37, Training loss: 10.4695, Validation loss: 17.7695
# Epoch: 38, Training loss: 10.5055, Validation loss: 16.1514
# Epoch: 39, Training loss: 10.5586, Validation loss: 17.5281
# Epoch: 40, Training loss: 10.5062, Validation loss: 16.8622
# Final test loss: 18.2172

# %% [markdown]
# # Create embeddings

# %%
data = model.evaluate(data)

# %%
dist = geometry.compute_distribution_distances(data)
emb_MDS = geometry.embed(dist, embed_typ = 'MDS')
plotting.embedding(emb_MDS, beta1,s=30, alpha=1)

# %% [markdown]
# # Distance matrix

# %%
plt.imshow(dist)

# %% [markdown]
# # Cluster and visualise embedding

# %%
emb = geometry.embed(data.emb)
titles = [r'$\beta$ = {:0.2f}'.format(b) for b in beta1]
plotting.embedding(emb, data.y.numpy(), titles=titles)
# Out:
# Performed umap embedding on embedded results.
# <AxesSubplot:>

# %%
n_clusters=[2,4,6,8]
fig, ax = plt.subplots(len(n_clusters),4, figsize=(10,10))
slices=data._slice_dict['x']

snapshot=4
for i, n in enumerate(n_clusters):
    plot_embedding(emb, ax[:,:2][i], slices, snapshot, n_clusters=n)
    
snapshot=5
for i, n in enumerate(n_clusters):
    plot_embedding(emb, ax[:,2:][i], slices, snapshot, n_clusters=n)
