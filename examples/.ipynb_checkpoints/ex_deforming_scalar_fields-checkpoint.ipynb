# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from MARBLE import plotting, utils, geometry, net

# %%
k = 10

# %% [markdown]
# # Create functions on the cone

# %%
def f1(x):
    return np.cos(x[:,[0]]) + np.sin(x[:,[1]])

def f2(x):
    return np.cos(x[:,[0]]) + np.sin(2*x[:,[1]])

def sample_cone(alpha, nr, ntheta):
    r = np.sqrt(np.linspace(0.5, 5, nr))
    theta = np.linspace(0, 2*np.pi, ntheta)
    r, theta = np.meshgrid(r, theta)
    X = r*np.cos(theta)
    Y = r*np.sin(theta)
    Z = -(alpha*r)**2
    
    return np.column_stack([X.flatten(), Y.flatten(), Z.flatten()])

# %% [markdown]
# # Continuously deform the manifold

# %%
n_steps = 3
alpha = np.linspace(1, 0.750, n_steps)
nr = 100
ntheta = 400
x_ = np.linspace(-np.pi, np.pi, nr)
y_ = np.linspace(-np.pi, np.pi, ntheta)
x_, y_ = np.meshgrid(x_, y_)
X = np.column_stack([x_.flatten(), y_.flatten()])
    
y = [f1(X) for i in range(n_steps)] + [f2(X) for i in range(n_steps)]
x = 2 * [sample_cone(a, nr, ntheta) for a in alpha]

# %% [markdown]
# # Even out sampling

# %%
ind, _ = geometry.furthest_point_sampling(x[0], stop_crit=0.05)
x = [x_[ind] for x_ in x]
y = [y_[ind] for y_ in y]

data = utils.construct_dataset(x, y, graph_type='cknn', k=k)

# %%
titles = [r'$f_1,\alpha$ = ' + str(a) for a in alpha] + \
        [r'$f_2,\alpha$ = ' + str(a) for a in alpha]
plotting.fields(data, titles=titles, col=3, node_size=5, figsize=(8,5))#, save='scalar_fields.svg')
# Out:
# /mnt/scratch/lts2/gosztolai/miniconda3/envs/MARBLE/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: constrained_layout not applied because axes sizes collapsed to zero.  Try making figure larger or axes decorations smaller.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Train model

# %%
# !export CUDA_VISIBLE_DEVICES=0

par = {'batch_size': 256, #batch size, this should be as large as possible
       'epochs': 20, #optimisation epochs
       'order': 2, #order of derivatives
       'n_lin_layers': 2,
       'hidden_channels': 16, #number of internal dimensions in MLP
       'out_channels': 4,
      }

model = net(data, gauge='global', **par)
model.run_training(data)
# Out:
# /mnt/scratch/lts2/gosztolai/MARBLE/MARBLE/lib/utils.py:57: UserWarning: Vector computation is requested but signal dimension is                      one! Setting vector=False
#   warnings.warn('Vector computation is requested but signal dimension is \
# ---- Settings:
#
# gauge : global
# batch_size : 256
# epochs : 20
# order : 2
# n_lin_layers : 2
# hidden_channels : 16
# out_channels : 4
# depth : 0
# inner_product_features : True
# vector : False
# frac_geodesic_nb : 2.0
# var_explained : 0.9
# diffusion : True
# frac_sampled_nb : 0.8
# dropout : 0.0
# bias : False
# batch_norm : batch_norm
# lr : 0.01
# seed : 0
# signal_dim : 1
# emb_dim : 3
# n_sampled_nb : 8
# n_geodesic_nb : 20
#
#
# ---- Number of features to pass to the MLP:  3
# ---- Total number of parameters:  148
#
# ---- Starting training ...
#
# Epoch: 1, Training loss: 11.9973, Validation loss: 21.9463
# Epoch: 2, Training loss: 10.9397, Validation loss: 20.7593
# Epoch: 3, Training loss: 11.0227, Validation loss: 20.9521
# Epoch: 4, Training loss: 10.7182, Validation loss: 20.4743
# Epoch: 5, Training loss: 11.0325, Validation loss: 15.4936
# Epoch: 6, Training loss: 10.8892, Validation loss: 17.5234
# Epoch: 7, Training loss: 10.8250, Validation loss: 15.9341
# Epoch: 8, Training loss: 10.8663, Validation loss: 17.5949
# Epoch: 9, Training loss: 10.7328, Validation loss: 17.9782
# Epoch: 10, Training loss: 11.0399, Validation loss: 17.5221
# Epoch: 11, Training loss: 10.7672, Validation loss: 19.7303
# Epoch: 12, Training loss: 10.8003, Validation loss: 18.2590
# Epoch: 13, Training loss: 10.8380, Validation loss: 17.1004
# Epoch: 14, Training loss: 10.9766, Validation loss: 18.5824
# Epoch: 15, Training loss: 10.8049, Validation loss: 15.5214
# Epoch: 16, Training loss: 10.8202, Validation loss: 21.4897
# Epoch: 17, Training loss: 10.6220, Validation loss: 18.3574
# Epoch: 18, Training loss: 10.6301, Validation loss: 19.2993
# Epoch: 19, Training loss: 10.8050, Validation loss: 18.0987
# Epoch: 20, Training loss: 10.6963, Validation loss: 17.3058
# Final test loss: 17.7227

# %% [markdown]
# # Create embeddings and clusters

# %%
n_clusters = 30

data = model.evaluate(data)
emb, clusters, dist = geometry.cluster_embedding(data, n_clusters=n_clusters)
emb_MDS = geometry.embed(dist, embed_typ='MDS')
# Out:
# Performed t-SNE embedding on embedded results.

# %%
plotting.embedding(emb, data.y.numpy(), clusters, titles=titles)#, save='scalar_fields_embedding.svg')

# %%
labels = np.array([0]*n_steps + [1]*n_steps)
plotting.embedding(emb_MDS, labels)#, save='scalar_fields_MDS.svg')

# %%
plotting.histograms(clusters, col=3, figsize=(13,5), titles=titles)#, save='scalar_fields_histogram.svg')

# %%
plotting.neighbourhoods(data, clusters, hops=1, norm=True)#, save='scalar_fields_nhoods.svg')
# Out:
# /mnt/scratch/lts2/gosztolai/miniconda3/envs/MARBLE/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: constrained_layout not applied because axes sizes collapsed to zero.  Try making figure larger or axes decorations smaller.
#   fig.canvas.print_figure(bytes_io, **kw)
