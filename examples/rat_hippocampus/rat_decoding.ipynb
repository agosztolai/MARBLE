# %% [markdown]
# # Decoding from MARBLE and CEBRA embeddings
#
# In this notebook, we compare MARBLE and CEBRA for decoding.
#
# - decode labels from a MARBLE and CEBRA embedding.
# - evaluate and compare the decoding performances for embeddings obtained from different hypotheses.
#
# This notebook is adapted from the demo notebook from CEBRA and is based on what was presented in [Figure 2.d.](https://cebra.ai/docs/cebra-figures/figures/Figure2.html) of Schneider, Lee, Mathis.

# %%
! pip install cebra
! pip install elephant

import sys
import numpy as np
import matplotlib.pyplot as plt
import pickle

# cebra imports
import cebra
from cebra import CEBRA

# marble imports
import MARBLE
from rat_utils import prepare_marble
# Out:
# Requirement already satisfied: cebra in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (0.3.0)
# Requirement already satisfied: torch in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from cebra) (1.12.1)
# Requirement already satisfied: scipy in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from cebra) (1.9.3)
# Requirement already satisfied: tqdm in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from cebra) (4.64.1)
# Requirement already satisfied: requests in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from cebra) (2.31.0)
# Requirement already satisfied: joblib in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from cebra) (1.1.1)
# Requirement already satisfied: matplotlib in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from cebra) (3.5.2)
# Requirement already satisfied: scikit-learn in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from cebra) (1.1.2)
# Requirement already satisfied: literate-dataclasses in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from cebra) (0.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from matplotlib->cebra) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from matplotlib->cebra) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from matplotlib->cebra) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from matplotlib->cebra) (9.2.0)
# Requirement already satisfied: numpy>=1.17 in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from matplotlib->cebra) (1.23.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from matplotlib->cebra) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from matplotlib->cebra) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from matplotlib->cebra) (21.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from requests->cebra) (2023.11.17)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from requests->cebra) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from requests->cebra) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from requests->cebra) (2.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from scikit-learn->cebra) (2.2.0)
# Requirement already satisfied: typing-extensions in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from torch->cebra) (4.3.0)
# Requirement already satisfied: six>=1.5 in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->cebra) (1.16.0)
# Requirement already satisfied: elephant in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (1.0.0)
# Requirement already satisfied: neo>=0.10.0 in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from elephant) (0.12.0)
# Requirement already satisfied: tqdm in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from elephant) (4.64.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from elephant) (1.23.3)
# Requirement already satisfied: quantities>=0.14.1 in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from elephant) (0.14.1)
# Requirement already satisfied: six>=1.10.0 in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from elephant) (1.16.0)
# Requirement already satisfied: scipy>=1.5.4 in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from elephant) (1.9.3)
# Requirement already satisfied: packaging in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from neo>=0.10.0->elephant) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages (from packaging->neo>=0.10.0->elephant) (3.0.9)

# %% [markdown]
# ## Load the data

# %%
# !wget -nc https://dataverse.harvard.edu/api/access/datafile/7609512 -O rat_data.pkl

with open('rat_data.pkl', 'rb') as handle:
    hippocampus_pos = pickle.load(handle)
    
rat = 'achilles'
hippocampus_pos = hippocampus_pos[rat]
# Out:
# File ‘rat_data.pkl’ already there; not retrieving.

# %% [markdown]
# ## Train the models
#
# *[This can be skipped if you already saved the models].*

# %% [markdown]
# - For a quick CEBRA CPU run-time demo, you can drop `max_iterations` to 100-500; otherwise set to 5000.

# %%
max_iterations = 10000
output_dimension = 32 #here, we set as a variable for hypothesis testing below.

# %%
# defining train and test splits of the data

def split_data(data, test_ratio):

    split_idx = int(data['neural'].shape[0] * (1-test_ratio))
    neural_train = data['neural'][:split_idx]
    neural_test = data['neural'][split_idx:]
    label_train = data['continuous_index'][:split_idx]
    label_test = data['continuous_index'][split_idx:]
    
    return neural_train.numpy(), neural_test.numpy(), label_train.numpy(), label_test.numpy()

neural_train, neural_test, label_train, label_test = split_data(hippocampus_pos, 0.2)

# %%
# 40 hz sampling rate (they binned into 25ms epochs

spikes = neural_train[:2000,:].T
spikes = [np.where(spikes[ch,:])[0]/40 for ch in range(120)] 
    
_, ax = plt.subplots(figsize=(8,4))
ax.eventplot(spikes,color='gray')
plt.ylabel('Neurons')
plt.xlabel('Time (s)')
plt.savefig('raster_plot.svg')

# %% [markdown]
# ### Train CEBRA-Behavior with position, or direction, and/or both variables

# %%
cebra_time_model = CEBRA(model_architecture='offset10-model',
                        batch_size=512,
                        learning_rate=3e-4,
                        temperature=1,
                        output_dimension=output_dimension,
                        max_iterations=max_iterations,
                        distance='cosine',
                        conditional='time',
                        device='cuda_if_available',
                        verbose=True,
                        time_offsets=10)

cebra_posdir_model = CEBRA(model_architecture='offset10-model',
                        batch_size=512,
                        learning_rate=3e-4,
                        temperature=1,
                        output_dimension=output_dimension,
                        max_iterations=max_iterations,
                        distance='cosine',
                        conditional='time_delta',
                        device='cuda_if_available',
                        verbose=True,
                        time_offsets=10)

cebra_pos_model = CEBRA(model_architecture='offset10-model',
                        batch_size=512,
                        learning_rate=3e-4,
                        temperature=1,
                        output_dimension=output_dimension,
                        max_iterations=max_iterations,
                        distance='cosine',
                        conditional='time_delta',
                        device='cuda_if_available',
                        verbose=True,
                        time_offsets=10)

cebra_dir_model = CEBRA(model_architecture='offset10-model',
                        batch_size=512,
                        learning_rate=3e-4,
                        temperature=1,
                        output_dimension=output_dimension,
                        max_iterations=max_iterations,
                        distance='cosine',
                        device='cuda_if_available',
                        verbose=True)

# %%
# Train CEBRA-Behavior models with both position and direction variables.
cebra_time_model.fit(neural_train)
cebra_time_model.save("cebra_time_model.pt")

# Train CEBRA-Behavior models with both position and direction variables.
cebra_posdir_model.fit(neural_train, label_train)
cebra_posdir_model.save("cebra_posdir_model.pt")

# Train CEBRA-Behavior models with position or direction variable.
cebra_pos_model.fit(neural_train, label_train[:,0])
cebra_pos_model.save("cebra_pos_model.pt")

cebra_dir_model.fit(neural_train, label_train[:,1])
cebra_dir_model.save("cebra_dir_model.pt")
# Out:
# pos: -0.8851 neg:  6.3849 total:  5.4997 temperature:  1.0000: 100%|█| 10000/100
# pos: -0.8866 neg:  6.4968 total:  5.6102 temperature:  1.0000: 100%|█| 10000/100
# pos: -0.8173 neg:  6.4704 total:  5.6531 temperature:  1.0000: 100%|█| 10000/100

# %% [markdown]
# ### Train MARBLE with only neural data

# %%
# build model 
data_train, label_train_marble, pca = prepare_marble(neural_train.T, label_train)

# build model
params = {
    "epochs": 100,
    "order": 1,  # order of derivatives
    "lr": 1,
    "batch_size": 64,
    "hidden_channels": [64],  # number of internal dimensions in MLP
    "out_channels": 32, 
    "inner_product_features": False,
    "emb_norm": True, # spherical output embedding
    "diffusion": False,
    "include_positions": True,
  }
model = MARBLE.net(data_train, params=params)

# run training of model
model.fit(data_train, outdir=f"hippocampus_{rat}")

# evaluate embedding on training data
data_train = model.transform(data_train)
# Out:
# [0.25057016 0.1686058  0.08780102 0.07304726 0.0413553  0.03523341
#  0.0322533  0.02940006 0.01651664 0.01588705]
#
# ---- Embedding dimension: 10
# ---- Signal dimension: 10
# ---- Computing kernels ...
# ---- Settings:
#
# epochs : 100
# order : 1
# lr : 1
# batch_size : 64
# hidden_channels : [64]
# out_channels : 32
# inner_product_features : False
# emb_norm : True
# diffusion : False
# include_positions : True
# momentum : 0.9
# frac_sampled_nb : -1
# include_self : True
# dropout : 0.0
# vec_norm : False
# bias : True
# batch_norm : batch_norm
# seed : 0
# dim_signal : 10
# dim_emb : 10
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  120
# ---- Total number of parameters:  9953
#
# Using device cpu
#
# ---- Training network ...
#
# Epoch: 0, Training loss: 1.049062, Validation loss: 1.0493, lr: 1.0000 *
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 20
#      17 model = MARBLE.net(data_train, params=params)
#      19 # run training of model
# ---> 20 model.fit(data_train, outdir=f"hippocampus_{rat}")
#      22 # evaluate embedding on training data
#      23 data_train = model.transform(data_train)
#
# File ~/github/MARBLE/MARBLE/main.py:381, in net.fit(self, data, outdir, verbose)
#     376 for epoch in range(
#     377     self.params.get("epoch", 0), self.params.get("epoch", 0) + self.params["epochs"]
#     378 ):
#     379     self._epoch = epoch
# --> 381     train_loss, optimizer = self.batch_loss(
#     382         data, train_loader, train=True, verbose=verbose, optimizer=optimizer
#     383     )
#     384     val_loss, _ = self.batch_loss(data, val_loader, verbose=verbose)
#     385     scheduler.step(train_loss)
#
# File ~/github/MARBLE/MARBLE/main.py:327, in net.batch_loss(self, data, loader, train, verbose, optimizer)
#     324 _, n_id, adjs = batch
#     325 adjs = [adj.to(data.x.device) for adj in utils.to_list(adjs)]
# --> 327 emb, mask = self.forward(data, n_id, adjs)
#     328 loss = self.loss(emb, mask)
#     329 cum_loss += float(loss)
#
# File ~/github/MARBLE/MARBLE/main.py:250, in net.forward(self, data, n_id, adjs)
#     248     out = []
#     249 for i, (_, _, size) in enumerate(adjs):
# --> 250     kernels = [K[n_id[: size[1] * d], :][:, n_id[: size[0] * d]] for K in data.kernels]
#     252     x = self.grad[i](x, kernels)
#     254     if self.params["vec_norm"]:
#
# File ~/github/MARBLE/MARBLE/main.py:250, in <listcomp>(.0)
#     248     out = []
#     249 for i, (_, _, size) in enumerate(adjs):
# --> 250     kernels = [K[n_id[: size[1] * d], :][:, n_id[: size[0] * d]] for K in data.kernels]
#     252     x = self.grad[i](x, kernels)
#     254     if self.params["vec_norm"]:
#
# File ~/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages/torch_sparse/tensor.py:585, in __getitem__(self, index)
#     583         dim += 1
#     584     elif item.dtype == torch.long:
# --> 585         out = out.index_select(dim, item)
#     586         dim += 1
#     587 elif item == Ellipsis:
#
# File ~/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages/torch_sparse/index_select.py:98, in <lambda>(self, dim, idx)
#      92         value = value[idx]
#      94     return SparseTensor(row=row, rowptr=None, col=col, value=value,
#      95                         sparse_sizes=src.sparse_sizes(), is_sorted=True)
# ---> 98 SparseTensor.index_select = lambda self, dim, idx: index_select(self, dim, idx)
#      99 tmp = lambda self, idx, layout=None: index_select_nnz(  # noqa
#     100     self, idx, layout)
#     101 SparseTensor.index_select_nnz = tmp
#
# File ~/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages/torch_sparse/index_select.py:43, in index_select(src, dim, idx)
#      40     return src.from_storage(storage)
#      42 elif dim == 1:
# ---> 43     old_colptr, row, value = src.csc()
#      44     colcount = src.storage.colcount()
#      46     colcount = colcount[idx]
#
# File ~/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages/torch_sparse/tensor.py:206, in SparseTensor.csc(self)
#     205 def csc(self) -> Tuple[torch.Tensor, torch.Tensor, Optional[torch.Tensor]]:
# --> 206     perm = self.storage.csr2csc()
#     207     value = self.storage.value()
#     208     if value is not None:
#
# File ~/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages/torch_sparse/storage.py:392, in SparseStorage.csr2csc(self)
#     389     return csr2csc
#     391 idx = self._sparse_sizes[0] * self._col + self.row()
# --> 392 csr2csc = idx.argsort()
#     393 self._csr2csc = csr2csc
#     394 return csr2csc
#
# KeyboardInterrupt:

# %%
# build model 
data_test, label_test_marble, _ = prepare_marble(neural_test.T, label_test, pca=pca)

# generate embedding of test data
data_test = model.transform(data_test)
# Out:
# [0.25057016 0.1686058  0.08780102 0.07304726 0.0413553  0.03523341
#  0.0322533  0.02940006 0.0165167  0.01588702]
#
# ---- Embedding dimension: 10
# ---- Signal dimension: 10
# ---- Computing kernels ...

# %% [markdown]
# # Compare embeddings after training

# %%
#%matplotlib notebook

fig = plt.figure(figsize=(10,6))

ax1 = plt.subplot(221, projection='3d')
ax=cebra.plot_embedding(ax=ax1, embedding=data_train.emb, embedding_labels=label_train_marble[:,0], markersize=0.2, title='MARBLE-train')

ax2 = plt.subplot(222, projection='3d')
ax=cebra.plot_embedding(ax=ax2, embedding=data_test.emb, embedding_labels=label_test_marble[:,0], markersize=0.2, title='MARBLE-test')

ax3 = plt.subplot(223, projection='3d')
ax=cebra.plot_embedding(ax=ax3, embedding=cebra_time_train, embedding_labels=label_train[:,0], markersize=0.2, title='CEBRA-time-train')

ax4 = plt.subplot(224, projection='3d')
ax=cebra.plot_embedding(ax=ax4, embedding=cebra_time_test, embedding_labels=label_test[:,0], markersize=0.2, title='CEBRA-time-test')
    
plt.show()

# %% [markdown]
# **------------------- END OF TRAINING SECTION -------------------**
#
# ## Load the models and get the corresponding embeddings

# %% [markdown]
# Load the CEBRA models

# %%
# We get train set embedding and test set embedding. 

# !wget -nc https://dataverse.harvard.edu/api/access/datafile/7609517 -O cebra_time_model.pt
# !wget -nc https://dataverse.harvard.edu/api/access/datafile/7609520 -O cebra_posdir_model.pt
# !wget -nc https://dataverse.harvard.edu/api/access/datafile/7609519 -O cebra_pos_model.pt
# !wget -nc https://dataverse.harvard.edu/api/access/datafile/7609518 -O cebra_dir_model.pt

cebra_time_model = cebra.CEBRA.load("cebra_time_model.pt")
cebra_time_train = cebra_time_model.transform(neural_train)
cebra_time_test = cebra_time_model.transform(neural_test)

cebra_posdir_model = cebra.CEBRA.load("cebra_posdir_model.pt")
cebra_posdir_train = cebra_posdir_model.transform(neural_train)
cebra_posdir_test = cebra_posdir_model.transform(neural_test)

cebra_pos_model = cebra.CEBRA.load("cebra_pos_model.pt")
cebra_pos_train = cebra_pos_model.transform(neural_train)
cebra_pos_test = cebra_pos_model.transform(neural_test)

cebra_dir_model = cebra.CEBRA.load("cebra_dir_model.pt")
cebra_dir_train = cebra_dir_model.transform(neural_train)
cebra_dir_test = cebra_dir_model.transform(neural_test)

cebra_time_all = cebra_time_model.transform(hippocampus_pos['neural'])
cebra_pos_all = cebra_pos_model.transform(hippocampus_pos['neural'])
cebra_dir_all = cebra_dir_model.transform(hippocampus_pos['neural'])
cebra_posdir_all = cebra_posdir_model.transform(hippocampus_pos['neural'])
# Out:
# --2023-12-01 18:21:07--  https://dataverse.harvard.edu/api/access/datafile/7609517
# Resolving dataverse.harvard.edu (dataverse.harvard.edu)... 34.203.112.67, 18.207.145.134, 107.23.57.159
# Connecting to dataverse.harvard.edu (dataverse.harvard.edu)|34.203.112.67|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://dvn-cloud.s3.amazonaws.com/10.7910/DVN/KTE4PC/18c104917f4-2a76fe44cad3?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27cebra_time_model.pt&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20231201T172122Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=AKIAIEJ3NV7UYCSRJC7A%2F20231201%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=afe3230ed290e583e36dd219737c8bf14367218de80e140dcfadbc1b2a45b7fc [following]
# --2023-12-01 18:21:23--  https://dvn-cloud.s3.amazonaws.com/10.7910/DVN/KTE4PC/18c104917f4-2a76fe44cad3?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27cebra_time_model.pt&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20231201T172122Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=AKIAIEJ3NV7UYCSRJC7A%2F20231201%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=afe3230ed290e583e36dd219737c8bf14367218de80e140dcfadbc1b2a45b7fc
# Resolving dvn-cloud.s3.amazonaws.com (dvn-cloud.s3.amazonaws.com)... 52.217.198.49, 3.5.25.187, 52.216.215.17, ...
# Connecting to dvn-cloud.s3.amazonaws.com (dvn-cloud.s3.amazonaws.com)|52.217.198.49|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 584362 (571K) [application/octet-stream]
# Saving to: ‘cebra_time_model.pt’
#
# cebra_time_model.pt 100%[===================>] 570,67K  43,2KB/s    in 13s
#
# 2023-12-01 18:21:49 (43,2 KB/s) - ‘cebra_time_model.pt’ saved [584362/584362]
#
# --2023-12-01 18:21:50--  https://dataverse.harvard.edu/api/access/datafile/7609520
# Resolving dataverse.harvard.edu (dataverse.harvard.edu)... 18.207.145.134, 107.23.57.159, 34.203.112.67
# Connecting to dataverse.harvard.edu (dataverse.harvard.edu)|18.207.145.134|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://dvn-cloud.s3.amazonaws.com/10.7910/DVN/KTE4PC/18c10490ea6-301674737562?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27cebra_posdir_model.pt&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20231201T172201Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=AKIAIEJ3NV7UYCSRJC7A%2F20231201%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=8a1ff121a7f889afac2450168aba737bc8cd673c708629fc069de21b839b505a [following]
# --2023-12-01 18:22:02--  https://dvn-cloud.s3.amazonaws.com/10.7910/DVN/KTE4PC/18c10490ea6-301674737562?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27cebra_posdir_model.pt&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20231201T172201Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=AKIAIEJ3NV7UYCSRJC7A%2F20231201%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=8a1ff121a7f889afac2450168aba737bc8cd673c708629fc069de21b839b505a
# Resolving dvn-cloud.s3.amazonaws.com (dvn-cloud.s3.amazonaws.com)... 52.217.198.49, 3.5.25.187, 52.216.215.17, ...
# Connecting to dvn-cloud.s3.amazonaws.com (dvn-cloud.s3.amazonaws.com)|52.217.198.49|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 584490 (571K) [application/octet-stream]
# Saving to: ‘cebra_posdir_model.pt’
#
# cebra_posdir_model. 100%[===================>] 570,79K  51,5KB/s    in 11s
#
# 2023-12-01 18:22:17 (51,5 KB/s) - ‘cebra_posdir_model.pt’ saved [584490/584490]
#
# --2023-12-01 18:22:18--  https://dataverse.harvard.edu/api/access/datafile/7609519
# Resolving dataverse.harvard.edu (dataverse.harvard.edu)... 107.23.57.159, 34.203.112.67, 18.207.145.134
# Connecting to dataverse.harvard.edu (dataverse.harvard.edu)|107.23.57.159|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://dvn-cloud.s3.amazonaws.com/10.7910/DVN/KTE4PC/18c1049130f-033e71efc595?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27cebra_pos_model.pt&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20231201T172223Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=AKIAIEJ3NV7UYCSRJC7A%2F20231201%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=d714fc29444af72a6fe879ad3761dc6b34f53ab0027ab1700e68617d1a59fb94 [following]
# --2023-12-01 18:22:25--  https://dvn-cloud.s3.amazonaws.com/10.7910/DVN/KTE4PC/18c1049130f-033e71efc595?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27cebra_pos_model.pt&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20231201T172223Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=AKIAIEJ3NV7UYCSRJC7A%2F20231201%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=d714fc29444af72a6fe879ad3761dc6b34f53ab0027ab1700e68617d1a59fb94
# Resolving dvn-cloud.s3.amazonaws.com (dvn-cloud.s3.amazonaws.com)... 52.217.198.49, 3.5.25.187, 52.216.215.17, ...
# Connecting to dvn-cloud.s3.amazonaws.com (dvn-cloud.s3.amazonaws.com)|52.217.198.49|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 584490 (571K) [application/octet-stream]
# Saving to: ‘cebra_pos_model.pt’
#
# cebra_pos_model.pt  100%[===================>] 570,79K  18,5KB/s    in 31s
#
# 2023-12-01 18:23:06 (18,5 KB/s) - ‘cebra_pos_model.pt’ saved [584490/584490]
#
# --2023-12-01 18:23:06--  https://dataverse.harvard.edu/api/access/datafile/7609518
# Resolving dataverse.harvard.edu (dataverse.harvard.edu)... 18.207.145.134, 34.203.112.67, 107.23.57.159
# Connecting to dataverse.harvard.edu (dataverse.harvard.edu)|18.207.145.134|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://dvn-cloud.s3.amazonaws.com/10.7910/DVN/KTE4PC/18c10490b93-58401e34431d?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27cebra_dir_model.pt&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20231201T172317Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=AKIAIEJ3NV7UYCSRJC7A%2F20231201%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=90017a866d65522e47bb49af7fb3ece8c7a099dbbfeae2deab02c9600614a774 [following]
# --2023-12-01 18:23:19--  https://dvn-cloud.s3.amazonaws.com/10.7910/DVN/KTE4PC/18c10490b93-58401e34431d?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27cebra_dir_model.pt&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20231201T172317Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=AKIAIEJ3NV7UYCSRJC7A%2F20231201%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=90017a866d65522e47bb49af7fb3ece8c7a099dbbfeae2deab02c9600614a774
# Resolving dvn-cloud.s3.amazonaws.com (dvn-cloud.s3.amazonaws.com)... 52.217.198.49, 3.5.25.187, 52.216.215.17, ...
# Connecting to dvn-cloud.s3.amazonaws.com (dvn-cloud.s3.amazonaws.com)|52.217.198.49|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 584426 (571K) [application/octet-stream]
# Saving to: ‘cebra_dir_model.pt’
#
# cebra_dir_model.pt  100%[===================>] 570,73K  21,0KB/s    in 27s
#
# 2023-12-01 18:23:55 (21,0 KB/s) - ‘cebra_dir_model.pt’ saved [584426/584426]

# %% [markdown]
# Load MARBLE models

# %%
# load MARBLE

# !wget -nc https://dataverse.harvard.edu/api/access/datafile/7609516 -O hippocampus_achilles/best_model_20231127-110323.pth

# process data
data_train, label_train_marble, pca = prepare_marble(neural_train.T, label_train)
data_test, label_test_marble, _ = prepare_marble(neural_test.T, label_test, pca=pca)

# load trained model
marble_model = MARBLE.net(data_train, loadpath=f"hippocampus_{rat}")

# generate embedding of test data
data_train = marble_model.transform(data_train)
data_test = marble_model.transform(data_test)
# Out:
# --2023-12-01 18:27:46--  https://dataverse.harvard.edu/api/access/datafile/7609516
# Resolving dataverse.harvard.edu (dataverse.harvard.edu)... 107.23.57.159, 18.207.145.134, 34.203.112.67
# Connecting to dataverse.harvard.edu (dataverse.harvard.edu)|107.23.57.159|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://dvn-cloud.s3.amazonaws.com/10.7910/DVN/KTE4PC/18c1047d72a-2831375261b6?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27best_model_20231127-110323.pth&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20231201T172747Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=AKIAIEJ3NV7UYCSRJC7A%2F20231201%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=d5b9a2150fc14cb338102dd29b08e884a8d89144938c332898d7c1936153da01 [following]
# --2023-12-01 18:27:47--  https://dvn-cloud.s3.amazonaws.com/10.7910/DVN/KTE4PC/18c1047d72a-2831375261b6?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27best_model_20231127-110323.pth&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20231201T172747Z&X-Amz-SignedHeaders=host&X-Amz-Expires=3600&X-Amz-Credential=AKIAIEJ3NV7UYCSRJC7A%2F20231201%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=d5b9a2150fc14cb338102dd29b08e884a8d89144938c332898d7c1936153da01
# Resolving dvn-cloud.s3.amazonaws.com (dvn-cloud.s3.amazonaws.com)... 52.216.42.89, 52.217.139.233, 52.217.117.17, ...
# Connecting to dvn-cloud.s3.amazonaws.com (dvn-cloud.s3.amazonaws.com)|52.216.42.89|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 123291 (120K) [application/octet-stream]
# Saving to: ‘hippocampus_achilles/best_model_20231127-110323.pth’
#
# hippocampus_achille 100%[===================>] 120,40K   388KB/s    in 0,3s
#
# 2023-12-01 18:27:48 (388 KB/s) - ‘hippocampus_achilles/best_model_20231127-110323.pth’ saved [123291/123291]
#
# [0.25057016 0.1686058  0.08780102 0.07304726 0.0413553  0.03523341
#  0.0322533  0.02940006 0.01651661 0.01588624]
#
# ---- Embedding dimension: 10
# ---- Signal dimension: 10
# ---- Computing kernels ... [0.25057016 0.1686058  0.08780102 0.07304726 0.0413553  0.03523341
#  0.0322533  0.02940006 0.01651661 0.01588624]
#
# ---- Embedding dimension: 10
# ---- Signal dimension: 10
# ---- Computing kernels ...
# ---- Settings:
#
# epochs : 100
# order : 1
# lr : 1
# batch_size : 64
# hidden_channels : [64]
# out_channels : 32
# inner_product_features : False
# emb_norm : True
# diffusion : False
# include_positions : True
# momentum : 0.9
# frac_sampled_nb : -1
# include_self : True
# dropout : 0.0
# vec_norm : False
# bias : True
# batch_norm : batch_norm
# seed : 0
# dim_signal : 10
# dim_emb : 10
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  120
# ---- Total number of parameters:  9953
#
# Using device cpu

# %% [markdown]
# ### Visualise the embeddings in 3D

# %%
#%matplotlib notebook

fig = plt.figure(figsize=(10,6))

ax1 = plt.subplot(221, projection='3d')
ax=cebra.plot_embedding(ax=ax1, embedding=data_train.emb, embedding_labels=label_train_marble[:,0], markersize=0.2, title='MARBLE-train')

ax2 = plt.subplot(222, projection='3d')
ax=cebra.plot_embedding(ax=ax2, embedding=data_test.emb, embedding_labels=label_test_marble[:,0], markersize=0.2, title='MARBLE-test')

ax3 = plt.subplot(223, projection='3d')
ax=cebra.plot_embedding(ax=ax3, embedding=cebra_time_train, embedding_labels=label_train[:,0], markersize=0.2, title='CEBRA-time-train')

ax4 = plt.subplot(224, projection='3d')
ax=cebra.plot_embedding(ax=ax4, embedding=cebra_time_test, embedding_labels=label_test[:,0], markersize=0.2, title='CEBRA-time-test')

plt.savefig('marble_cebra_embeddings_3D_32output.png')  
plt.show()

# %% [markdown]
# ## Decode the labels from the embeddings
# We evaluate decoding performance of the different hypothesis models.

# %%
from rat_utils import find_sequences, decoding_pos_dir
import pandas as pd
import seaborn as sns
from statannotations.Annotator import Annotator

# %% [markdown]
# ### Decode the position and direction from the trained hypothesis models

# %%
cebra_time_decode = decoding_pos_dir(cebra_time_train, cebra_time_test, label_train, label_test)
cebra_posdir_decode = decoding_pos_dir(cebra_posdir_train, cebra_posdir_test, label_train, label_test)
cebra_pos_decode = decoding_pos_dir(cebra_pos_train, cebra_pos_test, label_train, label_test)
cebra_dir_decode = decoding_pos_dir(cebra_dir_train, cebra_dir_test, label_train, label_test)
marble_decode = decoding_pos_dir(data_train.emb, data_test.emb, label_train_marble, label_test_marble)

# %% [markdown]
# ### Visualize the decoding results and loss - decoding performance

# %%
results = [cebra_time_decode[4][:-1], cebra_posdir_decode[4][:-1],  cebra_pos_decode[4][:-1], #cebra_dir_decode[5],
        marble_decode[4]]

results = pd.DataFrame(data=np.vstack(results).T,columns=['c-time','c-pos+dir', 'c-pos', 'marble'])
results = results.melt()
results.columns = ['model','accuracy']

f, ax = plt.subplots(figsize=(4,4))
sns.despine(bottom=True, left=True)

random_sampling = np.random.randint(low=0, high=results.shape[0], size=(200,))

sns.stripplot(
    data=results.iloc[random_sampling,:], x="model", y="accuracy", order=['c-time','c-pos+dir', 'c-pos', 'marble'], 
    dodge=True, alpha=.5, zorder=1, color='gray',
)

sns.pointplot(
    data=results, x="model", y="accuracy",
    join=False, dodge=.8 - .8 / 3, palette="dark",
    markers="d", scale=.75, errorbar=None
)

pairs=[("c-time", "marble"),
      ("c-pos+dir", "marble"),
      ("c-pos", "marble"),
      ]

annotator = Annotator(ax, pairs, data=results, x="model", y="accuracy",)
annotator.configure(test='Wilcoxon', text_format='star', loc='outside')
annotator.apply_and_annotate()
plt.tight_layout()
plt.savefig('decoding_accuracy_rat_32output_violin.svg')
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# c-pos vs. marble: Wilcoxon test (paired samples), P_val:6.824e-01 Stat=9.889e+05
# c-pos+dir vs. marble: Wilcoxon test (paired samples), P_val:9.279e-01 Stat=9.972e+05
# c-time vs. marble: Wilcoxon test (paired samples), P_val:3.872e-47 Stat=6.273e+05
# /Users/gosztola/opt/anaconda3/envs/MARBLE/lib/python3.9/site-packages/statannotations/_Plotter.py:337: UserWarning: Invalid x-position found. Are the same parameters passed to seaborn and statannotations calls? or are there few data points?
#   warnings.warn(

# %%
from scipy.stats import sem

fig = plt.figure(figsize=(10,4))

ax1= plt.subplot(121)
ax1.bar(np.arange(5), 
        [cebra_time_decode[1], cebra_posdir_decode[1],  cebra_pos_decode[1], cebra_dir_decode[1],
        marble_decode[1]], 
        width = 0.5, color = 'gray')

ax1.errorbar(np.arange(5),  
             [cebra_time_decode[1], cebra_posdir_decode[1],  cebra_pos_decode[1], cebra_dir_decode[1],
             marble_decode[1]],
             yerr=[sem(cebra_time_decode[4]), sem(cebra_posdir_decode[4]),  
                   sem(cebra_pos_decode[4]), sem(cebra_dir_decode[4]),
                   sem(marble_decode[4])], 
             fmt='none', ecolor='black', capsize=5)


ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.set_xticks(np.arange(5))
ax1.set_xticklabels(['time','pos+dir', 'pos', 'dir','marble'])
ax1.set_ylabel('Median err. [m]')


plt.legend(bbox_to_anchor=(1,1), frameon = False )
plt.savefig('decoding_accuracy_rat_32output_standarderror.svg')  
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig = plt.figure(figsize=(5,6))

t = label_test_marble[:,0].shape[0]

ax1= plt.subplot(311)
ax1.plot(np.arange(t)/40, label_test_marble[:,0])
ax1.plot(np.arange(t)/40, marble_decode[3][:,0])
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Position [m]')
ax1.set_title('MARBLE')

ax2= plt.subplot(312)
ax2.plot(np.arange(t)/40, label_test_marble[:,0])
ax2.plot(np.arange(t+1)/40, cebra_time_decode[3][:,0])
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.set_xlabel('Time [s]')
ax2.set_ylabel('Position [m]')
ax2.set_title('CEBRA (time)')

ax3 = plt.subplot(313)
ax3.plot(np.arange(t)/40, label_test_marble[:,0])
ax3.plot(np.arange(t+1)/40, cebra_pos_decode[3][:,0])
ax3.spines['top'].set_visible(False)
ax3.spines['right'].set_visible(False)
ax3.set_xlabel('Time [s]')
ax3.set_ylabel('Position [m]')
ax3.set_title('CEBRA (position)')

plt.savefig('decoding_vs_groundtruth_32output.svg')  


plt.tight_layout()
