# %% [markdown]
# # Decoding from MARBLE and CEBRA embeddings
#
# In this notebook, we compare MARBLE and CEBRA for decoding.
#
# - decode labels from a MARBLE and CEBRA embedding.
# - evaluate and compare the decoding performances for embeddings obtained from different hypotheses.
#
# This notebook is adapted from the demo notebook from CEBRA and is based on what was presented in [Figure 2.d.](https://cebra.ai/docs/cebra-figures/figures/Figure2.html) of Schneider, Lee, Mathis.

# %%
! pip install cebra
! pip install elephant

import sys
import numpy as np
import matplotlib.pyplot as plt
import pickle

# cebra imports
import cebra
from cebra import CEBRA

# marble imports
import MARBLE
from rat_utils import prepare_marble
# Out:
# Requirement already satisfied: cebra in /home/robert/anaconda3/lib/python3.9/site-packages (0.3.0)
# Requirement already satisfied: joblib in /home/robert/anaconda3/lib/python3.9/site-packages (from cebra) (1.2.0)
# Requirement already satisfied: literate-dataclasses in /home/robert/anaconda3/lib/python3.9/site-packages (from cebra) (0.0.6)
# Requirement already satisfied: scikit-learn in /home/robert/anaconda3/lib/python3.9/site-packages (from cebra) (1.2.2)
# Requirement already satisfied: scipy in /home/robert/anaconda3/lib/python3.9/site-packages (from cebra) (1.12.0)
# Requirement already satisfied: torch in /home/robert/anaconda3/lib/python3.9/site-packages (from cebra) (2.2.0)
# Requirement already satisfied: tqdm in /home/robert/anaconda3/lib/python3.9/site-packages (from cebra) (4.65.0)
# Requirement already satisfied: matplotlib in /home/robert/anaconda3/lib/python3.9/site-packages (from cebra) (3.7.1)
# Requirement already satisfied: requests in /home/robert/anaconda3/lib/python3.9/site-packages (from cebra) (2.28.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/robert/anaconda3/lib/python3.9/site-packages (from matplotlib->cebra) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/robert/anaconda3/lib/python3.9/site-packages (from matplotlib->cebra) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/robert/anaconda3/lib/python3.9/site-packages (from matplotlib->cebra) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/robert/anaconda3/lib/python3.9/site-packages (from matplotlib->cebra) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /home/robert/anaconda3/lib/python3.9/site-packages (from matplotlib->cebra) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /home/robert/anaconda3/lib/python3.9/site-packages (from matplotlib->cebra) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/robert/anaconda3/lib/python3.9/site-packages (from matplotlib->cebra) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/robert/anaconda3/lib/python3.9/site-packages (from matplotlib->cebra) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/robert/anaconda3/lib/python3.9/site-packages (from matplotlib->cebra) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/robert/anaconda3/lib/python3.9/site-packages (from matplotlib->cebra) (5.12.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/robert/anaconda3/lib/python3.9/site-packages (from requests->cebra) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/robert/anaconda3/lib/python3.9/site-packages (from requests->cebra) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/robert/anaconda3/lib/python3.9/site-packages (from requests->cebra) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /home/robert/anaconda3/lib/python3.9/site-packages (from requests->cebra) (2022.12.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/robert/anaconda3/lib/python3.9/site-packages (from scikit-learn->cebra) (3.1.0)
# Requirement already satisfied: filelock in /home/robert/anaconda3/lib/python3.9/site-packages (from torch->cebra) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/robert/anaconda3/lib/python3.9/site-packages (from torch->cebra) (4.9.0)
# Requirement already satisfied: sympy in /home/robert/anaconda3/lib/python3.9/site-packages (from torch->cebra) (1.10.1)
# Requirement already satisfied: networkx in /home/robert/anaconda3/lib/python3.9/site-packages (from torch->cebra) (3.1)
# Requirement already satisfied: jinja2 in /home/robert/anaconda3/lib/python3.9/site-packages (from torch->cebra) (3.1.2)
# Requirement already satisfied: fsspec in /home/robert/anaconda3/lib/python3.9/site-packages (from torch->cebra) (2024.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/robert/anaconda3/lib/python3.9/site-packages (from torch->cebra) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/robert/anaconda3/lib/python3.9/site-packages (from torch->cebra) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/robert/anaconda3/lib/python3.9/site-packages (from torch->cebra) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/robert/anaconda3/lib/python3.9/site-packages (from torch->cebra) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/robert/anaconda3/lib/python3.9/site-packages (from torch->cebra) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/robert/anaconda3/lib/python3.9/site-packages (from torch->cebra) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/robert/anaconda3/lib/python3.9/site-packages (from torch->cebra) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/robert/anaconda3/lib/python3.9/site-packages (from torch->cebra) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/robert/anaconda3/lib/python3.9/site-packages (from torch->cebra) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/robert/anaconda3/lib/python3.9/site-packages (from torch->cebra) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/robert/anaconda3/lib/python3.9/site-packages (from torch->cebra) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/robert/anaconda3/lib/python3.9/site-packages (from torch->cebra) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/robert/anaconda3/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->cebra) (12.3.101)
# Requirement already satisfied: zipp>=3.1.0 in /home/robert/anaconda3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->cebra) (3.11.0)
# Requirement already satisfied: six>=1.5 in /home/robert/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->cebra) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/robert/anaconda3/lib/python3.9/site-packages (from jinja2->torch->cebra) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /home/robert/anaconda3/lib/python3.9/site-packages (from sympy->torch->cebra) (1.2.1)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: elephant in /home/robert/anaconda3/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: neo>=0.10.0 in /home/robert/anaconda3/lib/python3.9/site-packages (from elephant) (0.11.1)
# Requirement already satisfied: numpy>=1.18.1 in /home/robert/anaconda3/lib/python3.9/site-packages (from elephant) (1.23.5)
# Requirement already satisfied: quantities>=0.12.1 in /home/robert/anaconda3/lib/python3.9/site-packages (from elephant) (0.13.0)
# Requirement already satisfied: scipy>=1.5.4 in /home/robert/anaconda3/lib/python3.9/site-packages (from elephant) (1.12.0)
# Requirement already satisfied: six>=1.10.0 in /home/robert/anaconda3/lib/python3.9/site-packages (from elephant) (1.16.0)
# Requirement already satisfied: tqdm in /home/robert/anaconda3/lib/python3.9/site-packages (from elephant) (4.65.0)
# Requirement already satisfied: packaging in /home/robert/anaconda3/lib/python3.9/site-packages (from neo>=0.10.0->elephant) (23.1)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# 2024-05-01 13:56:01.780098: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/robert/anaconda3/lib/python3.9/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/robert/anaconda3/lib/python3.9/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/robert/anaconda3/lib/python3.9/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/robert/anaconda3/lib/python3.9/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()

# %% [markdown]
# ## Load the data

# %%
# !wget -nc https://dataverse.harvard.edu/api/access/datafile/7609512 -O rat_data.pkl

with open('rat_data.pkl', 'rb') as handle:
    hippocampus_pos = pickle.load(handle)
    
rat = 'achilles'
hippocampus_pos = hippocampus_pos[rat]
# Out:
# File ‘rat_data.pkl’ already there; not retrieving.

# %% [markdown]
# ## Train the models
#
# *[This can be skipped if you already saved the models].*

# %% [markdown]
# - For a quick CEBRA CPU run-time demo, you can drop `max_iterations` to 100-500; otherwise set to 5000.

# %%
max_iterations = 10000
output_dimension = 32 #here, we set as a variable for hypothesis testing below.

# %%
# defining train and test splits of the data

def split_data(data, test_ratio):

    split_idx = int(data['neural'].shape[0] * (1-test_ratio))
    neural_train = data['neural'][:split_idx]
    neural_test = data['neural'][split_idx:]
    label_train = data['continuous_index'][:split_idx]
    label_test = data['continuous_index'][split_idx:]
    
    return neural_train.numpy(), neural_test.numpy(), label_train.numpy(), label_test.numpy()

neural_train, neural_test, label_train, label_test = split_data(hippocampus_pos, 0.2)

# %%
# 40 hz sampling rate (they binned into 25ms epochs

spikes = neural_train[:2000,:].T
spikes = [np.where(spikes[ch,:])[0]/40 for ch in range(120)] 
    
_, ax = plt.subplots(figsize=(8,4))
ax.eventplot(spikes,color='gray')
plt.ylabel('Neurons')
plt.xlabel('Time (s)')
plt.savefig('raster_plot.svg')

# %% [markdown]
# ### Train CEBRA-Behavior with position, or direction, and/or both variables

# %%
cebra_time_model = CEBRA(model_architecture='offset10-model',
                        batch_size=512,
                        learning_rate=3e-4,
                        temperature=1,
                        output_dimension=output_dimension,
                        max_iterations=max_iterations,
                        distance='cosine',
                        conditional='time',
                        device='cuda_if_available',
                        verbose=True,
                        time_offsets=10)

cebra_posdir_model = CEBRA(model_architecture='offset10-model',
                        batch_size=512,
                        learning_rate=3e-4,
                        temperature=1,
                        output_dimension=output_dimension,
                        max_iterations=max_iterations,
                        distance='cosine',
                        conditional='time_delta',
                        device='cuda_if_available',
                        verbose=True,
                        time_offsets=10)

cebra_pos_model = CEBRA(model_architecture='offset10-model',
                        batch_size=512,
                        learning_rate=3e-4,
                        temperature=1,
                        output_dimension=output_dimension,
                        max_iterations=max_iterations,
                        distance='cosine',
                        conditional='time_delta',
                        device='cuda_if_available',
                        verbose=True,
                        time_offsets=10)

cebra_dir_model = CEBRA(model_architecture='offset10-model',
                        batch_size=512,
                        learning_rate=3e-4,
                        temperature=1,
                        output_dimension=output_dimension,
                        max_iterations=max_iterations,
                        distance='cosine',
                        device='cuda_if_available',
                        verbose=True)

# %%
# Train CEBRA-Behavior models with both position and direction variables.
cebra_time_model.fit(neural_train)
cebra_time_model.save("cebra_time_model.pt")

# Train CEBRA-Behavior models with both position and direction variables.
cebra_posdir_model.fit(neural_train, label_train)
cebra_posdir_model.save("cebra_posdir_model.pt")

# Train CEBRA-Behavior models with position or direction variable.
cebra_pos_model.fit(neural_train, label_train[:,0])
cebra_pos_model.save("cebra_pos_model.pt")

cebra_dir_model.fit(neural_train, label_train[:,1])
cebra_dir_model.save("cebra_dir_model.pt")
# Out:
# pos: -0.8851 neg:  6.3849 total:  5.4997 temperature:  1.0000: 100%|█| 10000/100
# pos: -0.8866 neg:  6.4968 total:  5.6102 temperature:  1.0000: 100%|█| 10000/100
# pos: -0.8173 neg:  6.4704 total:  5.6531 temperature:  1.0000: 100%|█| 10000/100

# %%
neural_train

# %% [markdown]
# ### Train MARBLE with only neural data

# %%
# build model 
data_train, label_train_marble, pca = prepare_marble(neural_train.T, label_train, pca_n=20)

# build model
params = {
    "epochs": 100,
    "order": 1,  # order of derivatives
    "lr": 1,
    "batch_size": 64,
    "hidden_channels": [64],  # number of internal dimensions in MLP
    "out_channels": 32, 
    "inner_product_features": False,
    "emb_norm": True, # spherical output embedding
    "diffusion": False,
    "include_positions": True,
  }
model = MARBLE.net(data_train, params=params)

# run training of model
model.fit(data_train, outdir=f"hippocampus_{rat}")

# evaluate embedding on training data
data_train = model.transform(data_train)
# Out:
# [0.25057016 0.1686058  0.08780102 0.07304726 0.0413553  0.03523341
#  0.0322533  0.02940006 0.01651668 0.015887   0.01519323 0.01326354
#  0.01250465 0.01037483 0.0098495  0.0093985  0.00848823 0.00836819
#  0.00745799 0.00724018]
#
# ---- Embedding dimension: 20
# ---- Signal dimension: 20
# ---- Computing kernels ...
# ---- Settings:
#
# epochs : 100
# order : 1
# lr : 1
# batch_size : 64
# hidden_channels : [64]
# out_channels : 32
# inner_product_features : False
# emb_norm : True
# diffusion : False
# include_positions : True
# momentum : 0.9
# frac_sampled_nb : -1
# include_self : True
# dropout : 0.0
# vec_norm : False
# bias : True
# batch_norm : batch_norm
# seed : 0
# dim_signal : 20
# dim_emb : 20
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  440
# ---- Total number of parameters:  30433
#
# Using device cuda:0
#
# ---- Training network ...
#
# ---- Timestamp: 20231207-115006
#
# Epoch: 0, Training loss: 1.048879, Validation loss: 1.0368, lr: 1.0000 *
# Epoch: 1, Training loss: 1.046898, Validation loss: 1.0439, lr: 1.0000
# Epoch: 2, Training loss: 1.035058, Validation loss: 1.0338, lr: 1.0000 *
# Epoch: 3, Training loss: 1.041671, Validation loss: 1.0229, lr: 1.0000 *
# Epoch: 4, Training loss: 1.034364, Validation loss: 1.0410, lr: 1.0000
# Epoch: 5, Training loss: 1.035926, Validation loss: 1.0340, lr: 1.0000
# Epoch: 6, Training loss: 1.032379, Validation loss: 1.0487, lr: 1.0000
# Epoch: 7, Training loss: 1.037436, Validation loss: 1.0528, lr: 1.0000
# Epoch: 8, Training loss: 1.030223, Validation loss: 1.0491, lr: 1.0000
# Epoch: 9, Training loss: 1.028747, Validation loss: 1.0376, lr: 1.0000
# Epoch: 10, Training loss: 1.030970, Validation loss: 1.0221, lr: 1.0000 *
# Epoch: 11, Training loss: 1.033811, Validation loss: 1.0265, lr: 1.0000
# Epoch: 12, Training loss: 1.029497, Validation loss: 1.0328, lr: 1.0000
# Epoch: 13, Training loss: 1.030361, Validation loss: 1.0432, lr: 1.0000
# Epoch: 14, Training loss: 1.031887, Validation loss: 1.0467, lr: 1.0000
# Epoch: 15, Training loss: 1.034174, Validation loss: 1.0398, lr: 1.0000
# Epoch: 16, Training loss: 1.034855, Validation loss: 1.0397, lr: 1.0000
# Epoch: 17, Training loss: 1.033444, Validation loss: 1.0373, lr: 1.0000
# Epoch: 18, Training loss: 1.031320, Validation loss: 1.0397, lr: 1.0000
# Epoch: 19, Training loss: 1.034372, Validation loss: 1.0466, lr: 1.0000
# Epoch: 20, Training loss: 1.033167, Validation loss: 1.0380, lr: 0.1000
# Epoch: 21, Training loss: 1.031041, Validation loss: 1.0302, lr: 0.1000
# Epoch: 22, Training loss: 1.025192, Validation loss: 1.0331, lr: 0.1000
# Epoch: 23, Training loss: 1.032857, Validation loss: 1.0307, lr: 0.1000
# Epoch: 24, Training loss: 1.027110, Validation loss: 1.0334, lr: 0.1000
# Epoch: 25, Training loss: 1.030627, Validation loss: 1.0231, lr: 0.1000
# Epoch: 26, Training loss: 1.031080, Validation loss: 1.0242, lr: 0.1000
# Epoch: 27, Training loss: 1.034357, Validation loss: 1.0361, lr: 0.1000
# Epoch: 28, Training loss: 1.030517, Validation loss: 1.0321, lr: 0.1000
# Epoch: 29, Training loss: 1.029411, Validation loss: 1.0405, lr: 0.1000
# Epoch: 30, Training loss: 1.028132, Validation loss: 1.0345, lr: 0.1000
# Epoch: 31, Training loss: 1.032014, Validation loss: 1.0368, lr: 0.1000
# Epoch: 32, Training loss: 1.027640, Validation loss: 1.0278, lr: 0.1000
# Epoch: 33, Training loss: 1.031645, Validation loss: 1.0370, lr: 0.0100
# Epoch: 34, Training loss: 1.035127, Validation loss: 1.0386, lr: 0.0100
# Epoch: 35, Training loss: 1.035836, Validation loss: 1.0308, lr: 0.0100
# Epoch: 36, Training loss: 1.029427, Validation loss: 1.0367, lr: 0.0100
# Epoch: 37, Training loss: 1.033293, Validation loss: 1.0471, lr: 0.0100
# Epoch: 38, Training loss: 1.032153, Validation loss: 1.0414, lr: 0.0100
# Epoch: 39, Training loss: 1.030412, Validation loss: 1.0280, lr: 0.0100
# Epoch: 40, Training loss: 1.029988, Validation loss: 1.0309, lr: 0.0100
# Epoch: 41, Training loss: 1.033470, Validation loss: 1.0345, lr: 0.0100
# Epoch: 42, Training loss: 1.027869, Validation loss: 1.0350, lr: 0.0100
# Epoch: 43, Training loss: 1.032796, Validation loss: 1.0252, lr: 0.0100
# Epoch: 44, Training loss: 1.033672, Validation loss: 1.0329, lr: 0.0010
# Epoch: 45, Training loss: 1.030418, Validation loss: 1.0322, lr: 0.0010
# Epoch: 46, Training loss: 1.033013, Validation loss: 1.0268, lr: 0.0010
# Epoch: 47, Training loss: 1.028700, Validation loss: 1.0322, lr: 0.0010
# Epoch: 48, Training loss: 1.033967, Validation loss: 1.0364, lr: 0.0010
# Epoch: 49, Training loss: 1.030001, Validation loss: 1.0401, lr: 0.0010
# Epoch: 50, Training loss: 1.032214, Validation loss: 1.0382, lr: 0.0010
# Epoch: 51, Training loss: 1.031632, Validation loss: 1.0336, lr: 0.0010
# Epoch: 52, Training loss: 1.027551, Validation loss: 1.0325, lr: 0.0010
# Epoch: 53, Training loss: 1.033328, Validation loss: 1.0218, lr: 0.0010 *
# Epoch: 54, Training loss: 1.033937, Validation loss: 1.0383, lr: 0.0010
# Epoch: 55, Training loss: 1.029924, Validation loss: 1.0263, lr: 0.0001
# Epoch: 56, Training loss: 1.031953, Validation loss: 1.0345, lr: 0.0001
# Epoch: 57, Training loss: 1.031902, Validation loss: 1.0251, lr: 0.0001
# Epoch: 58, Training loss: 1.036429, Validation loss: 1.0358, lr: 0.0001
# Epoch: 59, Training loss: 1.030225, Validation loss: 1.0355, lr: 0.0001
# Epoch: 60, Training loss: 1.028622, Validation loss: 1.0267, lr: 0.0001
# Epoch: 61, Training loss: 1.033846, Validation loss: 1.0254, lr: 0.0001
# Epoch: 62, Training loss: 1.027993, Validation loss: 1.0295, lr: 0.0001
# Epoch: 63, Training loss: 1.028092, Validation loss: 1.0241, lr: 0.0001
# Epoch: 64, Training loss: 1.028560, Validation loss: 1.0512, lr: 0.0001
# Epoch: 65, Training loss: 1.030426, Validation loss: 1.0356, lr: 0.0001
# Epoch: 66, Training loss: 1.033303, Validation loss: 1.0324, lr: 0.0000
# Epoch: 67, Training loss: 1.030879, Validation loss: 1.0256, lr: 0.0000
# Epoch: 68, Training loss: 1.026878, Validation loss: 1.0329, lr: 0.0000
# Epoch: 69, Training loss: 1.032698, Validation loss: 1.0346, lr: 0.0000
# Epoch: 70, Training loss: 1.031909, Validation loss: 1.0412, lr: 0.0000
# Epoch: 71, Training loss: 1.032692, Validation loss: 1.0388, lr: 0.0000
# Epoch: 72, Training loss: 1.029367, Validation loss: 1.0287, lr: 0.0000
# Epoch: 73, Training loss: 1.031454, Validation loss: 1.0316, lr: 0.0000
# Epoch: 74, Training loss: 1.035800, Validation loss: 1.0348, lr: 0.0000
# Epoch: 75, Training loss: 1.028421, Validation loss: 1.0372, lr: 0.0000
# Epoch: 76, Training loss: 1.030380, Validation loss: 1.0340, lr: 0.0000
# Epoch: 77, Training loss: 1.026892, Validation loss: 1.0414, lr: 0.0000
# Epoch: 78, Training loss: 1.032647, Validation loss: 1.0309, lr: 0.0000
# Epoch: 79, Training loss: 1.031345, Validation loss: 1.0198, lr: 0.0000 *
# Epoch: 80, Training loss: 1.031073, Validation loss: 1.0349, lr: 0.0000
# Epoch: 81, Training loss: 1.031154, Validation loss: 1.0233, lr: 0.0000
# Epoch: 82, Training loss: 1.028389, Validation loss: 1.0531, lr: 0.0000
# Epoch: 83, Training loss: 1.031282, Validation loss: 1.0423, lr: 0.0000
# Epoch: 84, Training loss: 1.034727, Validation loss: 1.0226, lr: 0.0000
# Epoch: 85, Training loss: 1.031866, Validation loss: 1.0301, lr: 0.0000
# Epoch: 86, Training loss: 1.035604, Validation loss: 1.0283, lr: 0.0000
# Epoch: 87, Training loss: 1.023836, Validation loss: 1.0477, lr: 0.0000
# Epoch: 88, Training loss: 1.032533, Validation loss: 1.0534, lr: 0.0000
# Epoch: 89, Training loss: 1.032333, Validation loss: 1.0329, lr: 0.0000
# Epoch: 90, Training loss: 1.030186, Validation loss: 1.0376, lr: 0.0000
# Epoch: 91, Training loss: 1.025157, Validation loss: 1.0410, lr: 0.0000
# Epoch: 92, Training loss: 1.030561, Validation loss: 1.0497, lr: 0.0000
# Epoch: 93, Training loss: 1.028093, Validation loss: 1.0341, lr: 0.0000
# Epoch: 94, Training loss: 1.028655, Validation loss: 1.0432, lr: 0.0000
# Epoch: 95, Training loss: 1.035071, Validation loss: 1.0318, lr: 0.0000
# Epoch: 96, Training loss: 1.030847, Validation loss: 1.0485, lr: 0.0000
# Epoch: 97, Training loss: 1.032514, Validation loss: 1.0359, lr: 0.0000
# Epoch: 98, Training loss: 1.032207, Validation loss: 1.0362, lr: 0.0000
# Epoch: 99, Training loss: 1.032704, Validation loss: 1.0367, lr: 0.0000
# Final test loss: 1.0297

# %%
# build model 
data_test, label_test_marble, _ = prepare_marble(neural_test.T, label_test, pca=pca)

# generate embedding of test data
data_test = model.transform(data_test)
# Out:
# [0.25057016 0.1686058  0.08780102 0.07304726 0.0413553  0.03523341
#  0.0322533  0.02940006 0.01651668 0.015887   0.01519323 0.01326354
#  0.01250465 0.01037483 0.0098495  0.0093985  0.00848823 0.00836819
#  0.00745799 0.00724018]
#
# ---- Embedding dimension: 20
# ---- Signal dimension: 20
# ---- Computing kernels ...

# %% [markdown]
# # Compare embeddings after training

# %%
#%matplotlib notebook

fig = plt.figure(figsize=(10,6))

ax1 = plt.subplot(221, projection='3d')
ax=cebra.plot_embedding(ax=ax1, embedding=data_train.emb, embedding_labels=label_train_marble[:,0], markersize=0.2, title='MARBLE-train')

ax2 = plt.subplot(222, projection='3d')
ax=cebra.plot_embedding(ax=ax2, embedding=data_test.emb, embedding_labels=label_test_marble[:,0], markersize=0.2, title='MARBLE-test')

ax3 = plt.subplot(223, projection='3d')
ax=cebra.plot_embedding(ax=ax3, embedding=cebra_time_train, embedding_labels=label_train[:,0], markersize=0.2, title='CEBRA-time-train')

ax4 = plt.subplot(224, projection='3d')
ax=cebra.plot_embedding(ax=ax4, embedding=cebra_time_test, embedding_labels=label_test[:,0], markersize=0.2, title='CEBRA-time-test')
    
plt.show()

# %% [markdown]
# **------------------- END OF TRAINING SECTION -------------------**
#
# ## Load the models and get the corresponding embeddings

# %% [markdown]
# Load the CEBRA models

# %%
# We get train set embedding and test set embedding. 

# !wget -nc https://dataverse.harvard.edu/api/access/datafile/7609517 -O cebra_time_model.pt
# !wget -nc https://dataverse.harvard.edu/api/access/datafile/7609520 -O cebra_posdir_model.pt
# !wget -nc https://dataverse.harvard.edu/api/access/datafile/7609519 -O cebra_pos_model.pt
# !wget -nc https://dataverse.harvard.edu/api/access/datafile/7609518 -O cebra_dir_model.pt

cebra_time_model = cebra.CEBRA.load("cebra_time_model.pt")
cebra_time_train = cebra_time_model.transform(neural_train)
cebra_time_test = cebra_time_model.transform(neural_test)

cebra_posdir_model = cebra.CEBRA.load("cebra_posdir_model.pt")
cebra_posdir_train = cebra_posdir_model.transform(neural_train)
cebra_posdir_test = cebra_posdir_model.transform(neural_test)

cebra_pos_model = cebra.CEBRA.load("cebra_pos_model.pt")
cebra_pos_train = cebra_pos_model.transform(neural_train)
cebra_pos_test = cebra_pos_model.transform(neural_test)

cebra_dir_model = cebra.CEBRA.load("cebra_dir_model.pt")
cebra_dir_train = cebra_dir_model.transform(neural_train)
cebra_dir_test = cebra_dir_model.transform(neural_test)

cebra_time_all = cebra_time_model.transform(hippocampus_pos['neural'])
cebra_pos_all = cebra_pos_model.transform(hippocampus_pos['neural'])
cebra_dir_all = cebra_dir_model.transform(hippocampus_pos['neural'])
cebra_posdir_all = cebra_posdir_model.transform(hippocampus_pos['neural'])
# Out:
# File ‘cebra_time_model.pt’ already there; not retrieving.
# File ‘cebra_posdir_model.pt’ already there; not retrieving.
# File ‘cebra_pos_model.pt’ already there; not retrieving.
# File ‘cebra_dir_model.pt’ already there; not retrieving.

# %% [markdown]
# Load MARBLE models

# %%
# load MARBLE

# !wget -nc https://dataverse.harvard.edu/api/access/datafile/7659512 -O hippocampus_achilles/best_model_20231207-115006.pth

# process data
data_train, label_train_marble, pca = prepare_marble(neural_train.T, label_train, pca_n=20)
data_test, label_test_marble, _ = prepare_marble(neural_test.T, label_test, pca=pca)

# load trained model
marble_model = MARBLE.net(data_train, loadpath=f"hippocampus_{rat}")

# generate embedding of test data
data_train = marble_model.transform(data_train)
data_test = marble_model.transform(data_test)
# Out:
# File ‘hippocampus_achilles/best_model_20231207-115006.pth’ already there; not retrieving.
# [0.25057016 0.1686058  0.08780102 0.07304726 0.0413553  0.03523341
#  0.0322533  0.02940006 0.0165167  0.01588696 0.01519331 0.01326315
#  0.01250321 0.01037414 0.00984861 0.00939964 0.00849119 0.00836416
#  0.00745384 0.00721608]
#
# ---- Embedding dimension: 20
# ---- Signal dimension: 20
# ---- Computing kernels ... [0.25057016 0.1686058  0.08780102 0.07304726 0.0413553  0.03523341
#  0.0322533  0.02940006 0.0165167  0.01588696 0.01519331 0.01326315
#  0.01250321 0.01037414 0.00984861 0.00939964 0.00849119 0.00836416
#  0.00745384 0.00721608]
#
# ---- Embedding dimension: 20
# ---- Signal dimension: 20
# ---- Computing kernels ...
# ---- Settings:
#
# epochs : 100
# order : 1
# lr : 1
# batch_size : 64
# hidden_channels : [64]
# out_channels : 32
# inner_product_features : False
# emb_norm : True
# diffusion : False
# include_positions : True
# momentum : 0.9
# frac_sampled_nb : -1
# include_self : True
# dropout : 0.0
# vec_norm : False
# bias : True
# batch_norm : batch_norm
# seed : 0
# dim_signal : 20
# dim_emb : 20
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  440
# ---- Total number of parameters:  30433
#
# Using device cuda:0

# %% [markdown]
# ### Visualise the embeddings in 3D

# %%
#%matplotlib notebook

fig = plt.figure(figsize=(10,6))

ax1 = plt.subplot(221, projection='3d')
ax=cebra.plot_embedding(ax=ax1, embedding=data_train.emb, embedding_labels=label_train_marble[:,0], markersize=0.2, title='MARBLE-train')

ax2 = plt.subplot(222, projection='3d')
ax=cebra.plot_embedding(ax=ax2, embedding=data_test.emb, embedding_labels=label_test_marble[:,0], markersize=0.2, title='MARBLE-test')

ax3 = plt.subplot(223, projection='3d')
ax=cebra.plot_embedding(ax=ax3, embedding=cebra_time_train, embedding_labels=label_train[:,0], markersize=0.2, title='CEBRA-time-train')

ax4 = plt.subplot(224, projection='3d')
ax=cebra.plot_embedding(ax=ax4, embedding=cebra_time_test, embedding_labels=label_test[:,0], markersize=0.2, title='CEBRA-time-test')

plt.savefig('marble_cebra_embeddings_3D_32output.png')  
plt.show()

# %% [markdown]
# ## Decode the labels from the embeddings
# We evaluate decoding performance of the different hypothesis models.

# %%
from rat_utils import find_sequences, decoding_pos_dir
import pandas as pd
import seaborn as sns
from statannotations.Annotator import Annotator

# %% [markdown]
# ### Decode the position and direction from the trained hypothesis models

# %%
cebra_time_decode = decoding_pos_dir(cebra_time_train, cebra_time_test, label_train, label_test)
cebra_posdir_decode = decoding_pos_dir(cebra_posdir_train, cebra_posdir_test, label_train, label_test)
cebra_pos_decode = decoding_pos_dir(cebra_pos_train, cebra_pos_test, label_train, label_test)
cebra_dir_decode = decoding_pos_dir(cebra_dir_train, cebra_dir_test, label_train, label_test)
marble_decode = decoding_pos_dir(data_train.emb, data_test.emb, label_train_marble, label_test_marble)

# %% [markdown]
# ### Visualize the decoding results and loss - decoding performance

# %%
results = [cebra_time_decode[4][:-1], cebra_posdir_decode[4][:-1],  cebra_pos_decode[4][:-1], #cebra_dir_decode[5],
        marble_decode[4]]

results = pd.DataFrame(data=np.vstack(results).T,columns=['c-time','c-pos+dir', 'c-pos', 'marble'])
results = results.melt()
results.columns = ['model','accuracy']

f, ax = plt.subplots(figsize=(4,4))
sns.despine(bottom=True, left=True)

random_sampling = np.random.randint(low=0, high=results.shape[0], size=(200,))

sns.stripplot(
    data=results.iloc[random_sampling,:], x="model", y="accuracy", order=['c-time','c-pos+dir', 'c-pos', 'marble'], 
    dodge=True, alpha=.5, zorder=1, color='gray',
)

sns.pointplot(
    data=results, x="model", y="accuracy",
    join=False, dodge=.8 - .8 / 3, palette="dark",
    markers="d", scale=.75, errorbar=None
)

pairs=[("c-time", "marble"),
      ("c-pos+dir", "marble"),
      ("c-pos", "marble"),
      ]

annotator = Annotator(ax, pairs, data=results, x="model", y="accuracy",)
annotator.configure(test='Wilcoxon', text_format='star', loc='outside')
annotator.apply_and_annotate()
plt.tight_layout()
plt.savefig('decoding_accuracy_rat_32output_violin.svg')
# Out:
# /home/robert/anaconda3/lib/python3.9/site-packages/statannotations/_Plotter.py:337: UserWarning: Invalid x-position found. Are the same parameters passed to seaborn and statannotations calls? or are there few data points?
#   warnings.warn(
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# c-pos vs. marble: Wilcoxon test (paired samples), P_val:1.230e-22 Stat=7.468e+05
# c-pos+dir vs. marble: Wilcoxon test (paired samples), P_val:4.131e-29 Stat=7.105e+05
# c-time vs. marble: Wilcoxon test (paired samples), P_val:5.141e-113 Stat=4.164e+05

# %%
from scipy.stats import sem

fig = plt.figure(figsize=(10,4))

ax1= plt.subplot(121)
ax1.bar(np.arange(5), 
        [cebra_time_decode[1], cebra_posdir_decode[1],  cebra_pos_decode[1], cebra_dir_decode[1],
        marble_decode[1]], 
        width = 0.5, color = 'gray')

ax1.errorbar(np.arange(5),  
             [cebra_time_decode[1], cebra_posdir_decode[1],  cebra_pos_decode[1], cebra_dir_decode[1],
             marble_decode[1]],
             yerr=[sem(cebra_time_decode[4]), sem(cebra_posdir_decode[4]),  
                   sem(cebra_pos_decode[4]), sem(cebra_dir_decode[4]),
                   sem(marble_decode[4])], 
             fmt='none', ecolor='black', capsize=5)


ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.set_xticks(np.arange(5))
ax1.set_xticklabels(['time','pos+dir', 'pos', 'dir','marble'])
ax1.set_ylabel('Median err. [m]')


plt.legend(bbox_to_anchor=(1,1), frameon = False )
plt.savefig('decoding_accuracy_rat_32output_standarderror.svg')  
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig = plt.figure(figsize=(5,6))

t = label_test_marble[:,0].shape[0]

ax1= plt.subplot(311)
ax1.plot(np.arange(t)/40, label_test_marble[:,0])
ax1.plot(np.arange(t)/40, marble_decode[3][:,0])
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Position [m]')
ax1.set_title('MARBLE')

ax2= plt.subplot(312)
ax2.plot(np.arange(t)/40, label_test_marble[:,0])
ax2.plot(np.arange(t+1)/40, cebra_time_decode[3][:,0])
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.set_xlabel('Time [s]')
ax2.set_ylabel('Position [m]')
ax2.set_title('CEBRA (time)')

ax3 = plt.subplot(313)
ax3.plot(np.arange(t)/40, label_test_marble[:,0])
ax3.plot(np.arange(t+1)/40, cebra_pos_decode[3][:,0])
ax3.spines['top'].set_visible(False)
ax3.spines['right'].set_visible(False)
ax3.set_xlabel('Time [s]')
ax3.set_ylabel('Position [m]')
ax3.set_title('CEBRA (position)')

plt.savefig('decoding_vs_groundtruth_32output.svg')  


plt.tight_layout()

# %% [markdown]
# ## Robustness vs number of PCA components

# %% [markdown]
# ### Training for various PCA components

# %%
for pca_n in [3,5,10,20,30]:
    data_train, label_train_marble, pca = prepare_marble(neural_train.T, label_train, pca_n=pca_n)

    # build model
    params = {
        "epochs": 100,
        "order": 1,  # order of derivatives
        "lr": 1,
        "batch_size": 64,
        "hidden_channels": [64],  # number of internal dimensions in MLP
        "out_channels": 32, 
        "inner_product_features": False,
        "emb_norm": True, # spherical output embedding
        "diffusion": False,
        "include_positions": True,
      }
    model = MARBLE.net(data_train, params=params)

    # run training of model
    model.fit(data_train, outdir=f"hippocampus_{rat}_pca{pca_n}")

# %%
training = []
testing = []
labels_train = []
labels_test = []

for i, pca_n in enumerate([3, 5, 10, 20, 30]):
    data_train, label_train_marble, pca = prepare_marble(neural_train.T, label_train, pca_n=pca_n)
    data_test, label_test_marble, _ = prepare_marble(neural_test.T, label_test, pca=pca)
    marble_model = MARBLE.net(data_train, loadpath=f"hippocampus_{rat}_pca{pca_n}")
    
    data_train = marble_model.transform(data_train)
    data_test = marble_model.transform(data_test)
    
    training.append(data_train)
    testing.append(data_test)
    labels_train.append(label_train_marble)
    labels_test.append(label_test_marble)
# Out:
# [0.25057016 0.1686058  0.08780102]
#
# ---- Embedding dimension: 3
# ---- Signal dimension: 3
# ---- Computing kernels ... [0.25057016 0.1686058  0.08780102]
#
# ---- Embedding dimension: 3
# ---- Signal dimension: 3
# ---- Computing kernels ...
# ---- Settings:
#
# epochs : 100
# order : 1
# lr : 1
# batch_size : 64
# hidden_channels : [64]
# out_channels : 32
# inner_product_features : False
# emb_norm : True
# diffusion : False
# include_positions : True
# momentum : 0.9
# dropout : 0.0
# batch_norm : batch_norm
# bias : True
# frac_sampled_nb : -1
# include_self : True
# vec_norm : False
# seed : 0
# dim_signal : 3
# dim_emb : 3
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  15
# ---- Total number of parameters:  3233
#
# Using device cuda:0
# [0.25057016 0.1686058  0.08780102 0.07304726 0.0413553 ]
#
# ---- Embedding dimension: 5
# ---- Signal dimension: 5
# ---- Computing kernels ... [0.25057016 0.1686058  0.08780102 0.07304726 0.0413553 ]
#
# ---- Embedding dimension: 5
# ---- Signal dimension: 5
# ---- Computing kernels ...
# ---- Settings:
#
# epochs : 100
# order : 1
# lr : 1
# batch_size : 64
# hidden_channels : [64]
# out_channels : 32
# inner_product_features : False
# emb_norm : True
# diffusion : False
# include_positions : True
# momentum : 0.9
# dropout : 0.0
# batch_norm : batch_norm
# bias : True
# frac_sampled_nb : -1
# include_self : True
# vec_norm : False
# seed : 0
# dim_signal : 5
# dim_emb : 5
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  35
# ---- Total number of parameters:  4513
#
# Using device cuda:0
# [0.25057016 0.1686058  0.08780102 0.07304726 0.0413553  0.03523341
#  0.0322533  0.02940006 0.01651661 0.01588701]
#
# ---- Embedding dimension: 10
# ---- Signal dimension: 10
# ---- Computing kernels ... [0.25057016 0.1686058  0.08780102 0.07304726 0.0413553  0.03523341
#  0.0322533  0.02940006 0.01651661 0.01588701]
#
# ---- Embedding dimension: 10
# ---- Signal dimension: 10
# ---- Computing kernels ...
# ---- Settings:
#
# epochs : 100
# order : 1
# lr : 1
# batch_size : 64
# hidden_channels : [64]
# out_channels : 32
# inner_product_features : False
# emb_norm : True
# diffusion : False
# include_positions : True
# momentum : 0.9
# dropout : 0.0
# batch_norm : batch_norm
# bias : True
# frac_sampled_nb : -1
# include_self : True
# vec_norm : False
# seed : 0
# dim_signal : 10
# dim_emb : 10
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  120
# ---- Total number of parameters:  9953
#
# Using device cuda:0
# [0.25057016 0.1686058  0.08780102 0.07304726 0.0413553  0.03523341
#  0.0322533  0.02940006 0.01651648 0.015887   0.01519328 0.01326354
#  0.01250446 0.01037316 0.00984752 0.00939874 0.00849173 0.00834865
#  0.00744254 0.00723268]
#
# ---- Embedding dimension: 20
# ---- Signal dimension: 20
# ---- Computing kernels ... [0.25057016 0.1686058  0.08780102 0.07304726 0.0413553  0.03523341
#  0.0322533  0.02940006 0.01651648 0.015887   0.01519328 0.01326354
#  0.01250446 0.01037316 0.00984752 0.00939874 0.00849173 0.00834865
#  0.00744254 0.00723268]
#
# ---- Embedding dimension: 20
# ---- Signal dimension: 20
# ---- Computing kernels ...
# ---- Settings:
#
# epochs : 100
# order : 1
# lr : 1
# batch_size : 64
# hidden_channels : [64]
# out_channels : 32
# inner_product_features : False
# emb_norm : True
# diffusion : False
# include_positions : True
# momentum : 0.9
# dropout : 0.0
# batch_norm : batch_norm
# bias : True
# frac_sampled_nb : -1
# include_self : True
# vec_norm : False
# seed : 0
# dim_signal : 20
# dim_emb : 20
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  440
# ---- Total number of parameters:  30433
#
# Using device cuda:0
# [0.25057016 0.1686058  0.08780102 0.07304726 0.0413553  0.03523341
#  0.0322533  0.02940006 0.0165167  0.01588705 0.01519335 0.0132637
#  0.01250475 0.01037554 0.00985093 0.00940075 0.00849615 0.00837021
#  0.00746428 0.00724552 0.00700574 0.00641215 0.00620791 0.00577044
#  0.0056197  0.00497215 0.00491121 0.00459126 0.00433955 0.00426037]
#
# ---- Embedding dimension: 30
# ---- Signal dimension: 30
# ---- Computing kernels ... [0.25057016 0.1686058  0.08780102 0.07304726 0.0413553  0.03523341
#  0.0322533  0.02940006 0.0165167  0.01588705 0.01519335 0.0132637
#  0.01250475 0.01037554 0.00985093 0.00940075 0.00849615 0.00837021
#  0.00746428 0.00724552 0.00700574 0.00641215 0.00620791 0.00577044
#  0.0056197  0.00497215 0.00491121 0.00459126 0.00433955 0.00426037]
#
# ---- Embedding dimension: 30
# ---- Signal dimension: 30
# ---- Computing kernels ...
# ---- Settings:
#
# epochs : 100
# order : 1
# lr : 1
# batch_size : 64
# hidden_channels : [64]
# out_channels : 32
# inner_product_features : False
# emb_norm : True
# diffusion : False
# include_positions : True
# momentum : 0.9
# dropout : 0.0
# batch_norm : batch_norm
# bias : True
# frac_sampled_nb : -1
# include_self : True
# vec_norm : False
# seed : 0
# dim_signal : 30
# dim_emb : 30
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  960
# ---- Total number of parameters:  63713
#
# Using device cuda:0

# %%
num_models = 5
num_plots_per_model = 2
fig = plt.figure(figsize=(20,12))


for i, pca_n in enumerate([3, 5, 10, 20, 30]):
    
    data_train = training[i]
    data_test = testing[i]
    label_train_marble = labels_train[i]
    label_test_marble = labels_test[i]

    # Calculate subplot index for training data
    ax1 = fig.add_subplot( num_plots_per_model, num_models, i+1, projection='3d')
    ax = cebra.plot_embedding(ax=ax1, embedding=data_train.emb, embedding_labels=label_train_marble[:,0], markersize=0.2, title=f'MARBLE-train_pca{pca_n}')
    
    # Calculate subplot index for testing data
    ax2 = fig.add_subplot(num_plots_per_model, num_models, num_models + i + 1, projection='3d')
    ax = cebra.plot_embedding(ax=ax2, embedding=data_test.emb, embedding_labels=label_test_marble[:,0], markersize=1, title=f'MARBLE-test_pca{pca_n}')

    
plt.tight_layout()
plt.savefig('marble_cebra_embeddings_3D_pca_scan.png')

# %%
results = [cebra_time_decode[4][:-1], cebra_posdir_decode[4][:-1],  cebra_pos_decode[4][:-1], ]
for i, pca_n in enumerate([3, 5, 10, 20, 30]):
    
    data_train = training[i]
    data_test = testing[i]
    label_train_marble = labels_train[i]
    label_test_marble = labels_test[i]
    
    marble_decode = decoding_pos_dir(data_train.emb, data_test.emb, label_train_marble, label_test_marble)
    results.append(marble_decode[4])
    
    
    
results = pd.DataFrame(data=np.vstack(results).T,columns=['c-time','c-pos+dir', 'c-pos','pca3','pca5','pca10','pca20','pca30',])
results = results.melt()
results.columns = ['model','accuracy']

f, ax = plt.subplots(figsize=(8,8))
sns.despine(bottom=True, left=True)

random_sampling = np.random.randint(low=0, high=results.shape[0], size=(200,))
order = ['c-time','c-pos+dir', 'c-pos','pca5','pca3','pca10','pca20','pca30',]
sns.stripplot(
    data=results.iloc[random_sampling,:], x="model", y="accuracy", order=order, 
    dodge=True, alpha=.5, zorder=1, color='gray',
)

sns.pointplot(
    data=results, x="model", y="accuracy",  order=order, 
    join=False, dodge=.8 - .8 / 3, palette="dark",
    markers="d", scale=.75, errorbar=None
)

plt.ylim([0,0.4])

pairs=[("c-time", "c-pos+dir"),
      ("c-pos+dir", "c-pos"),
      ("c-pos", "pca3"),
      ("pca3", "pca5"),
      ("pca5", "pca10"),
      ("pca10", "pca20"),
      ("pca20", "pca30"),]

# pairs=[("c-time", "pca3"),
#       ("c-pos+dir", "pca3"),
#       ("c-pos", "pca3"),
#         ("c-pos", "pca5"),
#       ("c-pos", "pca10"),
#       ("pca10", "pca20"),
#       ("pca20", "pca30"),]

annotator = Annotator(ax, pairs, data=results, x="model", y="accuracy",order=order)
annotator.configure(test='Wilcoxon', text_format='star', loc='outside')
annotator.apply_and_annotate()
plt.tight_layout()
plt.savefig('decoding_accuracy_rat_32output_violin_pcascan.svg')
# Out:
# /home/robert/anaconda3/lib/python3.9/site-packages/statannotations/_Plotter.py:337: UserWarning: Invalid x-position found. Are the same parameters passed to seaborn and statannotations calls? or are there few data points?
#   warnings.warn(
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# c-time vs. pca5: Wilcoxon test (paired samples), P_val:3.868e-30 Stat=7.051e+05
# pca5 vs. pca3: Wilcoxon test (paired samples), P_val:3.501e-12 Stat=8.200e+05
# pca3 vs. c-pos+dir: Wilcoxon test (paired samples), P_val:2.804e-14 Stat=8.032e+05
# c-pos+dir vs. c-pos: Wilcoxon test (paired samples), P_val:4.585e-02 Stat=9.480e+05
# c-pos vs. pca10: Wilcoxon test (paired samples), P_val:5.469e-10 Stat=8.393e+05
# pca10 vs. pca20: Wilcoxon test (paired samples), P_val:1.287e-01 Stat=9.603e+05
# pca20 vs. pca30: Wilcoxon test (paired samples), P_val:2.070e-02 Stat=9.398e+05

# %% [markdown]
# ## Robustness against kernel width

# %% [markdown]
# ### Training various kernel widths

# %%
pca_n = 20
for k_width in [3,5,10,20,30,50,100]:
    data_train, label_train_marble, pca = prepare_marble(neural_train.T, label_train, pca_n=pca_n, kernel_width=k_width)

    # build model
    params = {
        "epochs": 100,
        "order": 1,  # order of derivatives
        "lr": 1,
        "batch_size": 64,
        "hidden_channels": [64],  # number of internal dimensions in MLP
        "out_channels": 32, 
        "inner_product_features": False,
        "emb_norm": True, # spherical output embedding
        "diffusion": False,
        "include_positions": True,
      }
    model = MARBLE.net(data_train, params=params)

    # run training of model
    model.fit(data_train, outdir=f"hippocampus_{rat}_kw{k_width}")

# %% [markdown]
# ### Apply to test data

# %%
training = []
testing = []
labels_train = []
labels_test = []

pca_n = 20

for i, kw in enumerate([3, 5, 10, 20, 30, 50, 100]):
    data_train, label_train_marble, pca = prepare_marble(neural_train.T, label_train, pca_n=pca_n, kernel_width=kw)
    data_test, label_test_marble, _ = prepare_marble(neural_test.T, label_test, kernel_width=kw,  pca=pca)
    marble_model = MARBLE.net(data_train, loadpath=f"hippocampus_{rat}_kw{kw}")
    
    data_train = marble_model.transform(data_train)
    data_test = marble_model.transform(data_test)
    
    training.append(data_train)
    testing.append(data_test)
    labels_train.append(label_train_marble)
    labels_test.append(label_test_marble)
# Out:
# [0.16347239 0.11395487 0.07429479 0.06630238 0.04659378 0.04430051
#  0.03306965 0.03062078 0.02928631 0.02231647 0.01976047 0.0168498
#  0.01554817 0.01441089 0.01352547 0.01274285 0.01187038 0.01094064
#  0.01023263 0.00986046]
#
# ---- Embedding dimension: 20
# ---- Signal dimension: 20
# ---- Computing kernels ... [0.16347239 0.11395487 0.07429479 0.06630238 0.04659378 0.04430051
#  0.03306965 0.03062078 0.02928631 0.02231647 0.01976047 0.0168498
#  0.01554817 0.01441089 0.01352547 0.01274285 0.01187038 0.01094064
#  0.01023263 0.00986046]
#
# ---- Embedding dimension: 20
# ---- Signal dimension: 20
# ---- Computing kernels ...
# ---- Settings:
#
# epochs : 100
# order : 1
# lr : 1
# batch_size : 64
# hidden_channels : [64]
# out_channels : 32
# inner_product_features : False
# emb_norm : True
# diffusion : False
# include_positions : True
# momentum : 0.9
# dropout : 0.0
# batch_norm : batch_norm
# bias : True
# frac_sampled_nb : -1
# include_self : True
# vec_norm : False
# seed : 0
# dim_signal : 20
# dim_emb : 20
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  440
# ---- Total number of parameters:  30433
#
# Using device cuda:0
# [0.19404307 0.13318472 0.08309196 0.07230358 0.04775948 0.04411086
#  0.03274457 0.03110206 0.02682538 0.0192229  0.01807132 0.01544352
#  0.01470977 0.01242637 0.0120109  0.01131759 0.0103277  0.00983689
#  0.00857343 0.00828041]
#
# ---- Embedding dimension: 20
# ---- Signal dimension: 20
# ---- Computing kernels ... [0.19404307 0.13318472 0.08309196 0.07230358 0.04775948 0.04411086
#  0.03274457 0.03110206 0.02682538 0.0192229  0.01807132 0.01544352
#  0.01470977 0.01242637 0.0120109  0.01131759 0.0103277  0.00983689
#  0.00857343 0.00828041]
#
# ---- Embedding dimension: 20
# ---- Signal dimension: 20
# ---- Computing kernels ...
# ---- Settings:
#
# epochs : 100
# order : 1
# lr : 1
# batch_size : 64
# hidden_channels : [64]
# out_channels : 32
# inner_product_features : False
# emb_norm : True
# diffusion : False
# include_positions : True
# momentum : 0.9
# dropout : 0.0
# batch_norm : batch_norm
# bias : True
# frac_sampled_nb : -1
# include_self : True
# vec_norm : False
# seed : 0
# dim_signal : 20
# dim_emb : 20
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  440
# ---- Total number of parameters:  30433
#
# Using device cuda:0
# [0.25057016 0.1686058  0.08780102 0.07304726 0.0413553  0.03523341
#  0.0322533  0.02940006 0.0165167  0.01588703 0.01519333 0.01326289
#  0.01250468 0.0103732  0.00985003 0.00939981 0.00848931 0.00836822
#  0.00746004 0.00724405]
#
# ---- Embedding dimension: 20
# ---- Signal dimension: 20
# ---- Computing kernels ... [0.25057016 0.1686058  0.08780102 0.07304726 0.0413553  0.03523341
#  0.0322533  0.02940006 0.0165167  0.01588703 0.01519333 0.01326289
#  0.01250468 0.0103732  0.00985003 0.00939981 0.00848931 0.00836822
#  0.00746004 0.00724405]
#
# ---- Embedding dimension: 20
# ---- Signal dimension: 20
# ---- Computing kernels ...
# ---- Settings:
#
# epochs : 100
# order : 1
# lr : 1
# batch_size : 64
# hidden_channels : [64]
# out_channels : 32
# inner_product_features : False
# emb_norm : True
# diffusion : False
# include_positions : True
# momentum : 0.9
# dropout : 0.0
# batch_norm : batch_norm
# bias : True
# frac_sampled_nb : -1
# include_self : True
# vec_norm : False
# seed : 0
# dim_signal : 20
# dim_emb : 20
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  440
# ---- Total number of parameters:  30433
#
# Using device cuda:0
# [0.30733688 0.2095267  0.06905708 0.05243719 0.04208165 0.03824674
#  0.0222998  0.01775534 0.01665624 0.01440323 0.01254006 0.01217681
#  0.01045596 0.00966913 0.00894451 0.00838664 0.00813429 0.00731924
#  0.00697427 0.00674426]
#
# ---- Embedding dimension: 20
# ---- Signal dimension: 20
# ---- Computing kernels ... [0.30733688 0.2095267  0.06905708 0.05243719 0.04208165 0.03824674
#  0.0222998  0.01775534 0.01665624 0.01440323 0.01254006 0.01217681
#  0.01045596 0.00966913 0.00894451 0.00838664 0.00813429 0.00731924
#  0.00697427 0.00674426]
#
# ---- Embedding dimension: 20
# ---- Signal dimension: 20
# ---- Computing kernels ...
# ---- Settings:
#
# epochs : 100
# order : 1
# lr : 1
# batch_size : 64
# hidden_channels : [64]
# out_channels : 32
# inner_product_features : False
# emb_norm : True
# diffusion : False
# include_positions : True
# momentum : 0.9
# dropout : 0.0
# batch_norm : batch_norm
# bias : True
# frac_sampled_nb : -1
# include_self : True
# vec_norm : False
# seed : 0
# dim_signal : 20
# dim_emb : 20
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  440
# ---- Total number of parameters:  30433
#
# Using device cuda:0
# [0.30121361 0.20954643 0.08291292 0.05592497 0.03389065 0.02915788
#  0.02469869 0.01974134 0.01745466 0.01526718 0.01364844 0.01257754
#  0.01178705 0.00988236 0.00983556 0.00898721 0.00810049 0.00802297
#  0.00739014 0.00674193]
#
# ---- Embedding dimension: 20
# ---- Signal dimension: 20
# ---- Computing kernels ... [0.30121361 0.20954643 0.08291292 0.05592497 0.03389065 0.02915788
#  0.02469869 0.01974134 0.01745466 0.01526718 0.01364844 0.01257754
#  0.01178705 0.00988236 0.00983556 0.00898721 0.00810049 0.00802297
#  0.00739014 0.00674193]
#
# ---- Embedding dimension: 20
# ---- Signal dimension: 20
# ---- Computing kernels ...
# ---- Settings:
#
# epochs : 100
# order : 1
# lr : 1
# batch_size : 64
# hidden_channels : [64]
# out_channels : 32
# inner_product_features : False
# emb_norm : True
# diffusion : False
# include_positions : True
# momentum : 0.9
# dropout : 0.0
# batch_norm : batch_norm
# bias : True
# frac_sampled_nb : -1
# include_self : True
# vec_norm : False
# seed : 0
# dim_signal : 20
# dim_emb : 20
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  440
# ---- Total number of parameters:  30433
#
# Using device cuda:0
# [0.20960925 0.16609472 0.12740738 0.08539196 0.04262937 0.04176242
#  0.02781738 0.02489122 0.02422016 0.01704126 0.01668187 0.01560025
#  0.01546735 0.01374891 0.01203125 0.01125048 0.01051211 0.00924854
#  0.00859579 0.00808841]
#
# ---- Embedding dimension: 20
# ---- Signal dimension: 20
# ---- Computing kernels ... [0.20960925 0.16609472 0.12740738 0.08539196 0.04262937 0.04176242
#  0.02781738 0.02489122 0.02422016 0.01704126 0.01668187 0.01560025
#  0.01546735 0.01374891 0.01203125 0.01125048 0.01051211 0.00924854
#  0.00859579 0.00808841]
#
# ---- Embedding dimension: 20
# ---- Signal dimension: 20
# ---- Computing kernels ...
# ---- Settings:
#
# epochs : 100
# order : 1
# lr : 1
# batch_size : 64
# hidden_channels : [64]
# out_channels : 32
# inner_product_features : False
# emb_norm : True
# diffusion : False
# include_positions : True
# momentum : 0.9
# dropout : 0.0
# batch_norm : batch_norm
# bias : True
# frac_sampled_nb : -1
# include_self : True
# vec_norm : False
# seed : 0
# dim_signal : 20
# dim_emb : 20
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  440
# ---- Total number of parameters:  30433
#
# Using device cuda:0
# [0.2505035  0.14380736 0.10073317 0.08039205 0.06636485 0.05959762
#  0.03576203 0.03098485 0.0263824  0.02231369 0.0197044  0.01785519
#  0.01490763 0.01338866 0.01320421 0.01221737 0.01085513 0.01005322
#  0.00757824 0.00716841]
#
# ---- Embedding dimension: 20
# ---- Signal dimension: 20
# ---- Computing kernels ... [0.2505035  0.14380736 0.10073317 0.08039205 0.06636485 0.05959762
#  0.03576203 0.03098485 0.0263824  0.02231369 0.0197044  0.01785519
#  0.01490763 0.01338866 0.01320421 0.01221737 0.01085513 0.01005322
#  0.00757824 0.00716841]
#
# ---- Embedding dimension: 20
# ---- Signal dimension: 20
# ---- Computing kernels ...
# ---- Settings:
#
# epochs : 100
# order : 1
# lr : 1
# batch_size : 64
# hidden_channels : [64]
# out_channels : 32
# inner_product_features : False
# emb_norm : True
# diffusion : False
# include_positions : True
# momentum : 0.9
# dropout : 0.0
# batch_norm : batch_norm
# bias : True
# frac_sampled_nb : -1
# include_self : True
# vec_norm : False
# seed : 0
# dim_signal : 20
# dim_emb : 20
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  440
# ---- Total number of parameters:  30433
#
# Using device cuda:0

# %%
num_models = 7
num_plots_per_model = 2
fig = plt.figure(figsize=(20,12))

for i, kw in enumerate([3, 5, 10, 20, 30, 50, 100]):
    data_train = training[i]
    data_test = testing[i]
    label_train_marble = labels_train[i]
    label_test_marble = labels_test[i]

    # Calculate subplot index for training data in the first row
    ax1 = fig.add_subplot(num_plots_per_model, num_models, i+1, projection='3d')
    ax = cebra.plot_embedding(ax=ax1, embedding=data_train.emb, embedding_labels=label_train_marble[:,0], markersize=0.2, title=f'MARBLE-train_kw{kw}')
    
    # Calculate subplot index for testing data in the second row
    ax2 = fig.add_subplot(num_plots_per_model, num_models, num_models + i + 1, projection='3d')
    ax = cebra.plot_embedding(ax=ax2, embedding=data_test.emb, embedding_labels=label_test_marble[:,0], markersize=1, title=f'MARBLE-test_kw{kw}')

plt.tight_layout()
plt.savefig('marble_cebra_embeddings_3D_kernelwidth_scan.png')

# %%
results = [cebra_time_decode[4][:-1], cebra_posdir_decode[4][:-1],  cebra_pos_decode[4][:-1], ]
for i, kw in enumerate([3, 5, 10, 20, 30, 50, 100]):
    
    data_train = training[i]
    data_test = testing[i]
    label_train_marble = labels_train[i]
    label_test_marble = labels_test[i]
    
    marble_decode = decoding_pos_dir(data_train.emb, data_test.emb, label_train_marble, label_test_marble)
    results.append(marble_decode[4])
    
    
    
results = pd.DataFrame(data=np.vstack(results).T,columns=['c-time','c-pos+dir', 'c-pos','kw3','kw5','kw10','kw20','kw30','kw50','kw100',])
results = results.melt()
results.columns = ['model','accuracy']

f, ax = plt.subplots(figsize=(8,8))
sns.despine(bottom=True, left=True)

random_sampling = np.random.randint(low=0, high=results.shape[0], size=(200,))

sns.stripplot(
    data=results.iloc[random_sampling,:], x="model", y="accuracy", order=['c-time','c-pos+dir', 'c-pos','kw3','kw5','kw10','kw20','kw30','kw50','kw100',], 
    dodge=True, alpha=.5, zorder=1, color='gray',
)

sns.pointplot(
    data=results, x="model", y="accuracy",
    join=False, dodge=.8 - .8 / 3, palette="dark",
    markers="d", scale=.75, errorbar=None
)

plt.ylim([0,0.4])

pairs=[("c-time", "kw3"),
      ("c-pos+dir", "kw3"),
      ("c-pos", "kw3"),
        ("kw3", "kw5"),
      ("kw5", "kw10"),
      ("kw10", "kw20"),
      ("kw20", "kw30"),
      ("kw30", "kw50"),
      ("kw50", "kw100")]

annotator = Annotator(ax, pairs, data=results, x="model", y="accuracy",)
annotator.configure(test='Wilcoxon', text_format='star', loc='outside')
annotator.apply_and_annotate()
plt.tight_layout()
plt.savefig('decoding_accuracy_rat_32output_violin_kwscan.svg')
# Out:
# /home/robert/anaconda3/lib/python3.9/site-packages/statannotations/_Plotter.py:337: UserWarning: Invalid x-position found. Are the same parameters passed to seaborn and statannotations calls? or are there few data points?
#   warnings.warn(
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# c-pos vs. kw3: Wilcoxon test (paired samples), P_val:7.166e-01 Stat=9.901e+05
# kw3 vs. kw5: Wilcoxon test (paired samples), P_val:8.143e-24 Stat=7.398e+05
# kw5 vs. kw10: Wilcoxon test (paired samples), P_val:7.414e-14 Stat=8.064e+05
# kw10 vs. kw20: Wilcoxon test (paired samples), P_val:7.591e-38 Stat=6.668e+05
# kw20 vs. kw30: Wilcoxon test (paired samples), P_val:2.175e-01 Stat=9.677e+05
# kw30 vs. kw50: Wilcoxon test (paired samples), P_val:5.941e-74 Stat=5.254e+05
# kw50 vs. kw100: Wilcoxon test (paired samples), P_val:3.456e-72 Stat=5.189e+05
# c-pos+dir vs. kw3: Wilcoxon test (paired samples), P_val:4.227e-01 Stat=9.788e+05
# c-time vs. kw3: Wilcoxon test (paired samples), P_val:1.247e-42 Stat=6.463e+05
