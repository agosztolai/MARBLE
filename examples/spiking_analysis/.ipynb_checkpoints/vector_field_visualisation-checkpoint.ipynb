# %%
# %load_ext autoreload
# %autoreload 2
import pickle
from MARBLE import utils, plotting, net, postprocessing, geometry

import matplotlib.pyplot as plt

# %%
from sklearn.decomposition import PCA
import numpy as np
def main():    
    rates = pickle.load(open('../outputs/spiking_data/rate_data_1ms.pkl','rb'))       

    # definingf the set of conditions     
    conditions=['DownLeft','Left','UpLeft','Up','UpRight','Right','DownRight']    
    
    # list of days
    days = rates.keys()
    
    # define some parameters
    pca_n = 5
    rm_outliers = False
    filter_data = False
    plot = False
      
    # storing all distance matrices
    embeddings = []
    distance_matrices = []
    

    times = [];
    all_condition_labels = [];
    
    # loop over each day
    for day in days:
        
        # first stack all trials from that day together and fit pca
        print(day)
        pos = []            
        # loop over each condition on that day
        for c, cond in enumerate(conditions):

            # go cue at 500ms 
            data = rates[day][cond][:,500:,:]
            
            # loop over all trials
            for trial in data:
                # store each trial as time x channels
                pos.append(trial)
                
                # smooth trial over time
                if filter_data:
                    trial = savgol_filter(trial, 9,2)
                
                # store each trial as time x channels
                pos.append(trial)
              
        # stacking all trials into a single array (time x channels)
        pos = np.vstack(pos)
        
        # fit PCA to all data across all conditions on a given day simultaneously
        pca = PCA(n_components=pca_n)
        pca.fit(pos)     
        print(pca.explained_variance_ratio_)   
        
        # create empty list of lists for each condition
        pos = [[] for u in range(len(conditions))]
        vel = [[] for u in range(len(conditions))]             
        timepoints = [[] for u in range(len(conditions))]    
        condition_labels = [[] for u in range(len(conditions))]    
        
        # loop over conditions
        for c, cond in enumerate(conditions):
            
            # go cue at 500ms 
            data = rates[day][cond][:,np.arange(500,1200,5),:]           
                       
            # loop over all trials
            for trial in data:
                
                # smooth trial over time
                if filter_data:
                    trial = savgol_filter(trial, 9,2)  
                
                # apply transformation to single trial
                trial = pca.transform(trial)
                
                # take all points except last
                pos[c].append(trial[:-1,:])
                
                # extract vectors between coordinates
                vel[c].append(get_vector_array(trial))
                
                timepoints[c].append(np.linspace(0,trial.shape[0]-2,trial.shape[0]-1))
                condition_labels[c].append(np.repeat(c,trial.shape[0]-1))
   
        # plt.quiver(pos[0][1][:,0],pos[0][1][:,1],vel[0][1][:,0],vel[0][1][:,1], angles='xy')
        
        # stack the trials within each condition
        pos = [np.vstack(u) for u in pos] # trials x time x channels
        vel = [np.vstack(u) for u in vel] # trials x time x channels
        timepoints = [np.hstack(u) for u in timepoints] 
        condition_labels = [np.hstack(u) for u in condition_labels]   
          
        # remove outliers
        if rm_outliers:
            pos, vel, timepoints, condition_labels = remove_outliers(pos, vel, timepoints, condition_labels)
            
def get_vector_array(coords):
    """ function for defining the vector features from each array of coordinates """
    diff = np.diff(coords, axis=0)
    return diff

# %%
main()
# Out:
# 43
# [0.19256373 0.13538672 0.08842333 0.07687818 0.05828389]

# %% [markdown]
# # Visualise a single condition in a single session

# %%
pos, vel = pickle.load(open('../outputs/spiking_data/raw_data_session_1','rb'))

# %%
#data = pickle.load(open('../outputs/spiking_data/data_object_session_0.pkl','rb'))
data = utils.construct_dataset(pos, features=vel, graph_type='cknn', k=30, stop_crit=0.02, delta=1, n_evec=2,
                               n_nodes=None, n_workers=1, n_geodesic_nb=10, compute_laplacian=True, vector=False)
#plotting.fields(data, width=0.03)
# Out:
# ---- Embedding dimension: 5
# ---- Signal dimension: 5
#
#
# Vector computations are disabled
#
# ---- Computing kernels ... Done

# %% [markdown]
# # Train model on all conditions and sessions

# %%
par = {'epochs': 150, #optimisation epochs
               'order': 2, #order of derivatives
               'hidden_channels': 100, #number of internal dimensions in MLP
               'out_channels': 6,
               'inner_product_features': False,
               'vec_norm': False,
               'diffusion': True,
              }
    
model = net(data, **par)#, loadpath='./outputs/best_model.pth')#, loadpath='../outputs/spiking_data/session_0/best_model.pth')
    
model.run_training(data, use_best=True)#, outdir='../outputs/spiking_data/session_0')
# Out:
# ---- Settings:
#
# epochs : 150
# order : 2
# hidden_channels : 100
# out_channels : 6
# inner_product_features : False
# vec_norm : False
# diffusion : True
# batch_size : 64
# lr : 0.01
# momentum : 0.9
# include_positions : False
# frac_sampled_nb : -1
# dropout : 0.0
# n_lin_layers : 2
# bias : True
# batch_norm : None
# seed : 0
# processes : 1
# dim_signal : 5
# dim_emb : 5
# n_sampled_nb : -1
#
# ---- Number of features to pass to the MLP:  155
# ---- Total number of parameters:  16207
#
# ---- Training network ...
#
# Epoch: 1, Training loss: 1.3841, Validation loss: 1.3832, lr: 0.0100 *
# Epoch: 2, Training loss: 1.3816, Validation loss: 1.3783, lr: 0.0100 *
# Epoch: 3, Training loss: 1.3671, Validation loss: 1.3394, lr: 0.0100 *
# Epoch: 4, Training loss: 1.3255, Validation loss: 1.2937, lr: 0.0100 *
# Epoch: 5, Training loss: 1.2795, Validation loss: 1.2584, lr: 0.0100 *
# Epoch: 6, Training loss: 1.2525, Validation loss: 1.2485, lr: 0.0100 *
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 12
#       1 par = {'epochs': 150, #optimisation epochs
#       2                'order': 2, #order of derivatives
#       3                'hidden_channels': 100, #number of internal dimensions in MLP
#    (...)
#       7                'diffusion': True,
#       8               }
#      10 model = net(data, **par)#, loadpath='./outputs/best_model.pth')#, loadpath='../outputs/spiking_data/session_0/best_model.pth')
# ---> 12 model.run_training(data, use_best=True)
#
# File /mnt/scratch/lts2/gosztolai/MARBLE/MARBLE/main.py:183, in net.run_training(self, data, outdir, use_best, verbose)
#     180 epoch = self.epoch + epoch + 1
#     182 train_loss, optimizer = self.batch_loss(data, train_loader, train=True, verbose=verbose, optimizer=optimizer)
# --> 183 val_loss, _ = self.batch_loss(data, val_loader, verbose=verbose)
#     184 scheduler.step(train_loss)
#     186 writer.add_scalar('Loss/train', train_loss, epoch)
#
# File /mnt/scratch/lts2/gosztolai/MARBLE/MARBLE/main.py:145, in net.batch_loss(self, data, loader, train, verbose, optimizer)
#     142 _, n_id, adjs = batch
#     143 adjs = [adj.to(data.x.device) for adj in utils.to_list(adjs)]
# --> 145 emb = self.forward(data, n_id, adjs)
#     146 loss = self.loss(emb)
#     147 cum_loss += float(loss)
#
# File /mnt/scratch/lts2/gosztolai/MARBLE/MARBLE/main.py:63, in net.forward(self, data, n_id, adjs)
#      60     x = self.diffusion(x, L, Lc=Lc, method='spectral')
#      62 #restrict to current batch
# ---> 63 x = x[n_id]
#      64 if data.kernels[0].size(0) == n*d:
#      65     n_id = utils.expand_index(n_id, d)
#
# KeyboardInterrupt:

# %%
data = model.evaluate(data)
data = postprocessing(data, n_clusters=40)
# Out:
# Performed umap embedding on embedded results.

# %%
conditions = ['DownLeft','Left','UpLeft','Up','UpRight','Right','DownRight']
plotting.embedding(data, data.y.numpy().astype(int), titles=conditions)
# Out:
# <AxesSubplot:>

# %%
plt.imshow(data.dist); plt.colorbar()

# %%
emb_MDS, _ = geometry.embed(data.dist, embed_typ = 'MDS')
labels = [i for i in range(len(conditions))]
plotting.embedding(emb_MDS, labels, titles=conditions, s=30, alpha=1)
# Out:
# Performed MDS embedding on embedded results.
# <AxesSubplot:>

# %%
import numpy as np
from sklearn.decomposition import PCA
rates = pickle.load(open('../outputs/spiking_data/rate_data_1ms.pkl','rb'))       

# definingf the set of conditions     
conditions=['DownLeft','Left','UpLeft','Up','UpRight','Right','DownRight']    
    
# list of days
days = rates.keys()
    
# define some parameters
pca_n = 5
      
# storing all distance matrices
embeddings = []
distance_matrices = []
    

times = [];
all_condition_labels = [];
    
# loop over each day
for day in days:
        
        # first stack all trials from that day together and fit pca
        print(day)
        pos = []            
        # loop over each condition on that day
        for c, cond in enumerate(conditions):

            # go cue at 500ms
            data = rates[day][cond][:,500:,:]
            
            # loop over all trials
            for trial in data:
                # store each trial as time x channels
                pos.append(trial)
              
        # stacking all trials into a single array (time x channels)
        pos = np.vstack(pos)
        print(pos.shape)
        
        # fit PCA to all data across all conditions on a given day simultaneously
        pca = PCA(n_components=pca_n)
        pca.fit(pos)     
        print(pca.explained_variance_ratio_)

# %%
rates[day][cond].shape
